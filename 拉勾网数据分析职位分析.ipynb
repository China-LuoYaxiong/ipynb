# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#导入相应的包" data-toc-modified-id="导入相应的包-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>导入相应的包</a></span></li><li><span><a href="#数据清洗" data-toc-modified-id="数据清洗-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>数据清洗</a></span><ul class="toc-item"><li><span><a href="#导入数据" data-toc-modified-id="导入数据-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>导入数据</a></span></li><li><span><a href="#查看数据的信息" data-toc-modified-id="查看数据的信息-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>查看数据的信息</a></span></li><li><span><a href="#数据去重" data-toc-modified-id="数据去重-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>数据去重</a></span></li><li><span><a href="#缺失值处理" data-toc-modified-id="缺失值处理-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>缺失值处理</a></span><ul class="toc-item"><li><span><a href="#公司名称缺失值处理" data-toc-modified-id="公司名称缺失值处理-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>公司名称缺失值处理</a></span></li><li><span><a href="#公司地点缺失值处理" data-toc-modified-id="公司地点缺失值处理-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>公司地点缺失值处理</a></span></li><li><span><a href="#城市缺失值处理" data-toc-modified-id="城市缺失值处理-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>城市缺失值处理</a></span></li><li><span><a href="#岗位技能缺失值处理" data-toc-modified-id="岗位技能缺失值处理-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>岗位技能缺失值处理</a></span></li></ul></li><li><span><a href="#去掉-公司地点-这列两边的中括号" data-toc-modified-id="去掉-公司地点-这列两边的中括号-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>去掉 公司地点 这列两边的中括号</a></span></li><li><span><a href="#去掉公司短评两边的引号" data-toc-modified-id="去掉公司短评两边的引号-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>去掉公司短评两边的引号</a></span></li><li><span><a href="#拆分-工位要求" data-toc-modified-id="拆分-工位要求-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>拆分 工位要求</a></span><ul class="toc-item"><li><span><a href="#拆分出-薪资" data-toc-modified-id="拆分出-薪资-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>拆分出 薪资</a></span></li><li><span><a href="#拆分出-经验要求" data-toc-modified-id="拆分出-经验要求-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>拆分出 经验要求</a></span></li><li><span><a href="#拆分出-学历要求" data-toc-modified-id="拆分出-学历要求-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>拆分出 学历要求</a></span></li></ul></li><li><span><a href="#删除-工位要求-这一列" data-toc-modified-id="删除-工位要求-这一列-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>删除 工位要求 这一列</a></span></li><li><span><a href="#拆分-公司级别-成三列" data-toc-modified-id="拆分-公司级别-成三列-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>拆分 公司级别 成三列</a></span></li><li><span><a href="#删除-公司级别" data-toc-modified-id="删除-公司级别-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>删除 公司级别</a></span></li></ul></li><li><span><a href="#数据分析" data-toc-modified-id="数据分析-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>数据分析</a></span><ul class="toc-item"><li><span><a href="#薪增一列-平均薪资" data-toc-modified-id="薪增一列-平均薪资-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>薪增一列 平均薪资</a></span></li><li><span><a href="#城市的平均薪资的关系" data-toc-modified-id="城市的平均薪资的关系-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>城市的平均薪资的关系</a></span></li><li><span><a href="#将上诉平均薪资的分析过程封装成一个函数" data-toc-modified-id="将上诉平均薪资的分析过程封装成一个函数-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>将上诉平均薪资的分析过程封装成一个函数</a></span></li><li><span><a href="#学历与平均薪资的关系" data-toc-modified-id="学历与平均薪资的关系-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>学历与平均薪资的关系</a></span></li><li><span><a href="#公司领域与平均薪资的关系" data-toc-modified-id="公司领域与平均薪资的关系-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>公司领域与平均薪资的关系</a></span></li><li><span><a href="#融资阶段与平均薪资的关系" data-toc-modified-id="融资阶段与平均薪资的关系-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>融资阶段与平均薪资的关系</a></span></li><li><span><a href="#公司规模与平均薪资的关系" data-toc-modified-id="公司规模与平均薪资的关系-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>公司规模与平均薪资的关系</a></span></li><li><span><a href="#经验要求与平均薪资的关系" data-toc-modified-id="经验要求与平均薪资的关系-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>经验要求与平均薪资的关系</a></span></li><li><span><a href="#利用饼图分析数据分析职位岗位技能占比" data-toc-modified-id="利用饼图分析数据分析职位岗位技能占比-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>利用饼图分析数据分析职位岗位技能占比</a></span></li><li><span><a href="#数据分析技能词云图" data-toc-modified-id="数据分析技能词云图-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>数据分析技能词云图</a></span></li><li><span><a href="#各城市-数据分析职位数目-地理图" data-toc-modified-id="各城市-数据分析职位数目-地理图-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>各城市 数据分析职位数目 地理图</a></span></li></ul></li></ul></div>

# %% [markdown]
# 本数据来源于拉勾网， 利用爬虫爬下来的。接下来我们来探讨一下基于拉勾网看数据分析职位的情况

# %% [markdown]
# # 导入相应的包

# %%
#全部行都能输出
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline

# %%
plt.rcParams['font.sans-serif']=['Simhei']  #显示中文,解决图中无法显示中文的问题
plt.rcParams['axes.unicode_minus']=False    #设置显示中文后,负号显示受影响。解决坐标轴上乱码问题

# %% [markdown]
# # 数据清洗

# %% [markdown]
# ## 导入数据

# %%
df = pd.read_csv(r"C:\Users\EDZ\Desktop\案列\拉勾网数据分析职位分析\data\lagou1.csv")
df.head()
# Out:
#           公司名称   公司地点                    公司短评                          公司级别  \
# 0           玩吧  [东城区]  “七险一金,免费午餐,弹性不打卡,季度旅游”            社交 / B轮 / 150-500人
# 1         和信集团  [大望路]             “五险一金、周末双休”          金融 / 不需要融资 / 2000人以上
# 2         水滴互助   [望京]    “年底双薪,股票期权,扁平管理,晋升快”  移动互联网,医疗丨健康 / B轮 / 500-2000人
# 3          易企秀  [西北旺]  “七险一金、零食水果、带薪年假、年度旅游等”         移动互联网 / B轮 / 150-500人
# 4  齐聚科技（原呱呱视频）  [东城区]  “五险一金,弹性工作,餐补年终奖,节日福利”      移动互联网,游戏 / C轮 / 150-500人
#
#    城市               岗位技能                 工位要求     标题
# 0  北京      数据分析 SPSS SQL  15k-25k 经验3-5年 / 本科  数据分析师
# 1  北京               数据分析    10k-20k 经验不限 / 本科  数据分析师
# 2  北京    数据分析 MySQL Hive  15k-25k 经验3-5年 / 本科  数据分析师
# 3  北京      数据运营 SPSS SQL  15k-30k 经验3-5年 / 本科   数据分析
# 4  北京  游戏 社交 SQL 数据分析 商业  15k-20k 经验3-5年 / 大专  数据分析师

# %% [markdown]
# 可以大概看一下有哪些列, 有些列里面明显包含了许多信息比如工位要求这一列， 就包含了3个信息，
# **薪资 经验 学历**， 所以我们后面就需要对类似的这种进行分列

# %% [markdown]
# ## 查看数据的信息

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1674 entries, 0 to 1673
# Data columns (total 8 columns):
# 公司名称    1673 non-null object
# 公司地点    1672 non-null object
# 公司短评    1674 non-null object
# 公司级别    1674 non-null object
# 城市      1669 non-null object
# 岗位技能    1671 non-null object
# 工位要求    1674 non-null object
# 标题      1674 non-null object
# dtypes: object(8)
# memory usage: 104.8+ KB

# %% [markdown]
# 从这里我们可以看出一下信息：
# - 1 数据一共1674行， 8列
# - 2 数据是有缺失值的， 比如公司名称这列就缺失1个, 公司地点缺失两个， 城市缺失5个
# - 3 所有列的数据类型， 都是object

# %% [markdown]
# ## 数据去重

# %%
df.drop_duplicates(inplace=True) # inplace=True在原表上进行去重， 不用返回新的DataFrame对象

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1593 entries, 0 to 1673
# Data columns (total 8 columns):
# 公司名称    1592 non-null object
# 公司地点    1591 non-null object
# 公司短评    1593 non-null object
# 公司级别    1593 non-null object
# 城市      1588 non-null object
# 岗位技能    1590 non-null object
# 工位要求    1593 non-null object
# 标题      1593 non-null object
# dtypes: object(8)
# memory usage: 112.0+ KB

# %% [markdown]
# 从这里我们可以看出数据变成了1593行， 也就是说原数据的确存在重复

# %%
1674-1593  # 有81行是完全重复的， 删除即可
# Out:
# 81

# %% [markdown]
# ## 缺失值处理

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1593 entries, 0 to 1673
# Data columns (total 8 columns):
# 公司名称    1592 non-null object
# 公司地点    1591 non-null object
# 公司短评    1593 non-null object
# 公司级别    1593 non-null object
# 城市      1588 non-null object
# 岗位技能    1590 non-null object
# 工位要求    1593 non-null object
# 标题      1593 non-null object
# dtypes: object(8)
# memory usage: 112.0+ KB

# %% [markdown]
# 缺失值情况如下：
# - 公司名称1个缺失
# - 公司地点2个缺失
# - 城市5个缺失
# - 岗位技能3个缺失

# %% [markdown]
# ### 公司名称缺失值处理

# %%
# 提取出公司名称有缺失的行
df[df.公司名称.isna()]
# Out:
#     公司名称   公司地点         公司短评                公司级别  城市 岗位技能                工位要求  \
# 872  NaN  [珠江路]  “扁平管理；弹性工作”  教育 / 未融资 / 50-150人  南京  大数据  4k-6k 经验应届毕业生 / 硕士
#
#                       标题
# 872  数据分析（python）实习生（南京）

# %% [markdown]
# 像这种缺失， 我们完全是不知道的， 所以可以直接删除该行， 当然我们这里不用带算法， 也可以不用处理，
# 所以**怎么处理都没有任何关系, 那我们这里选择删除该行。**

# %%
df.drop(index=872, inplace=True)  # 删除该行

# %%
# 提取出公司名称有缺失的行
df[df.公司名称.isna()]   # 公司名称不再有缺失值
# Out:
# Empty DataFrame
# Columns: [公司名称, 公司地点, 公司短评, 公司级别, 城市, 岗位技能, 工位要求, 标题]
# Index: []

# %% [markdown]
# ### 公司地点缺失值处理

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1592 entries, 0 to 1673
# Data columns (total 8 columns):
# 公司名称    1592 non-null object
# 公司地点    1590 non-null object
# 公司短评    1592 non-null object
# 公司级别    1592 non-null object
# 城市      1587 non-null object
# 岗位技能    1589 non-null object
# 工位要求    1592 non-null object
# 标题      1592 non-null object
# dtypes: object(8)
# memory usage: 111.9+ KB

# %%
# 提取出公司地点有缺失的行
df[df.公司地点.isna()]
# Out:
#       公司名称 公司地点                    公司短评                      公司级别  城市  \
# 876   南京森马  NaN     “目前五家店正在急速发展。空间很大。”  消费生活 / 不需要融资 / 500-2000人  南京
# 1634  三藏科技  NaN  “办公环境优、资深大佬指导、领导超Nice”       软件开发 / 未融资 / 15-50人  武汉
#
#             岗位技能                 工位要求         标题
# 876    产品设计 产品策划    3K-5K 经验1年以下 / 大专     数据分析助理
# 1634  建模 机器学习 算法  10k-20k 经验3-5年 / 硕士  数据分析算法工程师

# %%
# 我们这里也把这两行删除了
df.drop(index=[876, 1634], inplace=True)

# %%
# 提取出公司地点有缺失的行
df[df.公司地点.isna()]     # 公司地点也不再有缺失的行
# Out:
# Empty DataFrame
# Columns: [公司名称, 公司地点, 公司短评, 公司级别, 城市, 岗位技能, 工位要求, 标题]
# Index: []

# %% [markdown]
# ### 城市缺失值处理

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1590 entries, 0 to 1673
# Data columns (total 8 columns):
# 公司名称    1590 non-null object
# 公司地点    1590 non-null object
# 公司短评    1590 non-null object
# 公司级别    1590 non-null object
# 城市      1585 non-null object
# 岗位技能    1587 non-null object
# 工位要求    1590 non-null object
# 标题      1590 non-null object
# dtypes: object(8)
# memory usage: 111.8+ KB

# %%
df[df.城市.isna()]
# Out:
#                公司名称      公司地点                   公司短评  \
# 871            苏宁易购     [玄武区]         “500强 平台大 发展好”
# 874   苏宁云商集团互联网平台公司      [仙林]           “内容电商，前景无限。”
# 1617             微派  [东湖新技术…]            “发展空间大,大牛带”
# 1618            小红书      [光谷]  “六险一金 周末双休 13薪 定期体检等”
# 1619             极验  [东湖新技术…]       “有挑战性,技术先驱,大牛队友”
#
#                           公司级别   城市           岗位技能                  工位要求  \
# 871   电商,信息安全 / 上市公司 / 2000人以上  NaN     数据库 BI 可视化   10k-15k 经验3-5年 / 本科
# 874        电商 / 上市公司 / 2000人以上  NaN             电商  10k-20k 经验应届毕业生 / 本科
# 1617         社交 / B轮 / 50-150人  NaN           数据分析    4k-8k 经验应届毕业生 / 本科
# 1618  消费生活 / D轮及以上 / 500-2000人  NaN           数据分析   10k-15k 经验3-5年 / 本科
# 1619  信息安全,数据服务 / B轮 / 50-150人  NaN  大数据 数据挖掘 数据分析  12k-18k 经验应届毕业生 / 本科
#
#                    标题
# 871              数据分析
# 874   社招：高级数据分析师（非校招）
# 1617      数据分析（校招/实习）
# 1618        高级业务数据分析师
# 1619          数据分析工程师

# %% [markdown]
# 这里我们就不要直接删除了， 因为明显这里是可以填充缺失值的， 城市虽然缺失， 但是我们可以通过公司地点这一列来判断城市应该是什么，
# 比如1617 1618 1619 **公司地点出现'东湖'， '光谷'则可以判断出这些行的城市就应该是武汉。**
# **另外稍微查下就知道， 玄武区 仙林在南京市。**

# %%
# 把871 874 两行的城市这一列填充成  ---南京
df.loc[[871, 874], '城市'] = '南京'  # 填充一个标量会自动进行广播

# %%
df.loc[[871, 874], '城市']
# Out:
# 871    南京
# 874    南京
# Name: 城市, dtype: object

# %%
# 把1617 1618 1619三行的城市这一列的填充成---武汉
df.loc[1617:1619, '城市'] = '武汉'

# %%
df.loc[1617:1619, '城市']
# Out:
# 1617    武汉
# 1618    武汉
# 1619    武汉
# Name: 城市, dtype: object

# %%
df[df.城市.isna()]  # 城市这列也不在有缺失值
# Out:
# Empty DataFrame
# Columns: [公司名称, 公司地点, 公司短评, 公司级别, 城市, 岗位技能, 工位要求, 标题]
# Index: []

# %% [markdown]
# ### 岗位技能缺失值处理

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1590 entries, 0 to 1673
# Data columns (total 8 columns):
# 公司名称    1590 non-null object
# 公司地点    1590 non-null object
# 公司短评    1590 non-null object
# 公司级别    1590 non-null object
# 城市      1590 non-null object
# 岗位技能    1587 non-null object
# 工位要求    1590 non-null object
# 标题      1590 non-null object
# dtypes: object(8)
# memory usage: 191.8+ KB

# %%
# 提取出岗位技能有缺失的行
df[df.岗位技能.isna()]
# Out:
#               公司名称   公司地点                  公司短评                          公司级别  \
# 328   北京盛业恒泰投资有限公司   [朝外]        “双休 五险一金 朝九晚五”   移动互联网,金融 / 不需要融资 / 150-500人
# 475       XGATE讯格得  [武侯区]  “五险一金、国定假期、每周水果、休息室”  移动互联网,企业服务 / 不需要融资 / 50-150人
# 1025          旺旺集团   [虹桥]         “有班车、食堂；零食福利”     电商,移动互联网 / 上市公司 / 2000人以上
#
#       城市 岗位技能               工位要求    标题
# 328   北京  NaN   6k-12k 经验不限 / 大专  数据分析
# 475   成都  NaN  12k-20k 经验不限 / 硕士  数据分析
# 1025  上海  NaN    6k-8k 经验不限 / 不限  数据分析

# %% [markdown]
# 岗位技能我们很难获取， 那我们就用户一个空字符串来填充

# %%
df['岗位技能'] = df.岗位技能.fillna('')

# %%
# 提取出岗位技能有缺失的行
df[df.岗位技能.isna()]      # 岗位技能也不在有缺失
# Out:
# Empty DataFrame
# Columns: [公司名称, 公司地点, 公司短评, 公司级别, 城市, 岗位技能, 工位要求, 标题]
# Index: []

# %%
df[df.岗位技能=='']
# Out:
#               公司名称   公司地点                  公司短评                          公司级别  \
# 328   北京盛业恒泰投资有限公司   [朝外]        “双休 五险一金 朝九晚五”   移动互联网,金融 / 不需要融资 / 150-500人
# 475       XGATE讯格得  [武侯区]  “五险一金、国定假期、每周水果、休息室”  移动互联网,企业服务 / 不需要融资 / 50-150人
# 1025          旺旺集团   [虹桥]         “有班车、食堂；零食福利”     电商,移动互联网 / 上市公司 / 2000人以上
#
#       城市 岗位技能               工位要求    标题
# 328   北京        6k-12k 经验不限 / 大专  数据分析
# 475   成都       12k-20k 经验不限 / 硕士  数据分析
# 1025  上海         6k-8k 经验不限 / 不限  数据分析

# %% [markdown]
# 注意缺失值是NaN, 现在这里是空字符串， 两者是不一样的

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1590 entries, 0 to 1673
# Data columns (total 8 columns):
# 公司名称    1590 non-null object
# 公司地点    1590 non-null object
# 公司短评    1590 non-null object
# 公司级别    1590 non-null object
# 城市      1590 non-null object
# 岗位技能    1590 non-null object
# 工位要求    1590 non-null object
# 标题      1590 non-null object
# dtypes: object(8)
# memory usage: 191.8+ KB

# %% [markdown]
# 到这里我们就把缺失值处理完了

# %% [markdown]
# ## 去掉 公司地点 这列两边的中括号

# %%
df.head()
# Out:
#           公司名称   公司地点                    公司短评                          公司级别  \
# 0           玩吧  [东城区]  “七险一金,免费午餐,弹性不打卡,季度旅游”            社交 / B轮 / 150-500人
# 1         和信集团  [大望路]             “五险一金、周末双休”          金融 / 不需要融资 / 2000人以上
# 2         水滴互助   [望京]    “年底双薪,股票期权,扁平管理,晋升快”  移动互联网,医疗丨健康 / B轮 / 500-2000人
# 3          易企秀  [西北旺]  “七险一金、零食水果、带薪年假、年度旅游等”         移动互联网 / B轮 / 150-500人
# 4  齐聚科技（原呱呱视频）  [东城区]  “五险一金,弹性工作,餐补年终奖,节日福利”      移动互联网,游戏 / C轮 / 150-500人
#
#    城市               岗位技能                 工位要求     标题
# 0  北京      数据分析 SPSS SQL  15k-25k 经验3-5年 / 本科  数据分析师
# 1  北京               数据分析    10k-20k 经验不限 / 本科  数据分析师
# 2  北京    数据分析 MySQL Hive  15k-25k 经验3-5年 / 本科  数据分析师
# 3  北京      数据运营 SPSS SQL  15k-30k 经验3-5年 / 本科   数据分析
# 4  北京  游戏 社交 SQL 数据分析 商业  15k-20k 经验3-5年 / 大专  数据分析师

# %%
df['公司地点'] = df.公司地点.map(lambda s:s[1:-1])  # map一个匿名函数搞定

# %%
df.head()
# Out:
#           公司名称 公司地点                    公司短评                          公司级别  城市  \
# 0           玩吧  东城区  “七险一金,免费午餐,弹性不打卡,季度旅游”            社交 / B轮 / 150-500人  北京
# 1         和信集团  大望路             “五险一金、周末双休”          金融 / 不需要融资 / 2000人以上  北京
# 2         水滴互助   望京    “年底双薪,股票期权,扁平管理,晋升快”  移动互联网,医疗丨健康 / B轮 / 500-2000人  北京
# 3          易企秀  西北旺  “七险一金、零食水果、带薪年假、年度旅游等”         移动互联网 / B轮 / 150-500人  北京
# 4  齐聚科技（原呱呱视频）  东城区  “五险一金,弹性工作,餐补年终奖,节日福利”      移动互联网,游戏 / C轮 / 150-500人  北京
#
#                 岗位技能                 工位要求     标题
# 0      数据分析 SPSS SQL  15k-25k 经验3-5年 / 本科  数据分析师
# 1               数据分析    10k-20k 经验不限 / 本科  数据分析师
# 2    数据分析 MySQL Hive  15k-25k 经验3-5年 / 本科  数据分析师
# 3      数据运营 SPSS SQL  15k-30k 经验3-5年 / 本科   数据分析
# 4  游戏 社交 SQL 数据分析 商业  15k-20k 经验3-5年 / 大专  数据分析师

# %% [markdown]
# ## 去掉公司短评两边的引号

# %%
df['公司短评'] = df.公司短评.map(lambda s:s[1:-1])

# %%
df.head()
# Out:
#           公司名称 公司地点                  公司短评                          公司级别  城市  \
# 0           玩吧  东城区  七险一金,免费午餐,弹性不打卡,季度旅游            社交 / B轮 / 150-500人  北京
# 1         和信集团  大望路             五险一金、周末双休          金融 / 不需要融资 / 2000人以上  北京
# 2         水滴互助   望京    年底双薪,股票期权,扁平管理,晋升快  移动互联网,医疗丨健康 / B轮 / 500-2000人  北京
# 3          易企秀  西北旺  七险一金、零食水果、带薪年假、年度旅游等         移动互联网 / B轮 / 150-500人  北京
# 4  齐聚科技（原呱呱视频）  东城区  五险一金,弹性工作,餐补年终奖,节日福利      移动互联网,游戏 / C轮 / 150-500人  北京
#
#                 岗位技能                 工位要求     标题
# 0      数据分析 SPSS SQL  15k-25k 经验3-5年 / 本科  数据分析师
# 1               数据分析    10k-20k 经验不限 / 本科  数据分析师
# 2    数据分析 MySQL Hive  15k-25k 经验3-5年 / 本科  数据分析师
# 3      数据运营 SPSS SQL  15k-30k 经验3-5年 / 本科   数据分析
# 4  游戏 社交 SQL 数据分析 商业  15k-20k 经验3-5年 / 大专  数据分析师

# %% [markdown]
# ## 拆分 工位要求

# %% [markdown]
# ### 拆分出 薪资
# 位置放在工位要求后面

# %%
s = ' 15k-25k 经验3-5年 / 本科'
s
# Out:
# ' 15k-25k 经验3-5年 / 本科'

# %%
s.split()[0]
# Out:
# '15k-25k'

# %%
df.工位要求.map(lambda s : s.split()[0])
# Out:
# 0       15k-25k
# 1       10k-20k
# 2       15k-25k
# 3       15k-30k
# 4       15k-20k
#          ...
# 1669    30k-40k
# 1670     6k-10k
# 1671      4k-6k
# 1672    15k-25k
# 1673    10k-20k
# Name: 工位要求, Length: 1590, dtype: object

# %%
df.insert(7, '薪资', df.工位要求.map(lambda s : s.split()[0]))

# %%
df.head()
# Out:
#           公司名称 公司地点                  公司短评                          公司级别  城市  \
# 0           玩吧  东城区  七险一金,免费午餐,弹性不打卡,季度旅游            社交 / B轮 / 150-500人  北京
# 1         和信集团  大望路             五险一金、周末双休          金融 / 不需要融资 / 2000人以上  北京
# 2         水滴互助   望京    年底双薪,股票期权,扁平管理,晋升快  移动互联网,医疗丨健康 / B轮 / 500-2000人  北京
# 3          易企秀  西北旺  七险一金、零食水果、带薪年假、年度旅游等         移动互联网 / B轮 / 150-500人  北京
# 4  齐聚科技（原呱呱视频）  东城区  五险一金,弹性工作,餐补年终奖,节日福利      移动互联网,游戏 / C轮 / 150-500人  北京
#
#                 岗位技能                 工位要求       薪资     标题
# 0      数据分析 SPSS SQL  15k-25k 经验3-5年 / 本科  15k-25k  数据分析师
# 1               数据分析    10k-20k 经验不限 / 本科  10k-20k  数据分析师
# 2    数据分析 MySQL Hive  15k-25k 经验3-5年 / 本科  15k-25k  数据分析师
# 3      数据运营 SPSS SQL  15k-30k 经验3-5年 / 本科  15k-30k   数据分析
# 4  游戏 社交 SQL 数据分析 商业  15k-20k 经验3-5年 / 大专  15k-20k  数据分析师

# %%
# 查看薪资这列缺失值情况
df[df.薪资.isna()]          # 薪资这一列没有缺失值
# Out:
# Empty DataFrame
# Columns: [公司名称, 公司地点, 公司短评, 公司级别, 城市, 岗位技能, 工位要求, 薪资, 标题]
# Index: []

# %%
# 查看薪资这列异常值情况
print(list(df.薪资.value_counts().index))
# Out:
# ['15k-25k', '15k-30k', '10k-20k', '20k-40k', '10k-15k', '8k-15k', '20k-30k', '15k-20k', '20k-35k', '25k-50k', '6k-8k', '12k-20k', '8k-10k', '8k-12k', '6k-10k', '25k-40k', '10k-18k', '25k-35k', '30k-50k', '18k-35k', '8k-16k', '4k-6k', '3k-5k', '12k-24k', '4k-8k', '5k-10k', '6k-12k', '7k-10k', '5k-8k', '2k-4k', '30k-40k', '18k-30k', '18k-25k', '25k-30k', '12k-18k', '4k-7k', '13k-25k', '18k-36k', '25k-45k', '30k-60k', '13k-20k', '2k-3k', '7k-14k', '8k-13k', '8k-14k', '6k-9k', '15k-22k', '14k-20k', '9k-18k', '7k-12k', '3k-4k', '20k-25k', '5k-9k', '4k-5k', '1k-2k', '5k-7k', '7k-9k', '10k-16k', '11k-18k', '18k-28k', '10k-13k', '16k-25k', '50k-80k', '12k-17k', '7k-13k', '30k-45k', '9k-12k', '40k-70k', '10k-14k', '17k-30k', '12k-16k', '18k-32k', '50k-100k', '3k-6k', '14k-25k', '12k-15k', '13k-26k', '16k-24k', '17k-34k', '19k-28k', '50k-70k', '35k-45k', '5k-6k', '12k-22k', '14k-28k', '11k-22k', '经验1-3年', '30k-55k', '45k-60k', '13k-18k', '15k-18k', '10k-17k', '17k-25k', '21k-35k', '17k-23k', '14k-18k', '35k-60k', '20k-28k', '11k-16k', '9k-11k', '7k-8k', '9k-15k', '40k-50k', '28k-40k', '20k-23k', '6k-7k', '8k-11k', '14k-24k', '经验3-5年', '11k-17k', '14k-22k', '16k-23k', '60k-100k', '40k-80k', '1k-1k', '60k-80k', '28k-55k', '16k-32k', '15k-27k', '20k-26k', '23k-46k', '9k-16k', '55k-80k', '13k-22k', '50k-65k', '11k-21k', '15k-26k', '13k-15k', '35k-50k', '21k-29k', '6k-11k', '28k-45k', '24k-25k', '40k-60k', '15k-28k', '11k-20k', '28k-38k', '26k-40k', '16k-30k', '21k-26k', '35k-55k', '9k-14k', '20K-40K', '15k-19k', '38k-65k', '30k-35k', '15k-24k', '20k-38k', '4K-5K', '25k-49k', '200k-300k', '17k-28k', '35k-70k', '35k-65k']

# %% [markdown]
# 仔细观察上面的输出结果， **有出现 '经验1-3年' ,  '经验3-5年'这些明显的异常**， 我们把这些有异常的行提出来看一下

# %%
df[df.薪资.map(lambda s: '经验' in s)]
# Out:
#         公司名称 公司地点                  公司短评                     公司级别  城市  \
# 868    SHEIN  安德门    五险一金，绩效奖金，年终奖，节日福利  电商,移动互联网 / C轮 / 2000人以上  南京
# 875   南京德胜智业  珠江路  年轻、提薪快、五险一金、不加班、做五休二   电商,消费生活 / 未融资 / 15-50人  南京
# 1624    字节跳动  洪山区     六险一金，餐补，带薪休假，扁平管理     文娱丨内容 / C轮 / 2000人以上  武汉
#
#                   岗位技能         工位要求      薪资                      标题
# 868          跨境电商 数据分析  经验1-3年 / 本科  经验1-3年        数据分析师 (MJ000443)
# 875   移动互联网 广告营销 策划 创意  经验1-3年 / 不限  经验1-3年  推广/SEO/数据分析/运营分析/策划/创意
# 1624              项目管理  经验3-5年 / 本科  经验3-5年             商业化-高级数据分析师

# %% [markdown]
# 可以看出这里明显是由于工位要求没有薪资信息导致的，所以我们必须要处理， 这里的处理方式可以这样， 868 875 都是南京， 那我们看看南京其他公司工资如何， 为了更精准一点， 我们还可以利用其他信息进行定位， 比如， 868就是南京的2000人以上的公司经验是1-3年的工资， 其他类似。

# %%
df.城市=='南京'  # 第一个条件
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1669    False
# 1670    False
# 1671    False
# 1672    False
# 1673    False
# Name: 城市, Length: 1590, dtype: bool

# %%
df.公司级别.map(lambda s : '2000人以上' in s)   # 第二个条件
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1669     True
# 1670    False
# 1671    False
# 1672     True
# 1673     True
# Name: 公司级别, Length: 1590, dtype: bool

# %%
df.工位要求.map(lambda s : '经验1-3年' in s)  # 第三个条件
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1669    False
# 1670    False
# 1671    False
# 1672    False
# 1673    False
# Name: 工位要求, Length: 1590, dtype: bool

# %%
df[(df.城市=='南京')&(df.公司级别.map(lambda s : '2000人以上' in s)&(df.工位要求.map(lambda s : '经验1-3年' in s)))]
# Out:
#            公司名称  公司地点                公司短评                       公司级别  城市  \
# 861        vivo    小行    弹性工作,试用期全薪，丰富年终奖         硬件 / 未融资 / 2000人以上  南京
# 862  卓尔智联集团有限公司   安德门      上市公司 500强 五险一金  移动互联网,电商 / 上市公司 / 2000人以上  南京
# 863        鼎捷软件  双龙大道        五险一金全，各项补充福利        其他 / 上市公司 / 2000人以上  南京
# 868       SHEIN   安德门  五险一金，绩效奖金，年终奖，节日福利    电商,移动互联网 / C轮 / 2000人以上  南京
#
#               岗位技能                工位要求      薪资                标题
# 861           数据分析  7k-10k 经验1-3年 / 本科  7k-10k            数据分析专员
# 862        电商 数据挖掘  6k-12k 经验1-3年 / 本科  6k-12k       HB-数据分析师-南京
# 863  数据分析 数据运营 数据库  7k-10k 经验1-3年 / 本科  7k-10k     数据分析工程师(帆软报表）
# 868      跨境电商 数据分析         经验1-3年 / 本科  经验1-3年  数据分析师 (MJ000443)

# %% [markdown]
# 所以从这里可以看出， 南京2000人以上的要求经验1-3年的数据分析师工资也就是7k-10k， 当然这里只是参考

# %%
df[df.薪资.map(lambda s: '经验' in s)]
# Out:
#         公司名称 公司地点                  公司短评                     公司级别  城市  \
# 868    SHEIN  安德门    五险一金，绩效奖金，年终奖，节日福利  电商,移动互联网 / C轮 / 2000人以上  南京
# 875   南京德胜智业  珠江路  年轻、提薪快、五险一金、不加班、做五休二   电商,消费生活 / 未融资 / 15-50人  南京
# 1624    字节跳动  洪山区     六险一金，餐补，带薪休假，扁平管理     文娱丨内容 / C轮 / 2000人以上  武汉
#
#                   岗位技能         工位要求      薪资                      标题
# 868          跨境电商 数据分析  经验1-3年 / 本科  经验1-3年        数据分析师 (MJ000443)
# 875   移动互联网 广告营销 策划 创意  经验1-3年 / 不限  经验1-3年  推广/SEO/数据分析/运营分析/策划/创意
# 1624              项目管理  经验3-5年 / 本科  经验3-5年             商业化-高级数据分析师

# %% [markdown]
# 把868行的薪资改为7k-10k

# %%
df.loc[868, '薪资'] = '7k-10k'

# %% [markdown]
# 以同样的方式处理其他行

# %%
df[(df.城市=='南京')&(df.公司级别.map(lambda s : '15-50人' in s))&df.工位要求.map(lambda s : '经验1-3年' in s)]
# Out:
#        公司名称 公司地点                  公司短评                         公司级别  城市  \
# 875  南京德胜智业  珠江路  年轻、提薪快、五险一金、不加班、做五休二       电商,消费生活 / 未融资 / 15-50人  南京
# 880   南京邮数通  山西路       项目奖金,带薪休年假,五险一金  移动互联网,信息安全 / 不需要融资 / 15-50人  南京
#
#                  岗位技能                工位要求      薪资                      标题
# 875  移动互联网 广告营销 策划 创意         经验1-3年 / 不限  经验1-3年  推广/SEO/数据分析/运营分析/策划/创意
# 880          大数据 数据挖掘  8k-15k 经验1-3年 / 本科  8k-15k              大数据分析开发工程师

# %%
df.loc[875, '薪资'] = '8k-15k'

# %%
df.loc[875, '薪资']
# Out:
# '8k-15k'

# %%
df[df.薪资.map(lambda s: '经验' in s)]
# Out:
#       公司名称 公司地点               公司短评                  公司级别  城市  岗位技能  \
# 1624  字节跳动  洪山区  六险一金，餐补，带薪休假，扁平管理  文娱丨内容 / C轮 / 2000人以上  武汉  项目管理
#
#              工位要求      薪资           标题
# 1624  经验3-5年 / 本科  经验3-5年  商业化-高级数据分析师

# %%
df[(df['城市']=='武汉')&(df.公司级别.map(lambda s : '2000人以上' in s))&df.工位要求.map(lambda s : '经验3-5年' in s)]
# Out:
#                   公司名称    公司地点                  公司短评  \
# 1597              字节跳动     洪山区  弹性工作，免费三餐，晋升空间，团队氛围好
# 1603              斗鱼直播      关山    下午茶；五险一金；弹性工作；前景好；
# 1610              字节跳动  东湖新技术…     六险一金，餐补，租房补贴，带薪休假
# 1612  时时同云科技（成都）有限责任公司     丁字桥             六险一金 阿里背景
# 1623        海康威视武汉研发中心      关山              六险一金；大平台
# 1624              字节跳动     洪山区     六险一金，餐补，带薪休假，扁平管理
# 1636              字节跳动     洪山区   六险一金、团队氛围好、餐补、扁平化管理
#
#                             公司级别  城市                    岗位技能  \
# 1597        文娱丨内容 / C轮 / 2000人以上  武汉                    数据分析
# 1603     文娱丨内容 / D轮及以上 / 2000人以上  武汉                      分析
# 1610        文娱丨内容 / C轮 / 2000人以上  武汉                    数据分析
# 1612   移动互联网,消费生活 / C轮 / 2000人以上  武汉          本地生活 数据分析 数据处理
# 1623  信息安全,数据服务 / 上市公司 / 2000人以上  武汉                     大数据
# 1624        文娱丨内容 / C轮 / 2000人以上  武汉                    项目管理
# 1636        文娱丨内容 / C轮 / 2000人以上  武汉  移动互联网 数据分析 行业分析 市场竞争分析
#
#                      工位要求       薪资           标题
# 1597  20k-40k 经验3-5年 / 本科  20k-40k        数据分析师
# 1603   8k-12k 经验3-5年 / 本科   8k-12k        数据分析师
# 1610  15k-30k 经验3-5年 / 本科  15k-30k   数据分析经理（光谷）
# 1612   8k-12k 经验3-5年 / 大专   8k-12k       数据分析主管
# 1623  10k-15k 经验3-5年 / 本科  10k-15k      数据分析工程师
# 1624          经验3-5年 / 本科   经验3-5年  商业化-高级数据分析师
# 1636   6k-12k 经验3-5年 / 本科   6k-12k  商业化-高级数据分析师

# %%
df.loc[1624, '薪资'] = '20k-40k'

# %% [markdown]
# 到这里薪资的异常值就处理完了

# %%
print(df.薪资.value_counts().index.tolist())
# Out:
# ['15k-25k', '15k-30k', '10k-20k', '20k-40k', '10k-15k', '8k-15k', '20k-30k', '15k-20k', '20k-35k', '25k-50k', '6k-8k', '12k-20k', '8k-12k', '8k-10k', '6k-10k', '25k-40k', '25k-35k', '10k-18k', '4k-6k', '8k-16k', '30k-50k', '18k-35k', '3k-5k', '12k-24k', '4k-8k', '7k-10k', '5k-10k', '6k-12k', '5k-8k', '2k-4k', '30k-40k', '18k-30k', '18k-25k', '13k-25k', '4k-7k', '12k-18k', '18k-36k', '25k-30k', '25k-45k', '13k-20k', '2k-3k', '30k-60k', '8k-13k', '7k-14k', '6k-9k', '15k-22k', '8k-14k', '3k-4k', '14k-20k', '9k-18k', '7k-12k', '4k-5k', '20k-25k', '5k-7k', '1k-2k', '5k-9k', '10k-13k', '7k-9k', '10k-16k', '11k-18k', '18k-28k', '12k-17k', '7k-13k', '17k-30k', '30k-45k', '16k-25k', '12k-16k', '9k-12k', '50k-80k', '10k-14k', '40k-70k', '12k-15k', '13k-26k', '13k-18k', '35k-45k', '11k-22k', '12k-22k', '14k-25k', '18k-32k', '50k-100k', '30k-55k', '10k-17k', '14k-28k', '5k-6k', '50k-70k', '19k-28k', '17k-34k', '16k-24k', '3k-6k', '15k-18k', '45k-60k', '17k-25k', '14k-24k', '20k-23k', '7k-8k', '9k-15k', '11k-16k', '40k-50k', '35k-60k', '14k-18k', '9k-11k', '20k-28k', '21k-35k', '28k-40k', '17k-23k', '6k-7k', '8k-11k', '11k-17k', '14k-22k', '16k-23k', '60k-100k', '40k-80k', '1k-1k', '60k-80k', '28k-55k', '16k-32k', '15k-27k', '20k-26k', '23k-46k', '9k-16k', '55k-80k', '13k-22k', '50k-65k', '11k-21k', '15k-26k', '13k-15k', '35k-50k', '21k-29k', '6k-11k', '28k-45k', '24k-25k', '40k-60k', '15k-28k', '11k-20k', '28k-38k', '26k-40k', '16k-30k', '21k-26k', '35k-55k', '9k-14k', '20K-40K', '15k-19k', '38k-65k', '30k-35k', '15k-24k', '20k-38k', '4K-5K', '25k-49k', '200k-300k', '17k-28k', '35k-70k', '35k-65k']

# %% [markdown]
# ### 拆分出 经验要求
# 位置放在薪资后面

# %%
df.head(2)
# Out:
#    公司名称 公司地点                  公司短评                  公司级别  城市           岗位技能  \
# 0    玩吧  东城区  七险一金,免费午餐,弹性不打卡,季度旅游    社交 / B轮 / 150-500人  北京  数据分析 SPSS SQL
# 1  和信集团  大望路             五险一金、周末双休  金融 / 不需要融资 / 2000人以上  北京           数据分析
#
#                   工位要求       薪资     标题
# 0  15k-25k 经验3-5年 / 本科  15k-25k  数据分析师
# 1    10k-20k 经验不限 / 本科  10k-20k  数据分析师

# %%
s = df.工位要求[0]
s
# Out:
# '15k-25k 经验3-5年 / 本科'

# %%
s.split()[1]
# Out:
# '经验3-5年'

# %%
df.工位要求.map(lambda s:s.split()[1])
# Out:
# 0        经验3-5年
# 1          经验不限
# 2        经验3-5年
# 3        经验3-5年
# 4        经验3-5年
#          ...
# 1669    经验5-10年
# 1670       经验不限
# 1671       经验不限
# 1672     经验3-5年
# 1673    经验应届毕业生
# Name: 工位要求, Length: 1590, dtype: object

# %%
df.insert(8, '经验要求', df.工位要求.map(lambda s:s.split()[1]))

# %%
df.head()
# Out:
#           公司名称 公司地点                  公司短评                          公司级别  城市  \
# 0           玩吧  东城区  七险一金,免费午餐,弹性不打卡,季度旅游            社交 / B轮 / 150-500人  北京
# 1         和信集团  大望路             五险一金、周末双休          金融 / 不需要融资 / 2000人以上  北京
# 2         水滴互助   望京    年底双薪,股票期权,扁平管理,晋升快  移动互联网,医疗丨健康 / B轮 / 500-2000人  北京
# 3          易企秀  西北旺  七险一金、零食水果、带薪年假、年度旅游等         移动互联网 / B轮 / 150-500人  北京
# 4  齐聚科技（原呱呱视频）  东城区  五险一金,弹性工作,餐补年终奖,节日福利      移动互联网,游戏 / C轮 / 150-500人  北京
#
#                 岗位技能                 工位要求       薪资    经验要求     标题
# 0      数据分析 SPSS SQL  15k-25k 经验3-5年 / 本科  15k-25k  经验3-5年  数据分析师
# 1               数据分析    10k-20k 经验不限 / 本科  10k-20k    经验不限  数据分析师
# 2    数据分析 MySQL Hive  15k-25k 经验3-5年 / 本科  15k-25k  经验3-5年  数据分析师
# 3      数据运营 SPSS SQL  15k-30k 经验3-5年 / 本科  15k-30k  经验3-5年   数据分析
# 4  游戏 社交 SQL 数据分析 商业  15k-20k 经验3-5年 / 大专  15k-20k  经验3-5年  数据分析师

# %%
# 查看经验要求的缺失值情况
df[df.经验要求.isna()]        # 经验要求这列没有缺失值
# Out:
# Empty DataFrame
# Columns: [公司名称, 公司地点, 公司短评, 公司级别, 城市, 岗位技能, 工位要求, 薪资, 经验要求, 标题]
# Index: []

# %%
# 查看经验要求这列的异常值情况
df.经验要求.value_counts()      # 有3个异常值/
# Out:
# 经验3-5年     655
# 经验1-3年     422
# 经验5-10年    240
# 经验不限       167
# 经验应届毕业生     68
# 经验1年以下      31
# 经验10年以上      4
# /            3
# Name: 经验要求, dtype: int64

# %%
# 提出经验要去异常值的行
df[df.经验要求=='/']       # 原因就是没有薪资造成的
# Out:
#         公司名称 公司地点                  公司短评                     公司级别  城市  \
# 868    SHEIN  安德门    五险一金，绩效奖金，年终奖，节日福利  电商,移动互联网 / C轮 / 2000人以上  南京
# 875   南京德胜智业  珠江路  年轻、提薪快、五险一金、不加班、做五休二   电商,消费生活 / 未融资 / 15-50人  南京
# 1624    字节跳动  洪山区     六险一金，餐补，带薪休假，扁平管理     文娱丨内容 / C轮 / 2000人以上  武汉
#
#                   岗位技能         工位要求       薪资 经验要求                      标题
# 868          跨境电商 数据分析  经验1-3年 / 本科   7k-10k    /        数据分析师 (MJ000443)
# 875   移动互联网 广告营销 策划 创意  经验1-3年 / 不限   8k-15k    /  推广/SEO/数据分析/运营分析/策划/创意
# 1624              项目管理  经验3-5年 / 本科  20k-40k    /             商业化-高级数据分析师

# %%
df.loc[[868, 875], '经验要求'] = '经验1-3年'

# %%
df.loc[[868, 875], '经验要求']
# Out:
# 868    经验1-3年
# 875    经验1-3年
# Name: 经验要求, dtype: object

# %%
df.loc[1624, '经验要求'] = '经验3-5年'

# %%
df.loc[1624, '经验要求']
# Out:
# '经验3-5年'

# %%
df.经验要求.value_counts()   # 经验要求不再有异常值
# Out:
# 经验3-5年     656
# 经验1-3年     424
# 经验5-10年    240
# 经验不限       167
# 经验应届毕业生     68
# 经验1年以下      31
# 经验10年以上      4
# Name: 经验要求, dtype: int64

# %% [markdown]
# ### 拆分出 学历要求
# 位置放到 经验要求 后面

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1590 entries, 0 to 1673
# Data columns (total 10 columns):
# 公司名称    1590 non-null object
# 公司地点    1590 non-null object
# 公司短评    1590 non-null object
# 公司级别    1590 non-null object
# 城市      1590 non-null object
# 岗位技能    1590 non-null object
# 工位要求    1590 non-null object
# 薪资      1590 non-null object
# 经验要求    1590 non-null object
# 标题      1590 non-null object
# dtypes: object(10)
# memory usage: 216.6+ KB

# %%
s = df.工位要求[0]
s
# Out:
# '15k-25k 经验3-5年 / 本科'

# %%
s.split()[-1]
# Out:
# '本科'

# %%
df.工位要求.map(lambda s : s.split()[-1])
# Out:
# 0       本科
# 1       本科
# 2       本科
# 3       本科
# 4       大专
#         ..
# 1669    不限
# 1670    大专
# 1671    大专
# 1672    本科
# 1673    本科
# Name: 工位要求, Length: 1590, dtype: object

# %%
df['学历要求'] = df.工位要求.map(lambda s : s.split()[-1])

# %%
# 查看学历要求的缺失值
df.学历要求.isna().sum()   # 没有缺失
# Out:
# 0

# %%
# 查看学历要求的异常值情况
df.学历要求.value_counts()   # 有一个异常值
# Out:
# 本科        1324
# 不限          99
# 大专          94
# 硕士          70
# 博士           2
# 经验3-5年       1
# Name: 学历要求, dtype: int64

# %%
df[df.学历要求=='经验3-5年']   # 该行没有学历
# Out:
#                  公司名称 公司地点                  公司短评  \
# 1628  烽火科技·虹旭信息技术有限公司  江夏区  班车,提供食宿,奖金,薪酬增长,沟通畅通
#
#                               公司级别  城市       岗位技能           工位要求      薪资  \
# 1628  信息安全,数据服务 / 不需要融资 / 150-500人  武汉  数据分析 数据运营  7k-14k 经验3-5年  7k-14k
#
#         经验要求     标题    学历要求
# 1628  经验3-5年  数据分析师  经验3-5年

# %% [markdown]
# 学历要求  明显是一个分类型变量， 给他改成一个众数

# %%
df.学历要求.mode()  # 查看学历要求的众数， 由于众数不止一个， 则返回一个Series对象
# Out:
# 0    本科
# dtype: object

# %%
df.loc[1628, '学历要求'] = '本科'

# %%
df.学历要求.value_counts()   # 这里处理完了异常值
# Out:
# 本科    1325
# 不限      99
# 大专      94
# 硕士      70
# 博士       2
# Name: 学历要求, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1590 entries, 0 to 1673
# Data columns (total 11 columns):
# 公司名称    1590 non-null object
# 公司地点    1590 non-null object
# 公司短评    1590 non-null object
# 公司级别    1590 non-null object
# 城市      1590 non-null object
# 岗位技能    1590 non-null object
# 工位要求    1590 non-null object
# 薪资      1590 non-null object
# 经验要求    1590 non-null object
# 标题      1590 non-null object
# 学历要求    1590 non-null object
# dtypes: object(11)
# memory usage: 229.1+ KB

# %% [markdown]
# ## 删除 工位要求 这一列

# %%
del df['工位要求']

# %%
df.head()
# Out:
#           公司名称 公司地点                  公司短评                          公司级别  城市  \
# 0           玩吧  东城区  七险一金,免费午餐,弹性不打卡,季度旅游            社交 / B轮 / 150-500人  北京
# 1         和信集团  大望路             五险一金、周末双休          金融 / 不需要融资 / 2000人以上  北京
# 2         水滴互助   望京    年底双薪,股票期权,扁平管理,晋升快  移动互联网,医疗丨健康 / B轮 / 500-2000人  北京
# 3          易企秀  西北旺  七险一金、零食水果、带薪年假、年度旅游等         移动互联网 / B轮 / 150-500人  北京
# 4  齐聚科技（原呱呱视频）  东城区  五险一金,弹性工作,餐补年终奖,节日福利      移动互联网,游戏 / C轮 / 150-500人  北京
#
#                 岗位技能       薪资    经验要求     标题 学历要求
# 0      数据分析 SPSS SQL  15k-25k  经验3-5年  数据分析师   本科
# 1               数据分析  10k-20k    经验不限  数据分析师   本科
# 2    数据分析 MySQL Hive  15k-25k  经验3-5年  数据分析师   本科
# 3      数据运营 SPSS SQL  15k-30k  经验3-5年   数据分析   本科
# 4  游戏 社交 SQL 数据分析 商业  15k-20k  经验3-5年  数据分析师   大专

# %% [markdown]
# ## 拆分 公司级别 成三列
# - 公司领域
# - 融资阶段
# - 公司规模

# %%
a = df.公司级别.str.split('/', expand=True)
a.columns = ['公司领域', '融资阶段', '公司规模']
a
# Out:
#               公司领域     融资阶段        公司规模
# 0              社交       B轮     150-500人
# 1              金融    不需要融资      2000人以上
# 2     移动互联网,医疗丨健康       B轮    500-2000人
# 3           移动互联网       B轮     150-500人
# 4        移动互联网,游戏       C轮     150-500人
# ...            ...      ...         ...
# 1669         企业服务     上市公司      2000人以上
# 1670           金融      未融资      50-150人
# 1671   移动互联网,人工智能     上市公司    500-2000人
# 1672        移动互联网    不需要融资      2000人以上
# 1673        移动互联网    不需要融资      2000人以上
#
# [1590 rows x 3 columns]

# %%
# 将上表拼接到df上
df = pd.concat([df, a], axis=1)

# %%
df.head()
# Out:
#           公司名称 公司地点                  公司短评                          公司级别  城市  \
# 0           玩吧  东城区  七险一金,免费午餐,弹性不打卡,季度旅游            社交 / B轮 / 150-500人  北京
# 1         和信集团  大望路             五险一金、周末双休          金融 / 不需要融资 / 2000人以上  北京
# 2         水滴互助   望京    年底双薪,股票期权,扁平管理,晋升快  移动互联网,医疗丨健康 / B轮 / 500-2000人  北京
# 3          易企秀  西北旺  七险一金、零食水果、带薪年假、年度旅游等         移动互联网 / B轮 / 150-500人  北京
# 4  齐聚科技（原呱呱视频）  东城区  五险一金,弹性工作,餐补年终奖,节日福利      移动互联网,游戏 / C轮 / 150-500人  北京
#
#                 岗位技能       薪资    经验要求     标题 学历要求          公司领域     融资阶段  \
# 0      数据分析 SPSS SQL  15k-25k  经验3-5年  数据分析师   本科           社交       B轮
# 1               数据分析  10k-20k    经验不限  数据分析师   本科           金融    不需要融资
# 2    数据分析 MySQL Hive  15k-25k  经验3-5年  数据分析师   本科  移动互联网,医疗丨健康       B轮
# 3      数据运营 SPSS SQL  15k-30k  经验3-5年   数据分析   本科        移动互联网       B轮
# 4  游戏 社交 SQL 数据分析 商业  15k-20k  经验3-5年  数据分析师   大专     移动互联网,游戏       C轮
#
#          公司规模
# 0    150-500人
# 1     2000人以上
# 2   500-2000人
# 3    150-500人
# 4    150-500人

# %%
# 查看缺失值情况
df.info()   # 没有缺失值
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1590 entries, 0 to 1673
# Data columns (total 13 columns):
# 公司名称    1590 non-null object
# 公司地点    1590 non-null object
# 公司短评    1590 non-null object
# 公司级别    1590 non-null object
# 城市      1590 non-null object
# 岗位技能    1590 non-null object
# 薪资      1590 non-null object
# 经验要求    1590 non-null object
# 标题      1590 non-null object
# 学历要求    1590 non-null object
# 公司领域    1590 non-null object
# 融资阶段    1590 non-null object
# 公司规模    1590 non-null object
# dtypes: object(13)
# memory usage: 253.9+ KB

# %%
# 查看 融资阶段有无异常值
df.融资阶段.value_counts()  # 融资阶段也没有异常值
# Out:
#  上市公司      392
#  不需要融资     370
#  D轮及以上     172
#  C轮        172
#  未融资       156
#  A轮        151
#  B轮        150
#  天使轮        27
# Name: 融资阶段, dtype: int64

# %%
# 查看公司规模有无异常值
df.公司规模.value_counts()   # 公司规模没有异常值
# Out:
#  2000人以上      577
#  150-500人     366
#  500-2000人    330
#  50-150人      205
#  15-50人        88
#  少于15人         24
# Name: 公司规模, dtype: int64

# %% [markdown]
# ## 删除 公司级别

# %%
df.head(2)
# Out:
#    公司名称 公司地点                  公司短评                  公司级别  城市           岗位技能  \
# 0    玩吧  东城区  七险一金,免费午餐,弹性不打卡,季度旅游    社交 / B轮 / 150-500人  北京  数据分析 SPSS SQL
# 1  和信集团  大望路             五险一金、周末双休  金融 / 不需要融资 / 2000人以上  北京           数据分析
#
#         薪资    经验要求     标题 学历要求 公司领域     融资阶段       公司规模
# 0  15k-25k  经验3-5年  数据分析师   本科  社交       B轮    150-500人
# 1  10k-20k    经验不限  数据分析师   本科  金融    不需要融资     2000人以上

# %%
del df['公司级别']

# %%
df
# Out:
#               公司名称   公司地点                  公司短评  城市  \
# 0               玩吧    东城区  七险一金,免费午餐,弹性不打卡,季度旅游  北京
# 1             和信集团    大望路             五险一金、周末双休  北京
# 2             水滴互助     望京    年底双薪,股票期权,扁平管理,晋升快  北京
# 3              易企秀    西北旺  七险一金、零食水果、带薪年假、年度旅游等  北京
# 4      齐聚科技（原呱呱视频）    东城区  五险一金,弹性工作,餐补年终奖,节日福利  北京
# ...            ...    ...                   ...  ..
# 1669          宇通客车  管城回族区           高薪、福利待遇、假期多  郑州
# 1670  河南千山教育科技有限公司    金水区        薪资待遇：8K~10K 双休  郑州
# 1671        缓冲网络科技    经开区              包住，发展前景大  郑州
# 1672    中移在线服务有限公司    高新区       海量数据 优质平台 发展空间大  郑州
# 1673    中移在线服务有限公司    高新区            六险两金、扁平化管理  郑州
#
#                               岗位技能       薪资     经验要求                标题 学历要求  \
# 0                    数据分析 SPSS SQL  15k-25k   经验3-5年             数据分析师   本科
# 1                             数据分析  10k-20k     经验不限             数据分析师   本科
# 2                  数据分析 MySQL Hive  15k-25k   经验3-5年             数据分析师   本科
# 3                    数据运营 SPSS SQL  15k-30k   经验3-5年              数据分析   本科
# 4                游戏 社交 SQL 数据分析 商业  15k-20k   经验3-5年             数据分析师   大专
# ...                            ...      ...      ...               ...  ...
# 1669                  BI SPSS 数据分析  30k-40k  经验5-10年            大数据分析师   不限
# 1670                    证券 股票 证券分析   6k-10k     经验不限           金融数据分析师   大专
# 1671  工具软件 移动互联网 数据挖掘 数据架构 数据仓库 算法    4k-6k     经验不限  大数据分析开发工程师助理/实习生   大专
# 1672                      数据分析 SQL  15k-25k   经验3-5年            大数据分析师   本科
# 1673  分类信息 大数据 数据挖掘 数据架构 数据仓库 数据分析  10k-20k  经验应届毕业生          政企大数据分析师   本科
#
#               公司领域     融资阶段        公司规模
# 0              社交       B轮     150-500人
# 1              金融    不需要融资      2000人以上
# 2     移动互联网,医疗丨健康       B轮    500-2000人
# 3           移动互联网       B轮     150-500人
# 4        移动互联网,游戏       C轮     150-500人
# ...            ...      ...         ...
# 1669         企业服务     上市公司      2000人以上
# 1670           金融      未融资      50-150人
# 1671   移动互联网,人工智能     上市公司    500-2000人
# 1672        移动互联网    不需要融资      2000人以上
# 1673        移动互联网    不需要融资      2000人以上
#
# [1590 rows x 12 columns]

# %% [markdown]
# 基本上到这里我们就处理好了， 接下来我们来析一下

# %%
df
# Out:
#               公司名称   公司地点                  公司短评  城市  \
# 0               玩吧    东城区  七险一金,免费午餐,弹性不打卡,季度旅游  北京
# 1             和信集团    大望路             五险一金、周末双休  北京
# 2             水滴互助     望京    年底双薪,股票期权,扁平管理,晋升快  北京
# 3              易企秀    西北旺  七险一金、零食水果、带薪年假、年度旅游等  北京
# 4      齐聚科技（原呱呱视频）    东城区  五险一金,弹性工作,餐补年终奖,节日福利  北京
# ...            ...    ...                   ...  ..
# 1669          宇通客车  管城回族区           高薪、福利待遇、假期多  郑州
# 1670  河南千山教育科技有限公司    金水区        薪资待遇：8K~10K 双休  郑州
# 1671        缓冲网络科技    经开区              包住，发展前景大  郑州
# 1672    中移在线服务有限公司    高新区       海量数据 优质平台 发展空间大  郑州
# 1673    中移在线服务有限公司    高新区            六险两金、扁平化管理  郑州
#
#                               岗位技能       薪资     经验要求                标题 学历要求  \
# 0                    数据分析 SPSS SQL  15k-25k   经验3-5年             数据分析师   本科
# 1                             数据分析  10k-20k     经验不限             数据分析师   本科
# 2                  数据分析 MySQL Hive  15k-25k   经验3-5年             数据分析师   本科
# 3                    数据运营 SPSS SQL  15k-30k   经验3-5年              数据分析   本科
# 4                游戏 社交 SQL 数据分析 商业  15k-20k   经验3-5年             数据分析师   大专
# ...                            ...      ...      ...               ...  ...
# 1669                  BI SPSS 数据分析  30k-40k  经验5-10年            大数据分析师   不限
# 1670                    证券 股票 证券分析   6k-10k     经验不限           金融数据分析师   大专
# 1671  工具软件 移动互联网 数据挖掘 数据架构 数据仓库 算法    4k-6k     经验不限  大数据分析开发工程师助理/实习生   大专
# 1672                      数据分析 SQL  15k-25k   经验3-5年            大数据分析师   本科
# 1673  分类信息 大数据 数据挖掘 数据架构 数据仓库 数据分析  10k-20k  经验应届毕业生          政企大数据分析师   本科
#
#               公司领域     融资阶段        公司规模
# 0              社交       B轮     150-500人
# 1              金融    不需要融资      2000人以上
# 2     移动互联网,医疗丨健康       B轮    500-2000人
# 3           移动互联网       B轮     150-500人
# 4        移动互联网,游戏       C轮     150-500人
# ...            ...      ...         ...
# 1669         企业服务     上市公司      2000人以上
# 1670           金融      未融资      50-150人
# 1671   移动互联网,人工智能     上市公司    500-2000人
# 1672        移动互联网    不需要融资      2000人以上
# 1673        移动互联网    不需要融资      2000人以上
#
# [1590 rows x 12 columns]

# %% [markdown]
# # 数据分析

# %% [markdown]
# ## 薪增一列 平均薪资
# 位置在薪资之后

# %%
import re

# %%
def slary(x):
    L = re.findall('\d+', x)
    return (float(L[0])+float(L[1]))*1000/2

# %%
df.薪资.map(slary)
# Out:
# 0       20000.0
# 1       15000.0
# 2       20000.0
# 3       22500.0
# 4       17500.0
#          ...
# 1669    35000.0
# 1670     8000.0
# 1671     5000.0
# 1672    20000.0
# 1673    15000.0
# Name: 薪资, Length: 1590, dtype: float64

# %%
df.insert(6, '平均薪资', df.薪资.map(slary))

# %%
df
# Out:
#               公司名称   公司地点                  公司短评  城市  \
# 0               玩吧    东城区  七险一金,免费午餐,弹性不打卡,季度旅游  北京
# 1             和信集团    大望路             五险一金、周末双休  北京
# 2             水滴互助     望京    年底双薪,股票期权,扁平管理,晋升快  北京
# 3              易企秀    西北旺  七险一金、零食水果、带薪年假、年度旅游等  北京
# 4      齐聚科技（原呱呱视频）    东城区  五险一金,弹性工作,餐补年终奖,节日福利  北京
# ...            ...    ...                   ...  ..
# 1669          宇通客车  管城回族区           高薪、福利待遇、假期多  郑州
# 1670  河南千山教育科技有限公司    金水区        薪资待遇：8K~10K 双休  郑州
# 1671        缓冲网络科技    经开区              包住，发展前景大  郑州
# 1672    中移在线服务有限公司    高新区       海量数据 优质平台 发展空间大  郑州
# 1673    中移在线服务有限公司    高新区            六险两金、扁平化管理  郑州
#
#                               岗位技能       薪资     平均薪资     经验要求  \
# 0                    数据分析 SPSS SQL  15k-25k  20000.0   经验3-5年
# 1                             数据分析  10k-20k  15000.0     经验不限
# 2                  数据分析 MySQL Hive  15k-25k  20000.0   经验3-5年
# 3                    数据运营 SPSS SQL  15k-30k  22500.0   经验3-5年
# 4                游戏 社交 SQL 数据分析 商业  15k-20k  17500.0   经验3-5年
# ...                            ...      ...      ...      ...
# 1669                  BI SPSS 数据分析  30k-40k  35000.0  经验5-10年
# 1670                    证券 股票 证券分析   6k-10k   8000.0     经验不限
# 1671  工具软件 移动互联网 数据挖掘 数据架构 数据仓库 算法    4k-6k   5000.0     经验不限
# 1672                      数据分析 SQL  15k-25k  20000.0   经验3-5年
# 1673  分类信息 大数据 数据挖掘 数据架构 数据仓库 数据分析  10k-20k  15000.0  经验应届毕业生
#
#                     标题 学历要求          公司领域     融资阶段        公司规模
# 0                数据分析师   本科           社交       B轮     150-500人
# 1                数据分析师   本科           金融    不需要融资      2000人以上
# 2                数据分析师   本科  移动互联网,医疗丨健康       B轮    500-2000人
# 3                 数据分析   本科        移动互联网       B轮     150-500人
# 4                数据分析师   大专     移动互联网,游戏       C轮     150-500人
# ...                ...  ...           ...      ...         ...
# 1669            大数据分析师   不限         企业服务     上市公司      2000人以上
# 1670           金融数据分析师   大专           金融      未融资      50-150人
# 1671  大数据分析开发工程师助理/实习生   大专   移动互联网,人工智能     上市公司    500-2000人
# 1672            大数据分析师   本科        移动互联网    不需要融资      2000人以上
# 1673          政企大数据分析师   本科        移动互联网    不需要融资      2000人以上
#
# [1590 rows x 13 columns]

# %% [markdown]
# ## 城市的平均薪资的关系

# %%
gp = df.groupby('城市')
gp

# %%
a = gp['平均薪资'].mean().sort_values(ascending=False)
a = a.map(lambda x:int(x))
a
# Out:
# 城市
# 北京    22702
# 杭州    20220
# 深圳    20026
# 上海    19538
# 佛山    18450
# 广州    15460
# 郑州    14888
# 南京    14888
# 苏州    14687
# 厦门    14392
# 武汉    14170
# 成都    11728
# 长沙    11125
# 重庆    10625
# 天津     8500
# 西安     6833
# Name: 平均薪资, dtype: int64

# %%
# 导入直方图的类
from pyecharts.charts import Bar

# 导入配置项类
from pyecharts import options as opts

# 导入背景主题类
from pyecharts.globals import ThemeType

# %%
# 实例化一个bar图对象
bar = Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
# 添加横轴的标签
bar.add_xaxis(list(a.index))
bar.add_yaxis(series_name = "各城市平均薪资直方图",  
              yaxis_data = a.values.tolist())   
bar.set_global_opts( title_opts= opts.TitleOpts(title = '各城市平均薪资直方图')
                    
                    ,xaxis_opts=opts.AxisOpts(axislabel_opts={'rotate':30}) )
                                               # 使刻度旋转30度，解决横轴显示不完全的问题

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="8548af901e7a44a1a7768791931d7d8c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_8548af901e7a44a1a7768791931d7d8c = echarts.init(
#                     document.getElementById('8548af901e7a44a1a7768791931d7d8c'), 'purple-passion', {renderer: 'canvas'});
#                 var option_8548af901e7a44a1a7768791931d7d8c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5404\u57ce\u5e02\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe",
#             "data": [
#                 22702,
#                 20220,
#                 20026,
#                 19538,
#                 18450,
#                 15460,
#                 14888,
#                 14888,
#                 14687,
#                 14392,
#                 14170,
#                 11728,
#                 11125,
#                 10625,
#                 8500,
#                 6833
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u57ce\u5e02\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#             ],
#             "selected": {
#                 "\u5404\u57ce\u5e02\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "rotate": 30
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac",
#                 "\u676d\u5dde",
#                 "\u6df1\u5733",
#                 "\u4e0a\u6d77",
#                 "\u4f5b\u5c71",
#                 "\u5e7f\u5dde",
#                 "\u90d1\u5dde",
#                 "\u5357\u4eac",
#                 "\u82cf\u5dde",
#                 "\u53a6\u95e8",
#                 "\u6b66\u6c49",
#                 "\u6210\u90fd",
#                 "\u957f\u6c99",
#                 "\u91cd\u5e86",
#                 "\u5929\u6d25",
#                 "\u897f\u5b89"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u57ce\u5e02\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#         }
#     ]
# };
#                 chart_8548af901e7a44a1a7768791931d7d8c.setOption(option_8548af901e7a44a1a7768791931d7d8c);
#         });
#     </script>

# %% [markdown]
# ## 将上诉平均薪资的分析过程封装成一个函数
# - 根据传入的列名的不同而进行分组
# - 计算该列名下不同类别的平均薪资的均值， 并按此进行降序输出, 如果类别太多， 只保留平均薪资的均值最高的前8个
# - 利用直方图画出上述结果

# %%
df.head(3)
# Out:
#    公司名称 公司地点                  公司短评  城市             岗位技能       薪资     平均薪资  \
# 0    玩吧  东城区  七险一金,免费午餐,弹性不打卡,季度旅游  北京    数据分析 SPSS SQL  15k-25k  20000.0
# 1  和信集团  大望路             五险一金、周末双休  北京             数据分析  10k-20k  15000.0
# 2  水滴互助   望京    年底双薪,股票期权,扁平管理,晋升快  北京  数据分析 MySQL Hive  15k-25k  20000.0
#
#      经验要求     标题 学历要求          公司领域     融资阶段        公司规模
# 0  经验3-5年  数据分析师   本科           社交       B轮     150-500人
# 1    经验不限  数据分析师   本科           金融    不需要融资      2000人以上
# 2  经验3-5年  数据分析师   本科  移动互联网,医疗丨健康       B轮    500-2000人

# %%
def bar(c):  
    gp = df.groupby(c)
    a = gp['平均薪资'].mean().sort_values(ascending=False)
    a = a.map(lambda x:int(x))
    if len(a)<=8:
        a = a
    else:
        a = a[0:8]
    # 实例化一个bar图对象
    bar = Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
    # 添加横轴的标签
    bar.add_xaxis(list(a.index))
    bar.add_yaxis(series_name = "各{}与平均薪资直方图".format(c),  
                  yaxis_data = a.values.tolist())   
    bar.set_global_opts( title_opts= opts.TitleOpts(title =  "各{}与平均薪资直方图".format(c))
                        ,xaxis_opts=opts.AxisOpts(axislabel_opts={'rotate':30}) )
    
    return bar.render_notebook()

# %% [markdown]
# ## 学历与平均薪资的关系

# %%
df.head(2)
# Out:
#    公司名称 公司地点                  公司短评  城市           岗位技能       薪资     平均薪资  \
# 0    玩吧  东城区  七险一金,免费午餐,弹性不打卡,季度旅游  北京  数据分析 SPSS SQL  15k-25k  20000.0
# 1  和信集团  大望路             五险一金、周末双休  北京           数据分析  10k-20k  15000.0
#
#      经验要求     标题 学历要求 公司领域     融资阶段       公司规模
# 0  经验3-5年  数据分析师   本科  社交       B轮    150-500人
# 1    经验不限  数据分析师   本科  金融    不需要融资     2000人以上

# %%
bar('学历要求')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="6aaa6ba5217f4147bfe1029a4733bee5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_6aaa6ba5217f4147bfe1029a4733bee5 = echarts.init(
#                     document.getElementById('6aaa6ba5217f4147bfe1029a4733bee5'), 'purple-passion', {renderer: 'canvas'});
#                 var option_6aaa6ba5217f4147bfe1029a4733bee5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5404\u5b66\u5386\u8981\u6c42\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe",
#             "data": [
#                 40750,
#                 21750,
#                 19916,
#                 17449,
#                 10228
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u5b66\u5386\u8981\u6c42\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#             ],
#             "selected": {
#                 "\u5404\u5b66\u5386\u8981\u6c42\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "rotate": 30
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u535a\u58eb",
#                 "\u7855\u58eb",
#                 "\u672c\u79d1",
#                 "\u4e0d\u9650",
#                 "\u5927\u4e13"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u5b66\u5386\u8981\u6c42\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#         }
#     ]
# };
#                 chart_6aaa6ba5217f4147bfe1029a4733bee5.setOption(option_6aaa6ba5217f4147bfe1029a4733bee5);
#         });
#     </script>

# %% [markdown]
# ## 公司领域与平均薪资的关系

# %%
df.columns
# Out:
# Index(['公司名称', '公司地点', '公司短评', '城市', '岗位技能', '薪资', '平均薪资', '经验要求', '标题',
#        '学历要求', '公司领域', '融资阶段', '公司规模'],
#       dtype='object')

# %%
bar('公司领域')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="6f43b5b24c1b47039d18a6ccc2a0f2de" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_6f43b5b24c1b47039d18a6ccc2a0f2de = echarts.init(
#                     document.getElementById('6f43b5b24c1b47039d18a6ccc2a0f2de'), 'purple-passion', {renderer: 'canvas'});
#                 var option_6f43b5b24c1b47039d18a6ccc2a0f2de = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5404\u516c\u53f8\u9886\u57df\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe",
#             "data": [
#                 53750,
#                 35000,
#                 30000,
#                 28621,
#                 27916,
#                 27534,
#                 27500,
#                 26625
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u516c\u53f8\u9886\u57df\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#             ],
#             "selected": {
#                 "\u5404\u516c\u53f8\u9886\u57df\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "rotate": 30
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u65c5\u6e38,\u6587\u5a31\u4e28\u5185\u5bb9 ",
#                 "\u91d1\u878d,\u4e0d\u9650 ",
#                 "\u91d1\u878d,\u7535\u5546 ",
#                 "\u786c\u4ef6 ",
#                 "\u6570\u636e\u670d\u52a1,\u5e7f\u544a\u8425\u9500 ",
#                 "\u6559\u80b2 ",
#                 "\u91d1\u878d,\u533b\u7597\u4e28\u5065\u5eb7 ",
#                 "\u5e7f\u544a\u8425\u9500 "
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u516c\u53f8\u9886\u57df\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#         }
#     ]
# };
#                 chart_6f43b5b24c1b47039d18a6ccc2a0f2de.setOption(option_6f43b5b24c1b47039d18a6ccc2a0f2de);
#         });
#     </script>

# %% [markdown]
# ## 融资阶段与平均薪资的关系

# %%
df.columns
# Out:
# Index(['公司名称', '公司地点', '公司短评', '城市', '岗位技能', '薪资', '平均薪资', '经验要求', '标题',
#        '学历要求', '公司领域', '融资阶段', '公司规模'],
#       dtype='object')

# %%
bar('融资阶段')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="ba151ea7344c46e8aed7b95e27cd8d32" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_ba151ea7344c46e8aed7b95e27cd8d32 = echarts.init(
#                     document.getElementById('ba151ea7344c46e8aed7b95e27cd8d32'), 'purple-passion', {renderer: 'canvas'});
#                 var option_ba151ea7344c46e8aed7b95e27cd8d32 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5404\u878d\u8d44\u9636\u6bb5\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe",
#             "data": [
#                 22176,
#                 22136,
#                 20191,
#                 19503,
#                 17331,
#                 16655,
#                 15944,
#                 15544
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u878d\u8d44\u9636\u6bb5\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#             ],
#             "selected": {
#                 "\u5404\u878d\u8d44\u9636\u6bb5\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "rotate": 30
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 " \u4e0a\u5e02\u516c\u53f8 ",
#                 " D\u8f6e\u53ca\u4ee5\u4e0a ",
#                 " C\u8f6e ",
#                 " B\u8f6e ",
#                 " \u4e0d\u9700\u8981\u878d\u8d44 ",
#                 " A\u8f6e ",
#                 " \u5929\u4f7f\u8f6e ",
#                 " \u672a\u878d\u8d44 "
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u878d\u8d44\u9636\u6bb5\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#         }
#     ]
# };
#                 chart_ba151ea7344c46e8aed7b95e27cd8d32.setOption(option_ba151ea7344c46e8aed7b95e27cd8d32);
#         });
#     </script>

# %% [markdown]
# ## 公司规模与平均薪资的关系

# %%
df.columns
# Out:
# Index(['公司名称', '公司地点', '公司短评', '城市', '岗位技能', '薪资', '平均薪资', '经验要求', '标题',
#        '学历要求', '公司领域', '融资阶段', '公司规模'],
#       dtype='object')

# %%
bar('公司规模')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="df562c489cd449daada9bd69b3af613b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_df562c489cd449daada9bd69b3af613b = echarts.init(
#                     document.getElementById('df562c489cd449daada9bd69b3af613b'), 'purple-passion', {renderer: 'canvas'});
#                 var option_df562c489cd449daada9bd69b3af613b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5404\u516c\u53f8\u89c4\u6a21\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe",
#             "data": [
#                 22475,
#                 18643,
#                 18151,
#                 17121,
#                 12687,
#                 12125
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u516c\u53f8\u89c4\u6a21\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#             ],
#             "selected": {
#                 "\u5404\u516c\u53f8\u89c4\u6a21\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "rotate": 30
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 " 2000\u4eba\u4ee5\u4e0a",
#                 " 500-2000\u4eba",
#                 " 150-500\u4eba",
#                 " 50-150\u4eba",
#                 " 15-50\u4eba",
#                 " \u5c11\u4e8e15\u4eba"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u516c\u53f8\u89c4\u6a21\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#         }
#     ]
# };
#                 chart_df562c489cd449daada9bd69b3af613b.setOption(option_df562c489cd449daada9bd69b3af613b);
#         });
#     </script>

# %% [markdown]
# ## 经验要求与平均薪资的关系

# %%
df.columns
# Out:
# Index(['公司名称', '公司地点', '公司短评', '城市', '岗位技能', '薪资', '平均薪资', '经验要求', '标题',
#        '学历要求', '公司领域', '融资阶段', '公司规模'],
#       dtype='object')

# %%
bar('经验要求')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="39c1fc73a59845409af87bc1c61b4a6f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_39c1fc73a59845409af87bc1c61b4a6f = echarts.init(
#                     document.getElementById('39c1fc73a59845409af87bc1c61b4a6f'), 'purple-passion', {renderer: 'canvas'});
#                 var option_39c1fc73a59845409af87bc1c61b4a6f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5404\u7ecf\u9a8c\u8981\u6c42\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe",
#             "data": [
#                 50000,
#                 29783,
#                 21174,
#                 15955,
#                 14128,
#                 8290,
#                 7816
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u7ecf\u9a8c\u8981\u6c42\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#             ],
#             "selected": {
#                 "\u5404\u7ecf\u9a8c\u8981\u6c42\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "rotate": 30
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7ecf\u9a8c10\u5e74\u4ee5\u4e0a",
#                 "\u7ecf\u9a8c5-10\u5e74",
#                 "\u7ecf\u9a8c3-5\u5e74",
#                 "\u7ecf\u9a8c\u4e0d\u9650",
#                 "\u7ecf\u9a8c1-3\u5e74",
#                 "\u7ecf\u9a8c1\u5e74\u4ee5\u4e0b",
#                 "\u7ecf\u9a8c\u5e94\u5c4a\u6bd5\u4e1a\u751f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u7ecf\u9a8c\u8981\u6c42\u4e0e\u5e73\u5747\u85aa\u8d44\u76f4\u65b9\u56fe"
#         }
#     ]
# };
#                 chart_39c1fc73a59845409af87bc1c61b4a6f.setOption(option_39c1fc73a59845409af87bc1c61b4a6f);
#         });
#     </script>

# %% [markdown]
# ## 利用饼图分析数据分析职位岗位技能占比
# 统计技能需求里面一些关键字出现的次数， 比如Excel BI SPSS SQL Python 机器学习 数据挖掘 算法等出现的次数，
# 画出相对应的技能所占的饼图百分比。
# 统计规则如下:
# - 1 统计 数据库 ， 凡是出现 数据库 SQL Oracle MongoDB都算是数据库的
# - 2 统计 Python，  凡是出现 Python 数据挖掘 机器学习 算法 都算是Python的
# - 3 统计 BI
# - 4 统计 SPSS
# - 5 统计 Hive

# %%
a = df.岗位技能.str.split()
a
# Out:
# 0                         [数据分析, SPSS, SQL]
# 1                                    [数据分析]
# 2                       [数据分析, MySQL, Hive]
# 3                         [数据运营, SPSS, SQL]
# 4                   [游戏, 社交, SQL, 数据分析, 商业]
#                        ...
# 1669                       [BI, SPSS, 数据分析]
# 1670                         [证券, 股票, 证券分析]
# 1671    [工具软件, 移动互联网, 数据挖掘, 数据架构, 数据仓库, 算法]
# 1672                            [数据分析, SQL]
# 1673    [分类信息, 大数据, 数据挖掘, 数据架构, 数据仓库, 数据分析]
# Name: 岗位技能, Length: 1590, dtype: object

# %%
L = []
for i in a:
    L += i
s = ' '.join(L)
s
# Out:
# '数据分析 SPSS SQL 数据分析 数据分析 MySQL Hive 数据运营 SPSS SQL 游戏 社交 SQL 数据分析 商业 数据分析 数据运营 SQL 电商 新零售 Hive MySQL 数据处理 数据分析 电商 广告营销 增长黑客 SQL 商业 数据分析 数据运营 数据分析 教育 运营 数据分析 效果跟踪 MySQL SQLServer 数据分析 云计算 大数据 数据分析 SPSS SQL 数据分析 电商 新零售 运营 产品运营 用户运营 电商运营 移动互联网 需求分析 数据分析 数据分析 教育 数据分析 数据分析 数据分析 算法 数据挖掘 大数据 商业 数据分析 云计算 大数据 数据分析 数据库 数据分析 数据分析 数据分析 数据运营 SQL BI BI 数据分析 电商 产品设计 产品策划 需求分析 数据分析 移动互联网 数据分析 数据分析 移动互联网 数据分析 行业分析 数据分析 企业服务 房产服务 BI 数据库 数据分析 数据运营 SQL BI 商业 MySQL 数据分析 电商 汽车 商业 SQL SPSS 数据分析 数据分析 MySQL SQLServer 大数据 数据分析 商业 数据分析 SPSS SQL 商业 SQL 数据分析 数据分析 大数据 金融 数据分析 商业 数据分析 游戏 数据分析 商业 可视化 数据分析 金融 SQL 数据库 数据分析 数据运营 互联网金融 数据分析 SQL 教育 移动互联网 数据分析 用户增长 电商 SQL 数据分析 BI SQL 数据分析 商业 社交 移动互联网 数据分析 策略 用户研究 教育 SQL ETL 数据仓库 数据分析 SQLServer 移动互联网 增长黑客 数据分析 商业 数据运营 移动互联网 可视化 数据运营 SPSS SQL 直播 数据库 SQL 大数据 数据分析 数据分析 SQL 移动互联网 教育 数据分析 大数据 金融 Hadoop 算法 数据挖掘 数据分析 SQL SPSS 电商 新零售 数据分析 数据运营 数据分析 数据库 SQL 可视化 本地生活 数据分析 数据运营 SQL BI 可视化 数据分析 商业 SQL 数据分析 数据分析 SQL 视频 工具软件 数据分析 数据运营 SQL 商业 大数据 数据挖掘 数据分析 教育 移动互联网 数据分析 BI 可视化 SQL 数据库 SQL 数据分析 BI SQL 数据库 大数据 数据挖掘 数据分析 项目管理 数据分析 大数据 征信 数据分析 新零售 数据分析 汽车 大数据 数据挖掘 数据分析 教育 BI 数据分析 电商 新零售 数据仓库 数据分析 数据处理 数据分析 BI 增长黑客 数据分析 SQL 数据库 数据分析 SQL BI 可视化 数据分析 BI SQL 数据库 医疗健康 大数据 互联网金融 MySQL 数据分析 数据分析 数据挖掘 算法 数据分析 SQL 数据库 移动互联网 BI SQL 数据库 数据分析 移动互联网 数据分析 广告营销 移动互联网 数据分析 SQL 运营 BI 数据分析 金融 移动互联网 SPSS 数据分析 SQL 商业 大数据 数据分析 BI 数据分析 SQL 算法 搜索 数据挖掘 数据分析 旅游 数据分析 SPSS 商业 BI 数据分析 数据运营 大数据 数据分析 数据分析 数据挖掘 数据分析 商业 BI 数据分析 数据挖掘 数据分析 数据挖掘 数据仓库 大数据 数据分析 SPSS 数据分析 数据分析 SQL 金融 数据分析 移动互联网 电商 旅游 BI 产品经理 数据分析 汽车 数据分析 电商 商业 BI BI SQL SPSS 商业 数据分析 数据库 SQL 可视化 数据分析 增长黑客 视频 直播 数据分析 数据分析 数据分析 SQL 数据分析 数据运营 MySQL Scala 数据分析 金融 大数据 数据挖掘 BI 数据分析 数据分析 分析师 互联网金融 MySQL 教育 决策能力 业务流程管理 数据分析 移动互联网 金融 数据分析 数据运营 SQL 互联网金融 银行 节日礼物 技能培训 年度旅游 岗位晋升 数据分析 互联网金融 数据分析 数据分析 数据分析 数据分析 SQL 商业 数据库 产品 大数据 SQL 数据分析 商业 大数据 SQLServer Hive 数据分析 商业 可视化 数据分析 数据分析 房产服务 BI 数据分析 商业 移动互联网 数据分析 企业服务 移动互联网 数据分析 数据运营 数据库 SQL 数据分析 SQL 数据库 金融 NLP 算法 数据分析 医疗健康 大数据 数据分析 BI 数据运营 数据库 电商 大数据 数据分析 SPSS 数据分析 SPSS BI 可视化 数据分析 移动互联网 SQL 可视化 数据分析 数据分析 数据分析 增长黑客 数据分析 数据运营 商业 数据分析 MySQL 教育 算法 数据挖掘 数据分析 ETL MySQL 数据分析 数据处理 互联网金融 数据分析 数据分析 商业 数据分析 SPSS SQL 广告营销 大数据 商业 数据分析 SPSS 数据分析 数据分析 SQL 数据库 数据分析 数据分析 数据分析 互联网金融 借贷 数据分析 数据运营 电商 商业 BI 数据分析 SQL 数据分析 教育 数据分析 SQL 大数据 商业 BI 可视化 数据分析 大数据 金融 SQL 数据分析 大数据 数据分析 可视化 BI 商业 数据分析 互联网金融 借贷 数据分析 数据运营 数据运营 增长黑客 数据分析 Hive MySQL Oracle 电商 数据 大数据 数据运营 电商 SQL 互联网金融 Oracle 数据分析 Hive 游戏 数据分析 数据运营 大数据 数据分析 互联网金融 借贷 数据分析 MySQL Spark 电商 SQL 数据分析 数据运营 数据库 后端 音频处理 软件开发 滴滴 本地生活 移动互联网 BI 数据分析 数据运营 大数据 金融 数据挖掘 数据分析 数据分析 数据分析 数据分析 SQL 互联网金融 理财 BI 数据分析 数据库 大数据 金融 BI 数据分析 电商 数据分析 BI SQL 数据库 BI 数据分析 数据分析 风控 分析师 数据分析 SQL 数据分析 数据分析 大数据 数据分析 SQL 移动互联网 企业服务 数据分析 数据运营 SQL 数据库 数据分析 hadoop 大数据 数据挖掘 数据分析 数据分析 金融 数据分析 数据运营 医疗健康 大数据 数据分析 BI 移动互联网 数据分析 SQL 大数据 数据分析 数据分析 移动互联网 数据分析 Hive 数据处理 数据挖掘 电商 数据分析 数据分析 数据处理 移动互联网 数据分析 数据运营 数据挖掘 数据分析 Spark 电商 数据分析 SPSS BI SQL 产品经理 大数据 数据挖掘 数据分析 金融 数据挖掘 数据分析 Hive 数据分析 数据分析 数据运营 数据库 BI 数据分析 SQL 数据库 数据分析 大数据 旅游 数据挖掘 数据分析 数据处理 算法 SQL 增长黑客 数据分析 大数据 数据分析 数据分析 数据运营 SQL 数据库 电商 数据分析 数据分析 教育 产品 SQL SPSS SQL SPSS 数据运营 数据分析 大数据 房产服务 数据分析 MySQL 数据分析 数据分析 互联网金融 数据分析 数据分析 数据挖掘 SQL 商业 借贷 数据分析 数据处理 数据分析 MySQL SQLServer 滴滴 教育 BI SQL 商业 数据运营 数据分析 移动互联网 视频 数据分析 数据分析 数据架构 数据挖掘 数据分析 SQL 电商 新零售 SQL 数据分析 数据运营 大数据 旅游 数据仓库 数据分析 数据处理 Hive 互联网金融 电商 Hive Hadoop 数据分析 医疗健康 移动互联网 数据分析 SQLServer 借贷 数据分析 SQL 数据库 运营 APP推广 大数据 数据分析 数据分析 MySQL Hive 数据分析 SQL 教育 移动互联网 数据分析 商业 BI 数据运营 大数据 金融 数据分析 数据运营 SQL 数据分析 新零售 汽车 BI 可视化 数据分析 SQL 行业研究 分析师 游戏 大数据 数据分析 数据分析 效果跟踪 新媒体运营 数据分析 电商 数据分析 数据分析 保险 Hadoop ETL Hive 数据分析 数据分析 金融 数据分析 数据处理 数据分析 算法 电商 数据分析 SPSS 电商 可视化 商业 数据分析 BI 产品 数据分析 滴滴 数据分析 教育 数据分析 SPSS SQL 大数据 移动互联网 市场分析 数据分析 行业分析 市场 数据分析 电商 移动互联网 可视化 数据分析 数据运营 增长黑客 数据分析 数据运营 SQL 数据库 数据分析 BI 数据分析 大数据 数据分析 电商 ETL 数据分析 地图 大数据 审核 大数据 教育 滴滴 数据挖掘 数据仓库 数据分析 Hadoop BI 可视化 数据分析 数据运营 数据分析 大数据 数据分析 数据库 增长黑客 商业 数据运营 数据分析 商业 BI 数据分析 SQL 大数据 数据挖掘 数据分析 可视化 数据分析 SPSS 数据库 大数据 汽车 Java 数据挖掘 数据处理 算法 产品 滴滴 电商 SQL 数据分析 本地生活 房产服务 数据库 SQL 数据分析 大数据 商业 数据分析 游戏 数据分析 数据运营 汽车 地图 电商 商业 教育 MySQL 数据分析 数据分析 电商 SQLServer 数据分析 数据分析 游戏 数据分析 数据分析 汽车 Hive 数据分析 ...

# %%
L = ['数据库', 'SQL', 'Oracle', 'MongoDB', 'Python', '数据挖掘', '机器学习', '算法', 'BI', 'SPSS', 'Hive' ]
print(L)
# Out:
# ['数据库', 'SQL', 'Oracle', 'MongoDB', 'Python', '数据挖掘', '机器学习', '算法', 'BI', 'SPSS', 'Hive']

# %%
L2 = []
for i in L:
    L2.append((i, s.count(i)))
a = pd.DataFrame(L2)
a
# Out:
#           0    1
# 0       数据库  132
# 1       SQL  387
# 2    Oracle   13
# 3   MongoDB    2
# 4    Python    2
# 5      数据挖掘  158
# 6      机器学习    5
# 7        算法   40
# 8        BI  153
# 9      SPSS   84
# 10     Hive   39

# %%
# 数据库 
a[0:4].loc[:, 1].sum()
# Out:
# 534

# %%
# python  
a[4:8].loc[:, 1].sum()
# Out:
# 205

# %%
# BI  
a[8:9]
# Out:
#     0    1
# 8  BI  153

# %%
# spss
a[9:10]
# Out:
#       0   1
# 9  SPSS  84

# %%
# Hive
a[10:]
# Out:
#        0   1
# 10  Hive  39

# %%
a = pd.Series([534, 205, 153, 84, 39], ['数据库', 'Python', 'BI', 'SPSS', 'Hive'])
a
# Out:
# 数据库       534
# Python    205
# BI        153
# SPSS       84
# Hive       39
# dtype: int64

# %%
# 导入饼图类
from pyecharts.charts import Pie
def pie(a):
    # 实例化饼图对象
    pie = Pie(init_opts=opts.InitOpts(theme=ThemeType.MACARONS))
    pie.add(series_name = "数据分析各技能占比",
            data_pair = list(zip(a.index, a.values.tolist())))
    # 全局配置项

    pie.set_global_opts(title_opts= opts.TitleOpts(title = "数据分析各技能占比"),
                        # 使得图例垂直
                        legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%"))

    # 系列配置项        
                         # 系列配置项下的标签配置项
    pie.set_series_opts(label_opts= opts.LabelOpts(is_show = True, 
                                                   # formatter="{a}{b}{c}{d}"对应显示
                                                   #{a}（系列名称），{b}（数据项名称），{c}（数值）, {d}（百分比）
                                                   formatter="{b}:{c} \n{d}%"
                                                  ), 
                        position='right')  
    return pie.render_notebook()

# %%
pie(a)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#         <div id="5c0f9b61dcfc4fbd87e99b50f9df0131" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'macarons'], function(echarts) {
#                 var chart_5c0f9b61dcfc4fbd87e99b50f9df0131 = echarts.init(
#                     document.getElementById('5c0f9b61dcfc4fbd87e99b50f9df0131'), 'macarons', {renderer: 'canvas'});
#                 var option_5c0f9b61dcfc4fbd87e99b50f9df0131 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u6570\u636e\u5206\u6790\u5404\u6280\u80fd\u5360\u6bd4",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6570\u636e\u5e93",
#                     "value": 534
#                 },
#                 {
#                     "name": "Python",
#                     "value": 205
#                 },
#                 {
#                     "name": "BI",
#                     "value": 153
#                 },
#                 {
#                     "name": "SPSS",
#                     "value": 84
#                 },
#                 {
#                     "name": "Hive",
#                     "value": 39
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}:{c} \n{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "position": "right"
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u636e\u5e93",
#                 "Python",
#                 "BI",
#                 "SPSS",
#                 "Hive"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6570\u636e\u5206\u6790\u5404\u6280\u80fd\u5360\u6bd4"
#         }
#     ]
# };
#                 chart_5c0f9b61dcfc4fbd87e99b50f9df0131.setOption(option_5c0f9b61dcfc4fbd87e99b50f9df0131);
#         });
#     </script>

# %% [markdown]
# ## 数据分析技能词云图

# %%
a = df.岗位技能.str.split()
a
# Out:
# 0                         [数据分析, SPSS, SQL]
# 1                                    [数据分析]
# 2                       [数据分析, MySQL, Hive]
# 3                         [数据运营, SPSS, SQL]
# 4                   [游戏, 社交, SQL, 数据分析, 商业]
#                        ...
# 1669                       [BI, SPSS, 数据分析]
# 1670                         [证券, 股票, 证券分析]
# 1671    [工具软件, 移动互联网, 数据挖掘, 数据架构, 数据仓库, 算法]
# 1672                            [数据分析, SQL]
# 1673    [分类信息, 大数据, 数据挖掘, 数据架构, 数据仓库, 数据分析]
# Name: 岗位技能, Length: 1590, dtype: object

# %%
L = []
for i in a:
    L += i
s = ' '.join(L)
s = s.split()
s
# Out:
# ['数据分析',
#  'SPSS',
#  'SQL',
#  '数据分析',
#  '数据分析',
#  'MySQL',
#  'Hive',
#  '数据运营',
#  'SPSS',
#  'SQL',
#  '游戏',
#  '社交',
#  'SQL',
#  '数据分析',
#  '商业',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  '电商',
#  '新零售',
#  'Hive',
#  'MySQL',
#  '数据处理',
#  '数据分析',
#  '电商',
#  '广告营销',
#  '增长黑客',
#  'SQL',
#  '商业',
#  '数据分析',
#  '数据运营',
#  '数据分析',
#  '教育',
#  '运营',
#  '数据分析',
#  '效果跟踪',
#  'MySQL',
#  'SQLServer',
#  '数据分析',
#  '云计算',
#  '大数据',
#  '数据分析',
#  'SPSS',
#  'SQL',
#  '数据分析',
#  '电商',
#  '新零售',
#  '运营',
#  '产品运营',
#  '用户运营',
#  '电商运营',
#  '移动互联网',
#  '需求分析',
#  '数据分析',
#  '数据分析',
#  '教育',
#  '数据分析',
#  '数据分析',
#  '数据分析',
#  '算法',
#  '数据挖掘',
#  '大数据',
#  '商业',
#  '数据分析',
#  '云计算',
#  '大数据',
#  '数据分析',
#  '数据库',
#  '数据分析',
#  '数据分析',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  'BI',
#  'BI',
#  '数据分析',
#  '电商',
#  '产品设计',
#  '产品策划',
#  '需求分析',
#  '数据分析',
#  '移动互联网',
#  '数据分析',
#  '数据分析',
#  '移动互联网',
#  '数据分析',
#  '行业分析',
#  '数据分析',
#  '企业服务',
#  '房产服务',
#  'BI',
#  '数据库',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  'BI',
#  '商业',
#  'MySQL',
#  '数据分析',
#  '电商',
#  '汽车',
#  '商业',
#  'SQL',
#  'SPSS',
#  '数据分析',
#  '数据分析',
#  'MySQL',
#  'SQLServer',
#  '大数据',
#  '数据分析',
#  '商业',
#  '数据分析',
#  'SPSS',
#  'SQL',
#  '商业',
#  'SQL',
#  '数据分析',
#  '数据分析',
#  '大数据',
#  '金融',
#  '数据分析',
#  '商业',
#  '数据分析',
#  '游戏',
#  '数据分析',
#  '商业',
#  '可视化',
#  '数据分析',
#  '金融',
#  'SQL',
#  '数据库',
#  '数据分析',
#  '数据运营',
#  '互联网金融',
#  '数据分析',
#  'SQL',
#  '教育',
#  '移动互联网',
#  '数据分析',
#  '用户增长',
#  '电商',
#  'SQL',
#  '数据分析',
#  'BI',
#  'SQL',
#  '数据分析',
#  '商业',
#  '社交',
#  '移动互联网',
#  '数据分析',
#  '策略',
#  '用户研究',
#  '教育',
#  'SQL',
#  'ETL',
#  '数据仓库',
#  '数据分析',
#  'SQLServer',
#  '移动互联网',
#  '增长黑客',
#  '数据分析',
#  '商业',
#  '数据运营',
#  '移动互联网',
#  '可视化',
#  '数据运营',
#  'SPSS',
#  'SQL',
#  '直播',
#  '数据库',
#  'SQL',
#  '大数据',
#  '数据分析',
#  '数据分析',
#  'SQL',
#  '移动互联网',
#  '教育',
#  '数据分析',
#  '大数据',
#  '金融',
#  'Hadoop',
#  '算法',
#  '数据挖掘',
#  '数据分析',
#  'SQL',
#  'SPSS',
#  '电商',
#  '新零售',
#  '数据分析',
#  '数据运营',
#  '数据分析',
#  '数据库',
#  'SQL',
#  '可视化',
#  '本地生活',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  'BI',
#  '可视化',
#  '数据分析',
#  '商业',
#  'SQL',
#  '数据分析',
#  '数据分析',
#  'SQL',
#  '视频',
#  '工具软件',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  '商业',
#  '大数据',
#  '数据挖掘',
#  '数据分析',
#  '教育',
#  '移动互联网',
#  '数据分析',
#  'BI',
#  '可视化',
#  'SQL',
#  '数据库',
#  'SQL',
#  '数据分析',
#  'BI',
#  'SQL',
#  '数据库',
#  '大数据',
#  '数据挖掘',
#  '数据分析',
#  '项目管理',
#  '数据分析',
#  '大数据',
#  '征信',
#  '数据分析',
#  '新零售',
#  '数据分析',
#  '汽车',
#  '大数据',
#  '数据挖掘',
#  '数据分析',
#  '教育',
#  'BI',
#  '数据分析',
#  '电商',
#  '新零售',
#  '数据仓库',
#  '数据分析',
#  '数据处理',
#  '数据分析',
#  'BI',
#  '增长黑客',
#  '数据分析',
#  'SQL',
#  '数据库',
#  '数据分析',
#  'SQL',
#  'BI',
#  '可视化',
#  '数据分析',
#  'BI',
#  'SQL',
#  '数据库',
#  '医疗健康',
#  '大数据',
#  '互联网金融',
#  'MySQL',
#  '数据分析',
#  '数据分析',
#  '数据挖掘',
#  '算法',
#  '数据分析',
#  'SQL',
#  '数据库',
#  '移动互联网',
#  'BI',
#  'SQL',
#  '数据库',
#  '数据分析',
#  '移动互联网',
#  '数据分析',
#  '广告营销',
#  '移动互联网',
#  '数据分析',
#  'SQL',
#  '运营',
#  'BI',
#  '数据分析',
#  '金融',
#  '移动互联网',
#  'SPSS',
#  '数据分析',
#  'SQL',
#  '商业',
#  '大数据',
#  '数据分析',
#  'BI',
#  '数据分析',
#  'SQL',
#  '算法',
#  '搜索',
#  '数据挖掘',
#  '数据分析',
#  '旅游',
#  '数据分析',
#  'SPSS',
#  '商业',
#  'BI',
#  '数据分析',
#  '数据运营',
#  '大数据',
#  '数据分析',
#  '数据分析',
#  '数据挖掘',
#  '数据分析',
#  '商业',
#  'BI',
#  '数据分析',
#  '数据挖掘',
#  '数据分析',
#  '数据挖掘',
#  '数据仓库',
#  '大数据',
#  '数据分析',
#  'SPSS',
#  '数据分析',
#  '数据分析',
#  'SQL',
#  '金融',
#  '数据分析',
#  '移动互联网',
#  '电商',
#  '旅游',
#  'BI',
#  '产品经理',
#  '数据分析',
#  '汽车',
#  '数据分析',
#  '电商',
#  '商业',
#  'BI',
#  'BI',
#  'SQL',
#  'SPSS',
#  '商业',
#  '数据分析',
#  '数据库',
#  'SQL',
#  '可视化',
#  '数据分析',
#  '增长黑客',
#  '视频',
#  '直播',
#  '数据分析',
#  '数据分析',
#  '数据分析',
#  'SQL',
#  '数据分析',
#  '数据运营',
#  'MySQL',
#  'Scala',
#  '数据分析',
#  '金融',
#  '大数据',
#  '数据挖掘',
#  'BI',
#  '数据分析',
#  '数据分析',
#  '分析师',
#  '互联网金融',
#  'MySQL',
#  '教育',
#  '决策能力',
#  '业务流程管理',
#  '数据分析',
#  '移动互联网',
#  '金融',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  '互联网金融',
#  '银行',
#  '节日礼物',
#  '技能培训',
#  '年度旅游',
#  '岗位晋升',
#  '数据分析',
#  '互联网金融',
#  '数据分析',
#  '数据分析',
#  '数据分析',
#  '数据分析',
#  'SQL',
#  '商业',
#  '数据库',
#  '产品',
#  '大数据',
#  'SQL',
#  '数据分析',
#  '商业',
#  '大数据',
#  'SQLServer',
#  'Hive',
#  '数据分析',
#  '商业',
#  '可视化',
#  '数据分析',
#  '数据分析',
#  '房产服务',
#  'BI',
#  '数据分析',
#  '商业',
#  '移动互联网',
#  '数据分析',
#  '企业服务',
#  '移动互联网',
#  '数据分析',
#  '数据运营',
#  '数据库',
#  'SQL',
#  '数据分析',
#  'SQL',
#  '数据库',
#  '金融',
#  'NLP',
#  '算法',
#  '数据分析',
#  '医疗健康',
#  '大数据',
#  '数据分析',
#  'BI',
#  '数据运营',
#  '数据库',
#  '电商',
#  '大数据',
#  '数据分析',
#  'SPSS',
#  '数据分析',
#  'SPSS',
#  'BI',
#  '可视化',
#  '数据分析',
#  '移动互联网',
#  'SQL',
#  '可视化',
#  '数据分析',
#  '数据分析',
#  '数据分析',
#  '增长黑客',
#  '数据分析',
#  '数据运营',
#  '商业',
#  '数据分析',
#  'MySQL',
#  '教育',
#  '算法',
#  '数据挖掘',
#  '数据分析',
#  'ETL',
#  'MySQL',
#  '数据分析',
#  '数据处理',
#  '互联网金融',
#  '数据分析',
#  '数据分析',
#  '商业',
#  '数据分析',
#  'SPSS',
#  'SQL',
#  '广告营销',
#  '大数据',
#  '商业',
#  '数据分析',
#  'SPSS',
#  '数据分析',
#  '数据分析',
#  'SQL',
#  '数据库',
#  '数据分析',
#  '数据分析',
#  '数据分析',
#  '互联网金融',
#  '借贷',
#  '数据分析',
#  '数据运营',
#  '电商',
#  '商业',
#  'BI',
#  '数据分析',
#  'SQL',
#  '数据分析',
#  '教育',
#  '数据分析',
#  'SQL',
#  '大数据',
#  '商业',
#  'BI',
#  '可视化',
#  '数据分析',
#  '大数据',
#  '金融',
#  'SQL',
#  '数据分析',
#  '大数据',
#  '数据分析',
#  '可视化',
#  'BI',
#  '商业',
#  '数据分析',
#  '互联网金融',
#  '借贷',
#  '数据分析',
#  '数据运营',
#  '数据运营',
#  '增长黑客',
#  '数据分析',
#  'Hive',
#  'MySQL',
#  'Oracle',
#  '电商',
#  '数据',
#  '大数据',
#  '数据运营',
#  '电商',
#  'SQL',
#  '互联网金融',
#  'Oracle',
#  '数据分析',
#  'Hive',
#  '游戏',
#  '数据分析',
#  '数据运营',
#  '大数据',
#  '数据分析',
#  '互联网金融',
#  '借贷',
#  '数据分析',
#  'MySQL',
#  'Spark',
#  '电商',
#  'SQL',
#  '数据分析',
#  '数据运营',
#  '数据库',
#  '后端',
#  '音频处理',
#  '软件开发',
#  '滴滴',
#  '本地生活',
#  '移动互联网',
#  'BI',
#  '数据分析',
#  '数据运营',
#  '大数据',
#  '金融',
#  '数据挖掘',
#  '数据分析',
#  '数据分析',
#  '数据分析',
#  '数据分析',
#  'SQL',
#  '互联网金融',
#  '理财',
#  'BI',
#  '数据分析',
#  '数据库',
#  '大数据',
#  '金融',
#  'BI',
#  '数据分析',
#  '电商',
#  '数据分析',
#  'BI',
#  'SQL',
#  '数据库',
#  'BI',
#  '数据分析',
#  '数据分析',
#  '风控',
#  '分析师',
#  '数据分析',
#  'SQL',
#  '数据分析',
#  '数据分析',
#  '大数据',
#  '数据分析',
#  'SQL',
#  '移动互联网',
#  '企业服务',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  '数据库',
#  '数据分析',
#  'hadoop',
#  '大数据',
#  '数据挖掘',
#  '数据分析',
#  '数据分析',
#  '金融',
#  '数据分析',
#  '数据运营',
#  '医疗健康',
#  '大数据',
#  '数据分析',
#  'BI',
#  '移动互联网',
#  '数据分析',
#  'SQL',
#  '大数据',
#  '数据分析',
#  '数据分析',
#  '移动互联网',
#  '数据分析',
#  'Hive',
#  '数据处理',
#  '数据挖掘',
#  '电商',
#  '数据分析',
#  '数据分析',
#  '数据处理',
#  '移动互联网',
#  '数据分析',
#  '数据运营',
#  '数据挖掘',
#  '数据分析',
#  'Spark',
#  '电商',
#  '数据分析',
#  'SPSS',
#  'BI',
#  'SQL',
#  '产品经理',
#  '大数据',
#  '数据挖掘',
#  '数据分析',
#  '金融',
#  '数据挖掘',
#  '数据分析',
#  'Hive',
#  '数据分析',
#  '数据分析',
#  '数据运营',
#  '数据库',
#  'BI',
#  '数据分析',
#  'SQL',
#  '数据库',
#  '数据分析',
#  '大数据',
#  '旅游',
#  '数据挖掘',
#  '数据分析',
#  '数据处理',
#  '算法',
#  'SQL',
#  '增长黑客',
#  '数据分析',
#  '大数据',
#  '数据分析',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  '数据库',
#  '电商',
#  '数据分析',
#  '数据分析',
#  '教育',
#  '产品',
#  'SQL',
#  'SPSS',
#  'SQL',
#  'SPSS',
#  '数据运营',
#  '数据分析',
#  '大数据',
#  '房产服务',
#  '数据分析',
#  'MySQL',
#  '数据分析',
#  '数据分析',
#  '互联网金融',
#  '数据分析',
#  '数据分析',
#  '数据挖掘',
#  'SQL',
#  '商业',
#  '借贷',
#  '数据分析',
#  '数据处理',
#  '数据分析',
#  'MySQL',
#  'SQLServer',
#  '滴滴',
#  '教育',
#  'BI',
#  'SQL',
#  '商业',
#  '数据运营',
#  '数据分析',
#  '移动互联网',
#  '视频',
#  '数据分析',
#  '数据分析',
#  '数据架构',
#  '数据挖掘',
#  '数据分析',
#  'SQL',
#  '电商',
#  '新零售',
#  'SQL',
#  '数据分析',
#  '数据运营',
#  '大数据',
#  '旅游',
#  '数据仓库',
#  '数据分析',
#  '数据处理',
#  'Hive',
#  '互联网金融',
#  '电商',
#  'Hive',
#  'Hadoop',
#  '数据分析',
#  '医疗健康',
#  '移动互联网',
#  '数据分析',
#  'SQLServer',
#  '借贷',
#  '数据分析',
#  'SQL',
#  '数据库',
#  '运营',
#  'APP推广',
#  '大数据',
#  '数据分析',
#  '数据分析',
#  'MySQL',
#  'Hive',
#  '数据分析',
#  'SQL',
#  '教育',
#  '移动互联网',
#  '数据分析',
#  '商业',
#  'BI',
#  '数据运营',
#  '大数据',
#  '金融',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  '数据分析',
#  '新零售',
#  '汽车',
#  'BI',
#  '可视化',
#  '数据分析',
#  'SQL',
#  '行业研究',
#  '分析师',
#  '游戏',
#  '大数据',
#  '数据分析',
#  '数据分析',
#  '效果跟踪',
#  '新媒体运营',
#  '数据分析',
#  '电商',
#  '数据分析',
#  '数据分析',
#  '保险',
#  'Hadoop',
#  'ETL',
#  'Hive',
#  '数据分析',
#  '数据分析',
#  '金融',
#  '数据分析',
#  '数据处理',
#  '数据分析',
#  '算法',
#  '电商',
#  '数据分析',
#  'SPSS',
#  '电商',
#  '可视化',
#  '商业',
#  '数据分析',
#  'BI',
#  '产品',
#  '数据分析',
#  '滴滴',
#  '数据分析',
#  '教育',
#  '数据分析',
#  'SPSS',
#  'SQL',
#  '大数据',
#  '移动互联网',
#  '市场分析',
#  '数据分析',
#  '行业分析',
#  '市场',
#  '数据分析',
#  '电商',
#  '移动互联网',
#  '可视化',
#  '数据分析',
#  '数据运营',
#  '增长黑客',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  '数据库',
#  '数据分析',
#  'BI',
#  '数据分析',
#  '大数据',
#  '数据分析',
#  '电商',
#  'ETL',
#  '数据分析',
#  '地图',
#  '大数据',
#  '审核',
#  '大数据',
#  '教育',
#  '滴滴',
#  '数据挖掘',
#  '数据仓库',
#  '数据分析',
#  'Hadoop',
#  'BI',
#  '可视化',
#  '数据分析',
#  '数据运营',
#  '数据分析',
#  '大数据',
#  '数据分析',
#  '数据库',
#  '增长黑客',
#  '商业',
#  '数据运营',
#  '数据分析',
#  '商业',
#  'BI',
#  '数据分析',
#  'SQL',
#  '大数据',
#  '数据挖掘',
#  '数据分析',
#  '可视化',
#  '数据分析',
#  'SPSS',
#  '数据库',
#  '大数据',
#  '汽车',
#  'Java',
#  '数据挖掘',
#  '数据处理',
#  '算法',
#  '产品',
#  '滴滴',
#  '电商',
#  'SQL',
#  '数据分析',
#  '本地生活',
#  '房产服务',
#  '数据库',
#  'SQL',
#  '数据分析',
#  '大数据',
#  '商业',
#  '数据分析',
#  '游戏',
#  '数据分析',
#  '数据运营',
#  '汽车',
#  '地图',
#  '电商',
#  '商业',
#  '教育',
#  'MySQL',
#  '数据分析',
#  '数据分析',
#  '电商',
#  'SQLServer',
#  '数据分析',
#  '数据分析',
#  '游戏',
#  '数据分析',
#  '数据分析',
#  '汽车',
#  'Hive',
#  '数据分析',
#  '数据分析',
#  '数据分析',
#  '数据',
#  '互联网金融',
#  '保险',
#  '数据分析',
#  'BI',
#  'SPSS',
#  'SQL',
#  '游戏',
#  'BI',
#  '数据分析',
#  '商业',
#  'SQL',
#  '金融',
#  '数据分析',
#  '数据分析',
#  '数据运营',
#  '大数据',
#  '医疗健康',
#  '数据分析',
#  'SQL',
#  '广告营销',
#  '数据分析',
#  '数据挖掘',
#  '数据分析',
#  'Spark',
#  'Hadoop',
#  'Hive',
#  '数据分析',
#  'SQL',
#  '分析',
#  '财务',
#  '游戏',
#  '移动互联网',
#  'BI',
#  'SQL',
#  '数据分析',
#  'SPSS',
#  '数据分析',
#  '社交',
#  '移动互联网',
#  'SQL',
#  '商业',
#  '数据分析',
#  '增长黑客（GrowthHacking）',
#  '汽车',
#  '新零售',
#  '数据运营',
#  'SQL',
#  '数据分析',
#  '商业',
#  '大数据',
#  '数据挖掘',
#  '数据分析',
#  '数据分析',
#  '电商',
#  '本地生活',
#  '商业',
#  'BI',
#  '可视化',
#  '互联网金融',
#  '移动互联网',
#  '房产服务',
#  '数据分析',
#  'MySQL',
#  '数据挖掘',
#  '数据分析',
#  '电商',
#  '数据分析',
#  '数据运营',
#  '可视化',
#  '视频',
#  '移动互联网',
#  '商业',
#  '数据分析',
#  '数据运营',
#  'SQL',
#  '审核',
#  '数据分析',
#  '滴滴',
#  '直播',
#  '社交',
#  '数据分析',
#  '互联网金融',
#  '借贷',
#  'SQL',
#  '可视化',
#  '数据分析',
#  'SPSS',
#  '数据挖掘',
#  '算法',
#  '数据挖掘',
#  '数据分析',
#  '数据运营',
#  '新零售',
#  '汽车',
#  '可视化',
#  'SPSS',
#  'SQL',
#  '数据分析',
#  '数据分析',
#  'SQL',
#  '商业',
#  ...]

# %%
# 删除里面的  数据分析  数据  分析
s  = [i  for i in s if i not in ['数据分析',  '数据',  '分析']]
s = ' '.join(s)
s
# Out:
# 'SPSS SQL MySQL Hive 数据运营 SPSS SQL 游戏 社交 SQL 商业 数据运营 SQL 电商 新零售 Hive MySQL 数据处理 电商 广告营销 增长黑客 SQL 商业 数据运营 教育 运营 效果跟踪 MySQL SQLServer 云计算 大数据 SPSS SQL 电商 新零售 运营 产品运营 用户运营 电商运营 移动互联网 需求分析 教育 算法 数据挖掘 大数据 商业 云计算 大数据 数据库 数据运营 SQL BI BI 电商 产品设计 产品策划 需求分析 移动互联网 移动互联网 行业分析 企业服务 房产服务 BI 数据库 数据运营 SQL BI 商业 MySQL 电商 汽车 商业 SQL SPSS MySQL SQLServer 大数据 商业 SPSS SQL 商业 SQL 大数据 金融 商业 游戏 商业 可视化 金融 SQL 数据库 数据运营 互联网金融 SQL 教育 移动互联网 用户增长 电商 SQL BI SQL 商业 社交 移动互联网 策略 用户研究 教育 SQL ETL 数据仓库 SQLServer 移动互联网 增长黑客 商业 数据运营 移动互联网 可视化 数据运营 SPSS SQL 直播 数据库 SQL 大数据 SQL 移动互联网 教育 大数据 金融 Hadoop 算法 数据挖掘 SQL SPSS 电商 新零售 数据运营 数据库 SQL 可视化 本地生活 数据运营 SQL BI 可视化 商业 SQL SQL 视频 工具软件 数据运营 SQL 商业 大数据 数据挖掘 教育 移动互联网 BI 可视化 SQL 数据库 SQL BI SQL 数据库 大数据 数据挖掘 项目管理 大数据 征信 新零售 汽车 大数据 数据挖掘 教育 BI 电商 新零售 数据仓库 数据处理 BI 增长黑客 SQL 数据库 SQL BI 可视化 BI SQL 数据库 医疗健康 大数据 互联网金融 MySQL 数据挖掘 算法 SQL 数据库 移动互联网 BI SQL 数据库 移动互联网 广告营销 移动互联网 SQL 运营 BI 金融 移动互联网 SPSS SQL 商业 大数据 BI SQL 算法 搜索 数据挖掘 旅游 SPSS 商业 BI 数据运营 大数据 数据挖掘 商业 BI 数据挖掘 数据挖掘 数据仓库 大数据 SPSS SQL 金融 移动互联网 电商 旅游 BI 产品经理 汽车 电商 商业 BI BI SQL SPSS 商业 数据库 SQL 可视化 增长黑客 视频 直播 SQL 数据运营 MySQL Scala 金融 大数据 数据挖掘 BI 分析师 互联网金融 MySQL 教育 决策能力 业务流程管理 移动互联网 金融 数据运营 SQL 互联网金融 银行 节日礼物 技能培训 年度旅游 岗位晋升 互联网金融 SQL 商业 数据库 产品 大数据 SQL 商业 大数据 SQLServer Hive 商业 可视化 房产服务 BI 商业 移动互联网 企业服务 移动互联网 数据运营 数据库 SQL SQL 数据库 金融 NLP 算法 医疗健康 大数据 BI 数据运营 数据库 电商 大数据 SPSS SPSS BI 可视化 移动互联网 SQL 可视化 增长黑客 数据运营 商业 MySQL 教育 算法 数据挖掘 ETL MySQL 数据处理 互联网金融 商业 SPSS SQL 广告营销 大数据 商业 SPSS SQL 数据库 互联网金融 借贷 数据运营 电商 商业 BI SQL 教育 SQL 大数据 商业 BI 可视化 大数据 金融 SQL 大数据 可视化 BI 商业 互联网金融 借贷 数据运营 数据运营 增长黑客 Hive MySQL Oracle 电商 大数据 数据运营 电商 SQL 互联网金融 Oracle Hive 游戏 数据运营 大数据 互联网金融 借贷 MySQL Spark 电商 SQL 数据运营 数据库 后端 音频处理 软件开发 滴滴 本地生活 移动互联网 BI 数据运营 大数据 金融 数据挖掘 SQL 互联网金融 理财 BI 数据库 大数据 金融 BI 电商 BI SQL 数据库 BI 风控 分析师 SQL 大数据 SQL 移动互联网 企业服务 数据运营 SQL 数据库 hadoop 大数据 数据挖掘 金融 数据运营 医疗健康 大数据 BI 移动互联网 SQL 大数据 移动互联网 Hive 数据处理 数据挖掘 电商 数据处理 移动互联网 数据运营 数据挖掘 Spark 电商 SPSS BI SQL 产品经理 大数据 数据挖掘 金融 数据挖掘 Hive 数据运营 数据库 BI SQL 数据库 大数据 旅游 数据挖掘 数据处理 算法 SQL 增长黑客 大数据 数据运营 SQL 数据库 电商 教育 产品 SQL SPSS SQL SPSS 数据运营 大数据 房产服务 MySQL 互联网金融 数据挖掘 SQL 商业 借贷 数据处理 MySQL SQLServer 滴滴 教育 BI SQL 商业 数据运营 移动互联网 视频 数据架构 数据挖掘 SQL 电商 新零售 SQL 数据运营 大数据 旅游 数据仓库 数据处理 Hive 互联网金融 电商 Hive Hadoop 医疗健康 移动互联网 SQLServer 借贷 SQL 数据库 运营 APP推广 大数据 MySQL Hive SQL 教育 移动互联网 商业 BI 数据运营 大数据 金融 数据运营 SQL 新零售 汽车 BI 可视化 SQL 行业研究 分析师 游戏 大数据 效果跟踪 新媒体运营 电商 保险 Hadoop ETL Hive 金融 数据处理 算法 电商 SPSS 电商 可视化 商业 BI 产品 滴滴 教育 SPSS SQL 大数据 移动互联网 市场分析 行业分析 市场 电商 移动互联网 可视化 数据运营 增长黑客 数据运营 SQL 数据库 BI 大数据 电商 ETL 地图 大数据 审核 大数据 教育 滴滴 数据挖掘 数据仓库 Hadoop BI 可视化 数据运营 大数据 数据库 增长黑客 商业 数据运营 商业 BI SQL 大数据 数据挖掘 可视化 SPSS 数据库 大数据 汽车 Java 数据挖掘 数据处理 算法 产品 滴滴 电商 SQL 本地生活 房产服务 数据库 SQL 大数据 商业 游戏 数据运营 汽车 地图 电商 商业 教育 MySQL 电商 SQLServer 游戏 汽车 Hive 互联网金融 保险 BI SPSS SQL 游戏 BI 商业 SQL 金融 数据运营 大数据 医疗健康 SQL 广告营销 数据挖掘 Spark Hadoop Hive SQL 财务 游戏 移动互联网 BI SQL SPSS 社交 移动互联网 SQL 商业 增长黑客（GrowthHacking） 汽车 新零售 数据运营 SQL 商业 大数据 数据挖掘 电商 本地生活 商业 BI 可视化 互联网金融 移动互联网 房产服务 MySQL 数据挖掘 电商 数据运营 可视化 视频 移动互联网 商业 数据运营 SQL 审核 滴滴 直播 社交 互联网金融 借贷 SQL 可视化 SPSS 数据挖掘 算法 数据挖掘 数据运营 新零售 汽车 可视化 SPSS SQL SQL 商业 数据运营 市场 大数据 互联网金融 SQL 运营 商业 BI 可视化 SQL 电商 电商 新零售 视频 数据处理 数据架构 数据挖掘 移动互联网 大数据 工具软件 增长黑客（GrowthHacking） 商业 增长黑客 数据运营 数据运营 分类信息 可视化 数据库 SQL 大数据 云计算 数据挖掘 算法 数据处理 SQL 数据库 电商 广告营销 电商 移动互联网 数据挖掘 Hive MySQL 移动互联网 保险 增长黑客 可视化 数据运营 SQL 电商 广告营销 大数据 视频 直播 行业分析 市场分析 市场竞争分析 商业 物流 数据处理 SQLServer 大数据 商业 BI 可视化 电商 移动互联网 SQL 物流 电商 新零售 商业 SQL 电商 新零售 教育 Hadoop MySQL 广告营销 大数据 BI 数据运营 汽车 SPSS SQL 电商 电商 房产服务 BI SQL 广告营销 SQL 审核 市场分析 行业分析 物流 SQLServer 电商 新零售 效果跟踪 免费班车 岗位晋升 五险一金 定期体检 增长黑客 SQL 数据挖掘 数据处理 互联网金融 教育 运营 效果跟踪 大数据 数据挖掘 其他 大数据 银行 数据挖掘 SQLServer 游戏 移动互联网 数据运营 大数据 移动互联网 数据运营 SQL SPSS 大数据 本地生活 移动互联网 医疗健康 物流 企业服务 大数据 算法 数据挖掘 数据架构 大数据 Hadoop 大数据 企业服务 SPSS 数据库 移动互联网 通信/网络设备 移动互联网 大数据 大数据 SQL 市场 数据挖掘 风控 产品 大数据 移动互联网 智能硬件 数据运营 BI 大数据 大数据 银行 数据挖掘 移动互联网 电商 数据运营 可视化 商业 MySQL 游戏 移动互联网 效果跟踪 移动互联网 电商 大数据 算法 数据挖掘 分析师 大数据 金融 数据库 教育 移动互联网 电商 运营 机器学习 数据挖掘 建模 大数据 数据运营 商业 大数据 金融 数据库 数据运营 SPSS SQL 数据库 大数据 信息安全 数据运营 大数据 商业 物流 金融 移动互联网 企业服务 金融 SQL 市场竞争分析 消费者分析 市场分析 数字营销 Oracle MySQL Hadoop 数据架构 大数据 企业服务 大数据 医疗 ...

# %%
# from wordcloud import WordCloud
# from PIL import Image
# import numpy as np
# from wordcloud import ImageColorGenerator

# mask = np.array(Image.open(r"C:\Users\EDZ\Desktop\案列\拉勾网数据分析职位分析\code\数据分析.png"))
# image_colors = ImageColorGenerator(mask)

# '''从文本中生成词云图'''
# wordcloud = WordCloud(font_path=r"C:\Users\EDZ\Desktop\字体\bb1781\微软vista雅黑.ttf", # 定义SimHei字体文件
#                       background_color='white', # 背景色为白色
#                       height=400, # 高度设置为400
#                       width=800, # 宽度设置为800
#                       scale=20, # 长宽拉伸程度程度设置为20
#                       prefer_horizontal=0.2, # 调整水平显示倾向程度为0.2
#                       mask=mask, # 添加蒙版, 即轮廓
#                       max_words=1000, # 设置最大显示字数为1000
#                       relative_scaling=0.3, # 设置字体大小与词频的关联程度为0.3
#                       max_font_size=80 # 缩小最大字体为80
#                      ).generate(s)

# plt.figure(figsize=[8, 4])
# plt.imshow(wordcloud.recolor(color_func=image_colors), alpha=1)
# plt.axis('off')
# '''保存到本地'''
# plt.savefig('数据分析技能词云图.jpg', dpi=600, bbox_inches='tight', quality=95)
# plt.show()

# %%
from wordcloud import WordCloud
from PIL import Image
import numpy as np

mask = np.array(Image.open(r"C:\Users\EDZ\Desktop\案列\拉勾网数据分析职位分析\code\12.png"))


'''从文本中生成词云图'''
wordcloud = WordCloud(font_path=r"C:\Users\EDZ\Desktop\字体\bb1781\微软vista雅黑.ttf", # 定义SimHei字体文件
                      background_color='white', # 背景色为白色
                      height=400, # 高度设置为400
                      width=800, # 宽度设置为800
                      scale=20, # 长宽拉伸程度程度设置为20
                      prefer_horizontal=0.2, # 调整水平显示倾向程度为0.2
                      mask=mask, # 添加蒙版, 即轮廓
                      max_words=1000, # 设置最大显示字数为1000
                      relative_scaling=0.3, # 设置字体大小与词频的关联程度为0.3
                      max_font_size=80 # 缩小最大字体为80
                     ).generate(s)

plt.figure(figsize=(8, 6), dpi=800)
plt.imshow(wordcloud)
plt.axis('off')
'''保存到本地'''
plt.savefig('数据分析技能词云图.jpg', dpi=600)
plt.show();

# %% [markdown]
# ## 各城市 数据分析职位数目 地理图

# %%
a = df.城市.value_counts()
a
# Out:
# 北京    450
# 上海    359
# 深圳    260
# 广州    175
# 杭州    145
# 成都     46
# 武汉     44
# 南京     27
# 长沙     16
# 厦门     14
# 西安     12
# 佛山     10
# 郑州      9
# 重庆      8
# 苏州      8
# 天津      7
# Name: 城市, dtype: int64

# %%
def geo(a):
    # 导入地理类
    from pyecharts.charts import Geo
    # 导入配置项类
    from pyecharts import options as opts
    # 导入背景主题类
    from pyecharts.globals import ThemeType

    # 给地理图对象设置主题
    geo = Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
    # 设置地图北京 China
    geo.add_schema(maptype='china')

    # 添加数据
    geo.add(  series_name='各城市数据分析职位地理图'
            , data_pair=list(zip(a.index, a.tolist())) 
            , type_ = 'effectScatter')

    # 添加全局配置项
                        #  群居配置项下的标题配置项
    geo.set_global_opts(title_opts= opts.TitleOpts(title = '全国各城市数据分析职位统计图'),
                        # 全局配置项下的视觉设置配置项
                        visualmap_opts=opts.VisualMapOpts(min_ = 0 , max_=400),
                        # 全局配置项下的工具箱配置项
                        toolbox_opts= opts.ToolboxOpts())
    # 系列配置项
                        # 系列配置项下的标签配置项
    geo.set_series_opts(label_opts= opts.LabelOpts(is_show = False))
    return geo.render_notebook()

# %%
geo(a)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="56dfda46633d47f1a48dff49df0eddd4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china', 'purple-passion'], function(echarts) {
#                 var chart_56dfda46633d47f1a48dff49df0eddd4 = echarts.init(
#                     document.getElementById('56dfda46633d47f1a48dff49df0eddd4'), 'purple-passion', {renderer: 'canvas'});
#                 var option_56dfda46633d47f1a48dff49df0eddd4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u5404\u57ce\u5e02\u6570\u636e\u5206\u6790\u804c\u4f4d\u5730\u7406\u56fe",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         450
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         359
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         260
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         175
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         145
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         46
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         44
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": [
#                         113,
#                         28.21,
#                         16
#                     ]
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": [
#                         118.1,
#                         24.46,
#                         14
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         12
#                     ]
#                 },
#                 {
#                     "name": "\u4f5b\u5c71",
#                     "value": [
#                         113.11,
#                         23.05,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": [
#                         113.65,
#                         34.76,
#                         9
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         8
#                     ]
#                 },
#                 {
#                     "name": "\u82cf\u5dde",
#                     "value": [
#                         120.62,
#                         31.32,
#                         8
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         7
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u57ce\u5e02\u6570\u636e\u5206\u6790\u804c\u4f4d\u5730\u7406\u56fe"
#             ],
#             "selected": {
#                 "\u5404\u57ce\u5e02\u6570\u636e\u5206\u6790\u804c\u4f4d\u5730\u7406\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5168\u56fd\u5404\u57ce\u5e02\u6570\u636e\u5206\u6790\u804c\u4f4d\u7edf\u8ba1\u56fe"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image",
#                 "type": "png"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view",
#                 "readOnly": false
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "data zoom",
#                     "back": "data zoom restore"
#                 }
#             }
#         }
#     },
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 400,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_56dfda46633d47f1a48dff49df0eddd4.setOption(option_56dfda46633d47f1a48dff49df0eddd4);
#         });
#     </script>
