# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
import sys
sys.path.append("D:\yxp")
from need_import import *
d7 = str(list(pd.date_range(ds, freq='-1D', periods=7))[-1].date()).replace('-', '')
ds, dstime, d7
# Out:
# ('20240406', '20240407172045', '20240331')

# %% [markdown]
# # 中文文档

# %%
# https://pyecharts.org/#/zh-cn/intro

# %% [markdown]
# # 柱状图

# %%
df = pd.DataFrame(data = [['Category 1', 50, 50, 200, 300,-300],
                         ['Category 2', 100, 110, 250, 460, -460],
                         ['Category 3', 200, 90, 200, 490, -490],
                         ['Category 4', 350, 50, 60, 460, -460],
                         ['Category 5', 50, 150, 400, 600, -600],
                         ['Category 6', 250, 50, 260, 560, -560]],
                columns = ['Category', 'Series1', 'Series2', 'Series3', 'Series4','Series5']
                )
df['合计'] = df.iloc[:, 1:].sum(axis=1)
df
# Out:
#      Category  Series1  Series2  Series3  Series4  Series5   合计
# 0  Category 1       50       50      200      300     -300  300
# 1  Category 2      100      110      250      460     -460  460
# 2  Category 3      200       90      200      490     -490  490
# 3  Category 4      350       50       60      460     -460  460
# 4  Category 5       50      150      400      600     -600  600
# 5  Category 6      250       50      260      560     -560  560

# %%
x = df.Category.to_list()
y1 = df.Series1.to_list()
y2 = df.Series2.to_list()
y3 = df.Series3.to_list()
y4 = df.Series4.to_list()
y5 = df.Series5.to_list()
y6 = df.合计.to_list()


from pyecharts.charts import Bar
# 类的实例化,实例化一个柱状图的对象
bar = Bar(
    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='01柱状图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )
)
# 添加横轴和纵轴的数据
bar.add_xaxis(xaxis_data=x)

bar.add_yaxis(series_name='Series1'
              ,y_axis=y1 
              ,color='#028599' # 绿色
             )   

bar.add_yaxis(series_name='Series2'
              ,y_axis=y2 
              ,color='#FF3F5F' # 红色
             )  

bar.add_yaxis(series_name='Series3'
              ,y_axis=y3
              ,color='#FEB834'  # 黄色
             )  

# 设置图表全局配置项
bar.set_global_opts(
    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个柱状图', 
                              pos_left='center'
                             )
    # 图例
    ,legend_opts=opts.LegendOpts(is_show=True, 
                                pos_top=30,  # 图例离上边界 30
                                border_color='transparent'# 图例边界颜色为 透明
                               
                               )
    
    # X 坐标轴配置项
    ,xaxis_opts=opts.AxisOpts(type_='category'     # 'value': 数值轴，适用于连续数据。
                                                  # 'category': 类目轴，适用于离散的类目数据，为该类型时必须通过 data 设置类目数据。
                                                  # 'time': 时间轴，适用于连续的时序数据，与数值轴相比时间轴带有时间的格式化，在刻度计算上也有所不同，
                                                  # 例如会根据跨度的范围来决定使用月，星期，日还是小时范围的刻度。
                                                  # 'log' 对数轴。适用于对数数据。
                             ,name = 'X坐标轴名称' # 轴名称
                             ,is_show = True      # 是否显示x轴
                             ,name_location='center'  # 'start', 'middle' 或者 'center','end'
                             ,name_gap = 35      # 坐标轴名称与轴线之间的距离。
                             # 轴名称文字样式配置
                             ,name_textstyle_opts=opts.TextStyleOpts(# color='black'       # 文字颜色，使用默认
                                                                     # font_style='normal' # 字体风格
                                                                     # ,font_weight='normal'   # 字体粗细
                                                                     # ,font_family='Microsoft YaHei'        # 字体 'serif' , 'monospace', 'Arial', 'Courier New', 'Microsoft YaHei',
                                                                     font_size=15  # 字体大小
                                                                    
                                                                    
                                                                    )
                            
                            
                            
                            )
    #  Y 坐标轴配置项
    ,yaxis_opts=opts.AxisOpts(type_='value'     # 'value': 数值轴，适用于连续数据。
                                                  # 'category': 类目轴，适用于离散的类目数据，为该类型时必须通过 data 设置类目数据。
                                                  # 'time': 时间轴，适用于连续的时序数据，与数值轴相比时间轴带有时间的格式化，在刻度计算上也有所不同，
                                                  # 例如会根据跨度的范围来决定使用月，星期，日还是小时范围的刻度。
                                                  # 'log' 对数轴。适用于对数数据。
                             ,name = 'Y坐标轴名称' # 轴名称
                             ,is_show = True      # 是否显示
                             ,name_location='center'  # 'start', 'middle' 或者 'center','end'
                             ,name_gap = 35      # 坐标轴名称与轴线之间的距离。
                             # 轴名称文字样式配置
                             ,name_textstyle_opts=opts.TextStyleOpts(# color='black'       # 文字颜色,使用默认
                                                                     # font_style='normal' # 字体风格
                                                                     # font_weight='normal'   # 字体粗细
                                                                     # ,font_family='Microsoft YaHei'        # 字体 'serif' , 'monospace', 'Arial', 'Courier New', 'Microsoft YaHei',
                                                                     font_size=15  # 字体大小
                                                                    
                                                                    
                                                                    )
                             )
    
                   
)

# 设置系列配置项
bar.set_series_opts(
    # 数据标签配置项
    label_opts=opts.LabelOpts(
        is_show = True,
        position = 'top'
    )
    
    # 标记线配置项
    ,markline_opts=opts.MarkLineOpts(
        data=[
                 opts.MarkLineItem(y=240, 
                                   name="yAxis=240", 
                                   # 线样式配置项
                                   linestyle_opts = opts.LineStyleOpts(color='#5470C6' # 线的颜色
                                                                       ,type_='dashed'  # 线型
                                                                      
                                                                      )
                                  
                                  )
            
            
                ,opts.MarkLineItem(y=150, name="yAxis=150")
             
             
             ]
    )
)

# 在jupyter 中显示
bar.load_javascript()
# jupyter渲染的图片往往不够清晰，导出再截图
html_name = '01柱状图.html'
bar.render(html_name)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\01柱状图.html'

# %%
# render_notebook()显示不出来，就用下面这种
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="60640c9244a34ab297f7e119dabd9d0e" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_60640c9244a34ab297f7e119dabd9d0e = echarts.init(
#             document.getElementById('60640c9244a34ab297f7e119dabd9d0e'), 'white', {renderer: 'canvas'});
#         var option_60640c9244a34ab297f7e119dabd9d0e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#028599",
#         "#FF3F5F",
#         "#FEB834",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Series1",
#             "legendHoverLink": true,
#             "data": [
#                 50,
#                 100,
#                 200,
#                 350,
#                 50,
#                 250
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "yAxis=240",
#                         "yAxis": 240,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "dashed",
#                             "color": "#5470C6"
#                         }
#                     },
#                     {
#                         "name": "yAxis=150",
#                         "yAxis": 150
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Series2",
#             "legendHoverLink": true,
#             "data": [
#                 50,
#                 110,
#                 90,
#                 50,
#                 150,
#                 50
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "yAxis=240",
#                         "yAxis": 240,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "dashed",
#                             "color": "#5470C6"
#                         }
#                     },
#                     {
#                         "name": "yAxis=150",
#                         "yAxis": 150
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Series3",
#             "legendHoverLink": true,
#             "data": [
#                 200,
#                 250,
#                 200,
#                 60,
#                 400,
#                 260
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "yAxis=240",
#                         "yAxis": 240,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "dashed",
#                             "color": "#5470C6"
#                         }
#                     },
#                     {
#                         "name": "yAxis=150",
#                         "yAxis": 150
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Series1",
#                 "Series2",
#                 "Series3"
#             ],
#             "selected": {
#                 "Series1": true,
#                 "Series2": true,
#                 "Series3": true
#             },
#             "show": true,
#             "top": 30,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBo

# %% [markdown]
# # 条形图

# %%
df = pd.DataFrame(data = [['Category 1', 50, 50, 200, 300,-300],
                         ['Category 2', 100, 110, 250, 460, -460],
                         ['Category 3', 200, 90, 200, 490, -490],
                         ['Category 4', 350, 50, 60, 460, -460],
                         ['Category 5', 50, 150, 400, 600, -600],
                         ['Category 6', 250, 50, 260, 560, -560]],
                columns = ['Category', 'Series1', 'Series2', 'Series3', 'Series4','Series5']
                )
df['合计'] = df.iloc[:, 1:].sum(axis=1)
df
# Out:
#      Category  Series1  Series2  Series3  Series4  Series5   合计
# 0  Category 1       50       50      200      300     -300  300
# 1  Category 2      100      110      250      460     -460  460
# 2  Category 3      200       90      200      490     -490  490
# 3  Category 4      350       50       60      460     -460  460
# 4  Category 5       50      150      400      600     -600  600
# 5  Category 6      250       50      260      560     -560  560

# %%
x = df.Category.to_list()
y1 = df.Series1.to_list()
y2 = df.Series2.to_list()
y3 = df.Series3.to_list()
y4 = df.Series4.to_list()
y5 = df.Series5.to_list()
y6 = df.合计.to_list()

from pyecharts.charts import Bar
bar = Bar(
    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='02条形图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )
)
# 添加横轴和纵轴的数据
bar.add_xaxis(xaxis_data=x)


bar.add_yaxis(series_name='Series1'
              ,y_axis=y1 
              ,color='#028599' # 绿色
             )   

bar.add_yaxis(series_name='Series2'
              ,y_axis=y2 
              ,color='#FF3F5F' # 红色
             )  

bar.add_yaxis(series_name='Series3'
              ,y_axis=y3
              ,color='#FEB834'  # 黄色
             )  


bar.reversal_axis()


# 设置图表全局配置项
bar.set_global_opts(
    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个条形图', 
                              pos_left='center'
                             )
    # 图例
    ,legend_opts=opts.LegendOpts(is_show=True, 
                                pos_top=30,  # 图例离上边界 30
                                border_color='transparent'# 图例边界颜色为 透明
                               
                               )  
     # X 坐标轴配置项
    ,xaxis_opts=opts.AxisOpts(type_='value'       # 'value': 数值轴，适用于连续数据。
                                                  # 'category': 类目轴，适用于离散的类目数据，为该类型时必须通过 data 设置类目数据。
                                                  # 'time': 时间轴，适用于连续的时序数据，与数值轴相比时间轴带有时间的格式化，在刻度计算上也有所不同，
                                                  # 例如会根据跨度的范围来决定使用月，星期，日还是小时范围的刻度。
                                                  # 'log' 对数轴。适用于对数数据。
                             ,name = 'y坐标轴名称' # 轴名称
                             ,is_show = True      # 是否显示x轴
                             ,name_location='center'  # 'start', 'middle' 或者 'center','end'
                             ,name_gap = 35      # 坐标轴名称与轴线之间的距离。
                             # 轴名称文字样式配置
                             ,name_textstyle_opts=opts.TextStyleOpts(# color='black'       # 文字颜色，使用默认
                                                                     # font_style='normal' # 字体风格
                                                                     # ,font_weight='normal'   # 字体粗细
                                                                     # ,font_family='Microsoft YaHei'        # 字体 'serif' , 'monospace', 'Arial', 'Courier New', 'Microsoft YaHei',
                                                                     font_size=15  # 字体大小
                                                                    
                                                                    
                                                                    )
                             )
                   
)

# 设置系列配置项
bar.set_series_opts(
    # 数据标签配置项
    label_opts=opts.LabelOpts(
        is_show = True,
        position = 'right'
    )
    
    # 标记线配置项
    ,markline_opts=opts.MarkLineOpts(
        data=[
                 opts.MarkLineItem(x=240, 
                                   name="xAxis=240", 
                                   # 线样式配置项
                                   linestyle_opts = opts.LineStyleOpts(color='#5470C6' # 线的颜色
                                                                       ,type_='dashed'  # 线型
                                                                      
                                                                      )
                                  
                                  ) 
             
             ]
    )
)
    


# 在jupyter 中显示
bar.load_javascript()
# jupyter渲染的图片往往不够清晰，导出再截图
html_name = '02条形图.html'
bar.render(html_name)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\02条形图.html'

# %%
# # render_notebook()显示不出来，就用下面这种# bar.render_notebook()
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="2d5f61bb03cc4b42b69832bb279eb974" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_2d5f61bb03cc4b42b69832bb279eb974 = echarts.init(
#             document.getElementById('2d5f61bb03cc4b42b69832bb279eb974'), 'white', {renderer: 'canvas'});
#         var option_2d5f61bb03cc4b42b69832bb279eb974 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#028599",
#         "#FF3F5F",
#         "#FEB834",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Series1",
#             "legendHoverLink": true,
#             "data": [
#                 50,
#                 100,
#                 200,
#                 350,
#                 50,
#                 250
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "xAxis=240",
#                         "xAxis": 240,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "dashed",
#                             "color": "#5470C6"
#                         }
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Series2",
#             "legendHoverLink": true,
#             "data": [
#                 50,
#                 110,
#                 90,
#                 50,
#                 150,
#                 50
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "xAxis=240",
#                         "xAxis": 240,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "dashed",
#                             "color": "#5470C6"
#                         }
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Series3",
#             "legendHoverLink": true,
#             "data": [
#                 200,
#                 250,
#                 200,
#                 60,
#                 400,
#                 260
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "xAxis=240",
#                         "xAxis": 240,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "dashed",
#                             "color": "#5470C6"
#                         }
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Series1",
#                 "Series2",
#                 "Series3"
#             ],
#             "selected": {
#                 "Series1": true,
#                 "Series2": true,
#                 "Series3": true
#             },
#             "show": true,
#             "top": 30,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "name": "y\u5750\u6807\u8f74\u540d\u79f0",
#             "show": true,
#             "scale": false,
#             "nameLoc

# %% [markdown]
# # 堆叠柱状图

# %%
df = pd.DataFrame(data = [['Category 1', 50, 50, 200, 300],
                         ['Category 2', 100, 110, 250, 460],
                         ['Category 3', 200, 90, 200, 490],
                         ['Category 4', 350, 50, 60, 460],
                         ['Category 5', 50, 150, 400, 600],
                         ['Category 6', 250, 50, 260, 560]],
                columns = ['Category', 'Series1', 'Series2', 'Series3', '合计']
                )
df
# Out:
#      Category  Series1  Series2  Series3   合计
# 0  Category 1       50       50      200  300
# 1  Category 2      100      110      250  460
# 2  Category 3      200       90      200  490
# 3  Category 4      350       50       60  460
# 4  Category 5       50      150      400  600
# 5  Category 6      250       50      260  560

# %%
x = df.Category.to_list()
y1 = df.Series1.to_list()
y2 = df.Series2.to_list()
y3 = df.Series3.to_list()
合计 = df.合计.to_list()


bar = Bar(
    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='03堆叠柱状图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )
)
bar.add_xaxis(x)
# stack的值相同的就会堆叠放置
bar.add_yaxis("Series1", y1, stack="stack1", color='#028599', bar_width=40)
bar.add_yaxis("Series2", y2, stack="stack1", color='#FF3F5F', bar_width=40)
bar.add_yaxis("Series3", y3, stack="stack1", color='#FEB834', bar_width=40)
bar.add_yaxis("合计",    合计, stack="stack2", bar_width=40)

# 设置图表全局配置项
bar.set_global_opts(
    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个堆叠的状图', 
                              pos_left='center'
                             )
    # 图例
    ,legend_opts=opts.LegendOpts(is_show=True, 
                                pos_top=30,  # 图例离上边界 30
                                border_color='transparent'# 图例边界颜色为 透明
                               
                               )
    
    # X 坐标轴配置项
    ,xaxis_opts=opts.AxisOpts(type_='category'     # 'value': 数值轴，适用于连续数据。
                                                  # 'category': 类目轴，适用于离散的类目数据，为该类型时必须通过 data 设置类目数据。
                                                  # 'time': 时间轴，适用于连续的时序数据，与数值轴相比时间轴带有时间的格式化，在刻度计算上也有所不同，
                                                  # 例如会根据跨度的范围来决定使用月，星期，日还是小时范围的刻度。
                                                  # 'log' 对数轴。适用于对数数据。
                             ,name = 'X坐标轴名称' # 轴名称
                             ,is_show = True      # 是否显示x轴
                             ,name_location='center'  # 'start', 'middle' 或者 'center','end'
                             ,name_gap = 35      # 坐标轴名称与轴线之间的距离。
                             # 轴名称文字样式配置
                             ,name_textstyle_opts=opts.TextStyleOpts(# color='black'       # 文字颜色，使用默认
                                                                     # font_style='normal' # 字体风格
                                                                     # ,font_weight='normal'   # 字体粗细
                                                                     # ,font_family='Microsoft YaHei'        # 字体 'serif' , 'monospace', 'Arial', 'Courier New', 'Microsoft YaHei',
                                                                     font_size=15  # 字体大小
                                                                    
                                                                    
                                                                    )
                            
                            
                            
                            )
    #  Y 坐标轴配置项
    ,yaxis_opts=opts.AxisOpts(type_='value'     # 'value': 数值轴，适用于连续数据。
                                                  # 'category': 类目轴，适用于离散的类目数据，为该类型时必须通过 data 设置类目数据。
                                                  # 'time': 时间轴，适用于连续的时序数据，与数值轴相比时间轴带有时间的格式化，在刻度计算上也有所不同，
                                                  # 例如会根据跨度的范围来决定使用月，星期，日还是小时范围的刻度。
                                                  # 'log' 对数轴。适用于对数数据。
                             ,name = 'Y坐标轴名称' # 轴名称
                             ,is_show = True      # 是否显示
                             ,name_location='center'  # 'start', 'middle' 或者 'center','end'
                             ,name_gap = 35       # 坐标轴名称与轴线之间的距离。
                             # ,max_=700            # y轴的最大值  
                              
                             # 轴名称文字样式配置
                             ,name_textstyle_opts=opts.TextStyleOpts(# color='black'       # 文字颜色,使用默认
                                                                     # font_style='normal' # 字体风格
                                                                     # font_weight='normal'   # 字体粗细
                                                                     # ,font_family='Microsoft YaHei'        # 字体 'serif' , 'monospace', 'Arial', 'Courier New', 'Microsoft YaHei',
                                                                     font_size=15  # 字体大小
                                                                    
                                 
                            
                                                                    
                                                                    )
                             )
    
                   
)

# 设置系列配置项
bar.set_series_opts(
    # 数据标签配置项
    label_opts=opts.LabelOpts(
        is_show = True,
        #position = 'bottom'
    )
)


bar.load_javascript() 
# jupyter渲染的图片往往不够清晰，导出再截图
html_name = '03堆叠柱状图.html'
bar.render(html_name)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\03堆叠柱状图.html'

# %%
# # render_notebook()显示不出来，就用下面这种# bar.render_notebook()
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="1940aa3d04f64d88bbe9f257383678e9" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_1940aa3d04f64d88bbe9f257383678e9 = echarts.init(
#             document.getElementById('1940aa3d04f64d88bbe9f257383678e9'), 'white', {renderer: 'canvas'});
#         var option_1940aa3d04f64d88bbe9f257383678e9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#028599",
#         "#FF3F5F",
#         "#FEB834",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Series1",
#             "legendHoverLink": true,
#             "data": [
#                 50,
#                 100,
#                 200,
#                 350,
#                 50,
#                 250
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barWidth": 40,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Series2",
#             "legendHoverLink": true,
#             "data": [
#                 50,
#                 110,
#                 90,
#                 50,
#                 150,
#                 50
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barWidth": 40,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Series3",
#             "legendHoverLink": true,
#             "data": [
#                 200,
#                 250,
#                 200,
#                 60,
#                 400,
#                 260
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barWidth": 40,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5408\u8ba1",
#             "legendHoverLink": true,
#             "data": [
#                 300,
#                 460,
#                 490,
#                 460,
#                 600,
#                 560
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack2",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barWidth": 40,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Series1",
#                 "Series2",
#                 "Series3",
#                 "\u5408\u8ba1"
#             ],
#             "selected": {
#                 "Series1": true,
#                 "Series2": true,
#                 "Series3": true,
#                 "\u5408\u8ba1": true
#             },
#             "show": true,
#             "top": 30,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "X\u5750\u6807\u8f74\u540d\u79f0",
#             "show": true,
#             "scale": false,
#             "nameLocation": "center",
#             "nameGap": 35,
#             "nameTextStyle": {
#                 "fontSize": 15
#             },
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Category 1",
#                 "Category 2",
#                 "Category 3",
#                 "Category 4",
#                 "Category 5",
#                 "Category 6"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "name": "Y\u5750\u6807\u8f74\u540d\u79f0",
#             "show": true,
#             "scale": fal

# %% [markdown]
# # 堆叠条形图

# %%
df = pd.DataFrame(data = [['Category 1', 50, 50, 200, 300],
                         ['Category 2', 100, 110, 250, 460],
                         ['Category 3', 200, 90, 200, 490],
                         ['Category 4', 350, 50, 60, 460],
                         ['Category 5', 50, 150, 400, 600],
                         ['Category 6', 250, 50, 260, 560]],
                columns = ['Category', 'Series1', 'Series2', 'Series3', '合计']
                )
df
# Out:
#      Category  Series1  Series2  Series3   合计
# 0  Category 1       50       50      200  300
# 1  Category 2      100      110      250  460
# 2  Category 3      200       90      200  490
# 3  Category 4      350       50       60  460
# 4  Category 5       50      150      400  600
# 5  Category 6      250       50      260  560

# %%
x = df.Category.to_list()
y1 = df.Series1.to_list()
y2 = df.Series2.to_list()
y3 = df.Series3.to_list()
合计 = df.合计.to_list()

from pyecharts.charts import Bar
bar = Bar(
    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='04堆叠条形图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )
)
# 添加横轴和纵轴的数据
bar.add_xaxis(xaxis_data=x)
bar.add_yaxis(series_name='Series1', y_axis=y1,  stack='1', color='#028599')   # 绿色
bar.add_yaxis(series_name='Series2', y_axis=y2,  stack='1', color='#FF3F5F')  # 红色
bar.add_yaxis(series_name='Series3', y_axis=y3,  stack='1', color='#FEB834')  # 黄色

bar.reversal_axis()


# 设置图表全局配置项
bar.set_global_opts(
    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个堆叠条形图', 
                              pos_left='center'
                             )
    # 图例
    ,legend_opts=opts.LegendOpts(is_show=True, 
                                pos_top=30,  # 图例离上边界 30
                                border_color='transparent'# 图例边界颜色为 透明
                               
                               )  
     # X 坐标轴配置项
    ,xaxis_opts=opts.AxisOpts(type_='value'       # 'value': 数值轴，适用于连续数据。
                                                  # 'category': 类目轴，适用于离散的类目数据，为该类型时必须通过 data 设置类目数据。
                                                  # 'time': 时间轴，适用于连续的时序数据，与数值轴相比时间轴带有时间的格式化，在刻度计算上也有所不同，
                                                  # 例如会根据跨度的范围来决定使用月，星期，日还是小时范围的刻度。
                                                  # 'log' 对数轴。适用于对数数据。
                             ,name = 'y坐标轴名称' # 轴名称
                             ,is_show = True      # 是否显示x轴
                             ,name_location='center'  # 'start', 'middle' 或者 'center','end'
                             ,name_gap = 35      # 坐标轴名称与轴线之间的距离。
                             # 轴名称文字样式配置
                             ,name_textstyle_opts=opts.TextStyleOpts(# color='black'       # 文字颜色，使用默认
                                                                     # font_style='normal' # 字体风格
                                                                     # ,font_weight='normal'   # 字体粗细
                                                                     # ,font_family='Microsoft YaHei'        # 字体 'serif' , 'monospace', 'Arial', 'Courier New', 'Microsoft YaHei',
                                                                     font_size=15  # 字体大小
                                                                    
                                                                    
                                                                    )
                             )
                   
)

# 设置系列配置项
bar.set_series_opts(
    # 数据标签配置项
    label_opts=opts.LabelOpts(
        is_show = True,
       #  position = 'right'
    )
)
    


# 在jupyter 中显示
bar.load_javascript()
# jupyter渲染的图片往往不够清晰，导出再截图
html_name = '04堆叠条形图.html'
bar.render(html_name)

# render_notebook()显示不出来，就用下面这种# bar.render_notebook()
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\04堆叠条形图.html'

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="00ec069b88f54288b2007635d487f91e" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_00ec069b88f54288b2007635d487f91e = echarts.init(
#             document.getElementById('00ec069b88f54288b2007635d487f91e'), 'white', {renderer: 'canvas'});
#         var option_00ec069b88f54288b2007635d487f91e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#028599",
#         "#FF3F5F",
#         "#FEB834",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Series1",
#             "legendHoverLink": true,
#             "data": [
#                 50,
#                 100,
#                 200,
#                 350,
#                 50,
#                 250
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Series2",
#             "legendHoverLink": true,
#             "data": [
#                 50,
#                 110,
#                 90,
#                 50,
#                 150,
#                 50
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Series3",
#             "legendHoverLink": true,
#             "data": [
#                 200,
#                 250,
#                 200,
#                 60,
#                 400,
#                 260
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Series1",
#                 "Series2",
#                 "Series3"
#             ],
#             "selected": {
#                 "Series1": true,
#                 "Series2": true,
#                 "Series3": true
#             },
#             "show": true,
#             "top": 30,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "name": "y\u5750\u6807\u8f74\u540d\u79f0",
#             "show": true,
#             "scale": false,
#             "nameLocation": "center",
#             "nameGap": 35,
#             "nameTextStyle": {
#                 "fontSize": 15
#             },
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Category 1",
#                 "Category 2",
#                 "Category 3",
#                 "Category 4",
#                 "Category 5",
#                 "Category 6"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u8fd9\u662f\u4e00\u4e2a\u5806\u53e0\u6761\u5f62\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_00ec069b88f54288b2007635d487f91e.setOption(option_00ec069b88f54288b2007635d487f91e);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 对比条形图

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.commons.utils import JsCode

# 准备数据
x_data = ['A1', 'B1', 'C1', 'D1', 'E1', 'F1']
y_data1 = [20, 30, 40, 50, 60, 100]
y_data2 = [15, 25, 35, 45, 55, 100]

# 创建Bar实例
bar = Bar(
    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='06对比条形图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )

)

# 添加数据
bar.add_xaxis(x_data)
bar.add_yaxis("Series1", 
              y_data1, 
              stack="stack1", 
              color='#028599', 
              label_opts=opts.LabelOpts(formatter="{c}")) # c代表限制的是 值


bar.add_yaxis("Series2", 
              [-i for i in y_data2], 
              color='#FF3F5F', 
              stack="stack1",  
              label_opts=opts.LabelOpts(is_show=True,
                                           # 利用回调函数去除负号
                                           formatter=JsCode(
                                               """
                                               function(params) {
                                                   return -(params.data)
                                               }
                                               """

                                           )


                                          ))
bar.reversal_axis()

# 设置全局配置项
bar.set_global_opts(
    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个对比条形图', 
                              pos_left='center'
                             ),
    # 图例
    legend_opts=opts.LegendOpts(is_show=True, 
                                pos_top=30,  # 图例离上边界 30
                                border_color='transparent'# 图例边界颜色为 透明
                               
                               ),  
    
    
    
    
    # x坐标轴不显示
    xaxis_opts=opts.AxisOpts(is_show=False),
    
    # y轴
    yaxis_opts=opts.AxisOpts(is_show=True, 
                            # 坐标轴刻度线配置项
                            axisline_opts = opts.AxisLineOpts(is_show=False),
                             
                            # 坐标轴刻度配置项
                            axistick_opts = opts.AxisTickOpts(is_show=False),
                             
                            # 分割线配置项
                            splitline_opts=opts.SplitLineOpts(is_show=True)
                            )
)

# 渲染图表
bar.load_javascript()
html_name = '05对比条形图.html'
bar.render(html_name)

# render_notebook()显示不出来，就用下面这种# bar.render_notebook()
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\05对比条形图.html'

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="a3808f38541d4b8abb7d9f2ac3714bd4" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_a3808f38541d4b8abb7d9f2ac3714bd4 = echarts.init(
#             document.getElementById('a3808f38541d4b8abb7d9f2ac3714bd4'), 'white', {renderer: 'canvas'});
#         var option_a3808f38541d4b8abb7d9f2ac3714bd4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#028599",
#         "#FF3F5F",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Series1",
#             "legendHoverLink": true,
#             "data": [
#                 20,
#                 30,
#                 40,
#                 50,
#                 60,
#                 100
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{c}"
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Series2",
#             "legendHoverLink": true,
#             "data": [
#                 -15,
#                 -25,
#                 -35,
#                 -45,
#                 -55,
#                 -100
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter":                                                function(params) {                                                   return -(params.data)                                               }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Series1",
#                 "Series2"
#             ],
#             "selected": {
#                 "Series1": true,
#                 "Series2": true
#             },
#             "show": true,
#             "top": 30,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "A1",
#                 "B1",
#                 "C1",
#                 "D1",
#                 "E1",
#                 "F1"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u8fd9\u662f\u4e00\u4e2a\u5bf9\u6bd4\u6761\u5f62\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_a3808f38541d4b8abb7d9f2ac3714bd4.setOption(option_a3808f38541d4b8abb7d9f2ac3714bd4);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 饼图

# %%
df = pd.DataFrame(data=[['河马', 68],
                         ['蟒蛇', 95],
                         ['老虎', 85],
                         ['大象', 77],
                         ['兔子', 80],
                         ['熊猫', 124],
                         ['狮子', 25]]
                  
                  ,columns=['种类', '数值']
                 
                 )
df = df.sort_values('数值', ascending=False)
df
# Out:
#    种类   数值
# 5  熊猫  124
# 1  蟒蛇   95
# 2  老虎   85
# 4  兔子   80
# 3  大象   77
# 0  河马   68
# 6  狮子   25

# %%
df.数值/df.数值.sum()
# Out:
# 5    0.223827
# 1    0.171480
# 2    0.153430
# 4    0.144404
# 3    0.138989
# 0    0.122744
# 6    0.045126
# Name: 数值, dtype: float64

# %%
df.values.tolist()
# Out:
# [['熊猫', 124],
#  ['蟒蛇', 95],
#  ['老虎', 85],
#  ['兔子', 80],
#  ['大象', 77],
#  ['河马', 68],
#  ['狮子', 25]]

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie

pie = Pie(
    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='05饼图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )

)

pie.add(series_name='',data_pair=df.values.tolist()
        # radius=0.7
        # ,rosetype='radius' # 是否变成玫瑰图
        ,percent_precision=1 # 百分比小数位数
       
       )

# 全局配置项
pie.set_global_opts(

    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个饼图', 
                              pos_left='center'
                             ),
    # 图例
    legend_opts=opts.LegendOpts(is_show=True 
                                ,pos_top=150  # 图例离上边界 30
                                ,pos_left=50
                                ,orient = 'vertical'   #  可选：'horizontal', 'vertical'#
                                ,border_color='transparent'# 图例边界颜色为 透明
                               
                               ),  

)


# 设置系列配置项
pie.set_series_opts(
    # 数据标签配置项
    label_opts=opts.LabelOpts(
        is_show = True,
        # position = 'top',
        #{a}（系列名称），{b}（数据项名称），{c}（数值）, {d}（百分比）
        formatter="{b}：{c} \n\n{d}%"
        
    )
)

pie.load_javascript()
html_name = '饼图.html'
pie.render(html_name)

# render_notebook()显示不出来，就用下面这种# bar.render_notebook()
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\饼图.html'

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="aaf6c0e171ad4b65aba119aa4c3f2dbc" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_aaf6c0e171ad4b65aba119aa4c3f2dbc = echarts.init(
#             document.getElementById('aaf6c0e171ad4b65aba119aa4c3f2dbc'), 'white', {renderer: 'canvas'});
#         var option_aaf6c0e171ad4b65aba119aa4c3f2dbc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 1,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 124
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 95
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 25
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}\uff1a{c} \n\n{d}%"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u718a\u732b",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5154\u5b50",
#                 "\u5927\u8c61",
#                 "\u6cb3\u9a6c",
#                 "\u72ee\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "left": 50,
#             "top": 150,
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u8fd9\u662f\u4e00\u4e2a\u997c\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_aaf6c0e171ad4b65aba119aa4c3f2dbc.setOption(option_aaf6c0e171ad4b65aba119aa4c3f2dbc);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 玫瑰图

# %%
df = pd.DataFrame(data=[['河马', 68],
                         ['蟒蛇', 95],
                         ['老虎', 85],
                         ['大象', 77],
                         ['兔子', 80],
                         ['熊猫', 124],
                         ['狮子', 25]]
                  
                  ,columns=['种类', '数值']
                 
                 )
df = df.sort_values('数值', ascending=False)
df
# Out:
#    种类   数值
# 5  熊猫  124
# 1  蟒蛇   95
# 2  老虎   85
# 4  兔子   80
# 3  大象   77
# 0  河马   68
# 6  狮子   25

# %%
df.values.tolist()
# Out:
# [['熊猫', 124],
#  ['蟒蛇', 95],
#  ['老虎', 85],
#  ['兔子', 80],
#  ['大象', 77],
#  ['河马', 68],
#  ['狮子', 25]]

# %%
pie = Pie(
    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='玫瑰图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )

)

pie.add(series_name='',data_pair=df.values.tolist()
        # radius=0.7
        ,rosetype='radius' # 是否变成玫瑰图
        ,percent_precision=1 # 百分比小数位数
       
       )

# 全局配置项
pie.set_global_opts(

    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个玫瑰图', 
                              pos_left='center'
                             ),
    # 图例
    legend_opts=opts.LegendOpts(is_show=True 
                                ,pos_top=150  # 图例离上边界 30
                                ,pos_left=50
                                ,orient = 'vertical'   #  可选：'horizontal', 'vertical'#
                                ,border_color='transparent'# 图例边界颜色为 透明
                               
                               ),  

)


# 设置系列配置项
pie.set_series_opts(
    # 数据标签配置项
    label_opts=opts.LabelOpts(
        is_show = True,
        # position = 'top',
        #{a}（系列名称），{b}（数据项名称），{c}（数值）, {d}（百分比）
        formatter="{b}：{c} \n\n{d}%"
        
    )
)
pie.render('玫瑰图.html')
pie.load_javascript()
html_name = '玫瑰图.html'
pie.render(html_name)
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\玫瑰图.html'

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="400599506482487e8cf9ab3627e5f117" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_400599506482487e8cf9ab3627e5f117 = echarts.init(
#             document.getElementById('400599506482487e8cf9ab3627e5f117'), 'white', {renderer: 'canvas'});
#         var option_400599506482487e8cf9ab3627e5f117 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 1,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 124
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 95
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 25
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}\uff1a{c} \n\n{d}%"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u718a\u732b",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5154\u5b50",
#                 "\u5927\u8c61",
#                 "\u6cb3\u9a6c",
#                 "\u72ee\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "left": 50,
#             "top": 150,
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u8fd9\u662f\u4e00\u4e2a\u73ab\u7470\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_400599506482487e8cf9ab3627e5f117.setOption(option_400599506482487e8cf9ab3627e5f117);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 圆环图

# %%
df = pd.DataFrame(data=[['河马', 68],
                         ['蟒蛇', 95],
                         ['老虎', 85],
                         ['大象', 77],
                         ['兔子', 80],
                         ['熊猫', 124],
                         ['狮子', 25]]
                  
                  ,columns=['种类', '数值']
                 
                 )
df = df.sort_values('数值', ascending=False)
df
# Out:
#    种类   数值
# 5  熊猫  124
# 1  蟒蛇   95
# 2  老虎   85
# 4  兔子   80
# 3  大象   77
# 0  河马   68
# 6  狮子   25

# %%
pie = Pie(
    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='圆环图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )

)

pie.add(series_name='',data_pair=df.values.tolist()
        # 饼图的半径，数组的第一项是内半径，第二项是外半径
        ,radius=["50%", "75%"]
        ,center=["50%", "50%"]
        #,rosetype='radius' # 是否变成玫瑰图
        ,percent_precision=1 # 百分比小数位数
       
       )

# 全局配置项
pie.set_global_opts(

    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个圆环图', 
                              pos_left='center'
                             ),
    # 图例
    legend_opts=opts.LegendOpts(is_show=True 
                                ,pos_top=150  # 图例离上边界 30
                                ,pos_left=50
                                ,orient = 'vertical'   #  可选：'horizontal', 'vertical'#
                                ,border_color='transparent'# 图例边界颜色为 透明
                               
                               ),  

)


# 设置系列配置项
pie.set_series_opts(
    # 数据标签配置项
    label_opts=opts.LabelOpts(
        is_show = True,
        # position = 'top',
        #{a}（系列名称），{b}（数据项名称），{c}（数值）, {d}（百分比）
        formatter="{b}：{c} \n\n{d}%"
        
    )
)

pie.load_javascript()
html_name = '圆环图.html'
pie.render(html_name)
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\圆环图.html'

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="b7291bb81fc5411cbf33c4a3cffde2a2" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_b7291bb81fc5411cbf33c4a3cffde2a2 = echarts.init(
#             document.getElementById('b7291bb81fc5411cbf33c4a3cffde2a2'), 'white', {renderer: 'canvas'});
#         var option_b7291bb81fc5411cbf33c4a3cffde2a2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 1,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 124
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 95
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 25
#                 }
#             ],
#             "radius": [
#                 "50%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}\uff1a{c} \n\n{d}%"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u718a\u732b",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5154\u5b50",
#                 "\u5927\u8c61",
#                 "\u6cb3\u9a6c",
#                 "\u72ee\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "left": 50,
#             "top": 150,
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u8fd9\u662f\u4e00\u4e2a\u5706\u73af\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_b7291bb81fc5411cbf33c4a3cffde2a2.setOption(option_b7291bb81fc5411cbf33c4a3cffde2a2);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 散点图

# %% [markdown]
# ## x是数值

# %%
x = np.linspace(-10, 10, 100).tolist()
y1 = np.sin(x).tolist()
y2 = np.cos(x).tolist()

from pyecharts.charts import Scatter
from pyecharts import options as opts
from pyecharts.commons.utils import JsCode

sc = Scatter(    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='散点图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )
)

sc.add_xaxis(xaxis_data=x)
sc.add_yaxis(series_name='sin', y_axis=y1, color='#028599' )
sc.add_yaxis(series_name='tanh', y_axis=y2, color='#FF3F5F')

# 全局配置项
sc.set_global_opts(
    
    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个散点图', 
                              pos_left='center'
                             ),
    # 图例
    legend_opts=opts.LegendOpts(is_show=True 
                                ,pos_top=30  # 图例离上边界 30
                                # ,pos_left=50
                                # ,orient = 'vertical'   #  可选：'horizontal', 'vertical'#
                                ,border_color='transparent'# 图例边界颜色为 透明
                               
                               ),  
    
    # x轴配置项
    xaxis_opts=opts.AxisOpts(
        # x轴数值为数值型
        type_="value",     #  如果x是数值型，这里要指定为 value
    )
)

# 系列配置项
sc.set_series_opts(
    # 标签配置项
    label_opts=opts.LabelOpts(
        is_show=False
    )
)

sc.load_javascript()

html_name = '散点图1.html'
sc.render(html_name)
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\散点图1.html'

# %%
sc.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="f01c3014d5f3482aa58f97132a932869" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_f01c3014d5f3482aa58f97132a932869 = echarts.init(
#             document.getElementById('f01c3014d5f3482aa58f97132a932869'), 'white', {renderer: 'canvas'});
#         var option_f01c3014d5f3482aa58f97132a932869 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#028599",
#         "#FF3F5F",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "sin",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     -10.0,
#                     0.5440211108893698
#                 ],
#                 [
#                     -9.797979797979798,
#                     0.3645987336558887
#                 ],
#                 [
#                     -9.595959595959595,
#                     0.1703468323280965
#                 ],
#                 [
#                     -9.393939393939394,
#                     -0.03083367906114098
#                 ],
#                 [
#                     -9.191919191919192,
#                     -0.23076007532505177
#                 ],
#                 [
#                     -8.98989898989899,
#                     -0.4213006405886069
#                 ],
#                 [
#                     -8.787878787878787,
#                     -0.5947054140244975
#                 ],
#                 [
#                     -8.585858585858587,
#                     -0.7439214082568444
#                 ],
#                 [
#                     -8.383838383838384,
#                     -0.8628794793817836
#                 ],
#                 [
#                     -8.181818181818182,
#                     -0.9467411805833543
#                 ],
#                 [
#                     -7.979797979797979,
#                     -0.9920955589323228
#                 ],
#                 [
#                     -7.777777777777778,
#                     -0.9970978909438748
#                 ],
#                 [
#                     -7.575757575757576,
#                     -0.9615447140268237
#                 ],
#                 [
#                     -7.373737373737374,
#                     -0.8868821020290788
#                 ],
#                 [
#                     -7.171717171717171,
#                     -0.7761468482835805
#                 ],
#                 [
#                     -6.96969696969697,
#                     -0.6338429484489058
#                 ],
#                 [
#                     -6.767676767676768,
#                     -0.46575840702565247
#                 ],
#                 [
#                     -6.565656565656566,
#                     -0.27872981867755725
#                 ],
#                 [
#                     -6.363636363636363,
#                     -0.08036429967028173
#                 ],
#                 [
#                     -6.161616161616162,
#                     0.12126992053716677
#                 ],
#                 [
#                     -5.959595959595959,
#                     0.31797166281061867
#                 ],
#                 [
#                     -5.757575757575758,
#                     0.5017403693939113
#                 ],
#                 [
#                     -5.555555555555555,
#                     0.6651015149788224
#                 ],
#                 [
#                     -5.353535353535354,
#                     0.8014106221689696
#                 ],
#                 [
#                     -5.151515151515151,
#                     0.9051235159501367
#                 ],
#                 [
#                     -4.94949494949495,
#                     0.9720218249588334
#                 ],
#                 [
#                     -4.747474747474747,
#                     0.9993845576124357
#                 ],
#                 [
#                     -4.545454545454546,
#                     0.9860987744909298
#                 ],
#                 [
#                     -4.343434343434343,
#                     0.9327048555318336
#                 ],
#                 [
#                     -4.141414141414142,
#                     0.8413745208608705
#                 ],
#                 [
#                     -3.9393939393939394,
#                     0.7158224992291902
#                 ],
#                 [
#                     -3.737373737373738,
#                     0.5611554368152021
#                 ],
#                 [
#                     -3.5353535353535355,
#                     0.38366419180611233
#                 ],
#                 [
#                     -3.333333333333333,
#                     0.19056796287548494
#                 ],
#                 [
#                     -3.1313131313131315,
#                     -0.010279341240534253
#                 ],
#                 [
#                     -2.929292929292929,
#                     -0.2107085480771929
#                 ],
#                 [
#                     -2.7272727272727275,
#                     -0.40256749066949615
#                 ],
#                 [
#                     -2.525252525252525,
#                     -0.5780525851065732
#                 ],
#                 [
#                     -2.3232323232323235,
#                     -0.7300262299764461
#                 ],
#                 [
#                     -2.121212121212121,
#                     -0.8523071179396752
#                 ],
#                 [
#                     -1.9191919191919187,
#                     -0.9399216514301314
#                 ],
#                 [
#                     -1.717171717171718,
#                     -0.9893062365143399
#                 ],
#                 [
#                     -1.5151515151515156,
#                     -0.9984522269003896
#                 ],
#                 [
#                     -1.3131313131313131,
#                     -0.9669876227092996
#                 ],
#                 [
#                     -1.1111111111111107,
#                     -0.8961922010299561
#                 ],
#                 [
#                     -0.9090909090909101,
#                     -0.788945462844258
#                 ],
#                 [
#                     -0.7070707070707076,
#                     -0.649609513505707
#                 ],
#                 [
#                     -0.5050505050505052,
#                     -0.48385164043793477
#                 ],
#                 [
#                     -0.30303030303030276,
#                     -0.2984138044476408
#                 ],
#                 [
#                     -0.10101010101010033,
#                     -0.10083842025810393
#                 ],
#                 [
#                     0.10101010101010033,
#                     0.10083842025810393
#                 ],
#                 [
#                     0.30303030303030276,
#                     0.2984138044476408
#                 ],
#                 [
#                     0.5050505050505052,
#                     0.48385164043793477
#                 ],
#                 [
#                     0.7070707070707076,
#                     0.649609513505707
#                 ],
#                 [
#                     0.9090909090909083,
#                     0.7889454628442569
#                 ],
#                 [
#                     1.1111111111111107,
#                     0.8961922010299561
#                 ],
#                 [
#                     1.3131313131313131,
#                     0.9669876227092996
#                 ],
#                 [
#                     1.5151515151515156,
#                     0.9984522269003896
#                 ],
#                 [
#                     1.7171717171717162,
#                     0.9893062365143402
#                 ],

# %% [markdown]
# ## x是类别

# %% [markdown]
# ### 原坐标

# %%
df = pd.DataFrame(data=[['河马', 68],
                         ['蟒蛇', 95],
                         ['老虎', 85],
                         ['大象', 77],
                         ['兔子', 80],
                         ['熊猫', 124],
                         ['狮子', 25]]
                  
                  ,columns=['种类', '数值']
                 
                 )
df = df.sort_values('数值', ascending=False)
df
# Out:
#    种类   数值
# 5  熊猫  124
# 1  蟒蛇   95
# 2  老虎   85
# 4  兔子   80
# 3  大象   77
# 0  河马   68
# 6  狮子   25

# %%
x = df.种类.to_list()
y = df.数值.to_list()


from pyecharts.charts import Scatter
from pyecharts import options as opts

sc = Scatter(    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='散点图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )
)

sc.add_xaxis(xaxis_data=x)
sc.add_yaxis(series_name='', 
             y_axis=[list(z) for z in zip(y, x)],
             color='#028599', # 绿色
             symbol_size=50,# 散点大小
            
    )

# 全局配置项
sc.set_global_opts(
    
    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个散点图', 
                              pos_left='center'
                             ),
    # 图例
    legend_opts=opts.LegendOpts(is_show=True 
                                ,pos_top=30  # 图例离上边界 30
                                # ,pos_left=50
                                # ,orient = 'vertical'   #  可选：'horizontal', 'vertical'#
                                ,border_color='transparent'# 图例边界颜色为 透明
                               
                               ),  
    
    # x轴配置项
    xaxis_opts=opts.AxisOpts( 
        is_show=False,
        # x轴数值为种类
        type_="category",     #  如果x是数值型，这里要指定为 value
    ),
    
    # tooltip_opts=opts.TooltipOpts( is_show=True,
    #         formatter=JsCode(
    #             "function (params) {return params.value[0] + ' : ' + params.value[1];}"
    #         )
    
    # ),
    visualmap_opts=opts.VisualMapOpts( 
        is_show=False,  # -------  是否显示映射的标识
        type_="color", 
        max_=150, 
        min_=20, 
        dimension=1,
        range_color=['#028599',  '#FEB834','#FF3F5F',]# 颜色梯度，绿色 黄 红
        ),
    

)

# 系列配置项
sc.set_series_opts(
    # 标签配置项
    label_opts=opts.LabelOpts(
         is_show=True,
         # position = 'top',
         font_size=8, # 字体大小
         formatter=JsCode(
                     "function (params) {return params.value[0] + ' : ' + params.value[1];}"
                 ),
        
    )
)

sc.load_javascript()

html_name = '散点图2.html'
sc.render(html_name)
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\散点图2.html'

# %%
sc.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="f9eebd13c63b44ef9f6360ef46b31092" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_f9eebd13c63b44ef9f6360ef46b31092 = echarts.init(
#             document.getElementById('f9eebd13c63b44ef9f6360ef46b31092'), 'white', {renderer: 'canvas'});
#         var option_f9eebd13c63b44ef9f6360ef46b31092 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#028599",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 50,
#             "data": [
#                 [
#                     "\u718a\u732b",
#                     124,
#                     "\u718a\u732b"
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     95,
#                     "\u87d2\u86c7"
#                 ],
#                 [
#                     "\u8001\u864e",
#                     85,
#                     "\u8001\u864e"
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     80,
#                     "\u5154\u5b50"
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     77,
#                     "\u5927\u8c61"
#                 ],
#                 [
#                     "\u6cb3\u9a6c",
#                     68,
#                     "\u6cb3\u9a6c"
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     25,
#                     "\u72ee\u5b50"
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "fontSize": 8,
#                 "formatter": function (params) {return params.value[0] + ' : ' + params.value[1];}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "top": 30,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u718a\u732b",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5154\u5b50",
#                 "\u5927\u8c61",
#                 "\u6cb3\u9a6c",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u8fd9\u662f\u4e00\u4e2a\u6563\u70b9\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": false,
#         "type": "continuous",
#         "min": 20,
#         "max": 150,
#         "inRange": {
#             "color": [
#                 "#028599",
#                 "#FEB834",
#                 "#FF3F5F"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 1,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#         chart_f9eebd13c63b44ef9f6360ef46b31092.setOption(option_f9eebd13c63b44ef9f6360ef46b31092);
#     </script>
# </body>
# </html>

# %% [markdown]
# ### 标记线
# - 使用标记线，然后隐藏原来的坐标轴即可

# %%
df = pd.DataFrame(data=[['河马', 68, 79],
                         ['蟒蛇', 95, 30],
                         ['老虎', 85, 10],
                         ['大象', 77, 50],
                         ['兔子', 80, 100],
                         ['熊猫', 124, 37],
                         ['狮子', 25, 59]]
                  
                  ,columns=['种类', '数值1', '数值2']
                 
                 )
df = df.sort_values('数值1', ascending=False)
df
# Out:
#    种类  数值1  数值2
# 5  熊猫  124   37
# 1  蟒蛇   95   30
# 2  老虎   85   10
# 4  兔子   80  100
# 3  大象   77   50
# 0  河马   68   79
# 6  狮子   25   59

# %%
x = df.种类.to_list()
y1 = df.数值1.to_list()
y2 = df.数值2.to_list()

from pyecharts.charts import Scatter
from pyecharts import options as opts

sc = Scatter(    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='散点图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )
)

sc.add_xaxis(xaxis_data=y1)
sc.add_yaxis(series_name='', 
             y_axis=[list(z) for z in zip(y2, x)],
             #y_axis=y2,
             color='#028599', # 绿色
             symbol_size=55,# 散点大小
            
    )

# 全局配置项
sc.set_global_opts(
    
    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个散点图', 
                              pos_left='center'
                             ),
    # 图例
    legend_opts=opts.LegendOpts(is_show=True 
                                ,pos_top=30  # 图例离上边界 30
                                # ,pos_left=50
                                # ,orient = 'vertical'   #  可选：'horizontal', 'vertical'#
                                ,border_color='transparent'# 图例边界颜色为 透明
                               
                               ),  
    
    # x轴配置项
    xaxis_opts=opts.AxisOpts( 
        is_show=True,
        # x轴数值为种类
        type_="value",     #  如果x是数值型，这里要指定为 value
    ),
    # x轴配置项
    yaxis_opts=opts.AxisOpts( 
        is_show=True,
        # x轴数值为种类
        type_="value",     #  如果x是数值型，这里要指定为 value
    ),
    
    
    
    
    # tooltip_opts=opts.TooltipOpts( is_show=True,
    #         formatter=JsCode(
    #             "function (params) {return params.value[0] + ' : ' + params.value[1];}"
    #         )
    
    # ),
    visualmap_opts=opts.VisualMapOpts( 
        is_show=False,  # -------  是否显示映射的标识
        type_="color", 
        max_=150, 
        min_=20, 
        dimension=1,
        range_color=['#028599',  '#FEB834','#FF3F5F',]# 颜色梯度，绿色 黄 红
        ),
    

)

# 系列配置项
sc.set_series_opts(
    # 标签配置项
    label_opts=opts.LabelOpts(
         is_show=True,
         # position = 'top',
         font_size=8, # 字体大小
        
         
         # params.value[0]指的是传入的y1，，就是x 轴接受到的东西
         # params.value[1]指的是传入的y2，y轴接受的东西
         # params.value[2]指的是传入的x，就是Y轴接受的标签
         formatter=JsCode(
                     '''function (params) {
                         return params.value[2]+','+
                                params.value[0]+','+
                                params.value[1];
                       }'''
                 ),       
    ),
    
    # 标记线配置项
    markline_opts=opts.MarkLineOpts(
        data=[
                 opts.MarkLineItem(x=80, 
                                   name="xAxis=80", 
                                   # 线样式配置项
                                   linestyle_opts = opts.LineStyleOpts(color='#5470C6' # 线的颜色
                                                                       ,type_='dashed'  # 线型
                                                                      
                                                                      )
                                  
                                  ),
                 opts.MarkLineItem(y=50, 
                                   name="yAxis=50", 
                                   # 线样式配置项
                                   linestyle_opts = opts.LineStyleOpts(color='#5470C6' # 线的颜色
                                                                       ,type_='dashed'  # 线型
                                                                      
                                                                      )
                                  
                                  ) 
             
             ]
        
    )
    
    
)

sc.load_javascript()

html_name = '散点图3.html'
sc.render(html_name)
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\散点图3.html'

# %%
sc.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="a3919f5b8bfe45df8f8596ad27c56861" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_a3919f5b8bfe45df8f8596ad27c56861 = echarts.init(
#             document.getElementById('a3919f5b8bfe45df8f8596ad27c56861'), 'white', {renderer: 'canvas'});
#         var option_a3919f5b8bfe45df8f8596ad27c56861 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#028599",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 55,
#             "data": [
#                 [
#                     124,
#                     37,
#                     "\u718a\u732b"
#                 ],
#                 [
#                     95,
#                     30,
#                     "\u87d2\u86c7"
#                 ],
#                 [
#                     85,
#                     10,
#                     "\u8001\u864e"
#                 ],
#                 [
#                     80,
#                     100,
#                     "\u5154\u5b50"
#                 ],
#                 [
#                     77,
#                     50,
#                     "\u5927\u8c61"
#                 ],
#                 [
#                     68,
#                     79,
#                     "\u6cb3\u9a6c"
#                 ],
#                 [
#                     25,
#                     59,
#                     "\u72ee\u5b50"
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "fontSize": 8,
#                 "formatter": function (params) {                         return params.value[2]+','+                                params.value[0]+','+                                params.value[1];                       }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "xAxis=80",
#                         "xAxis": 80,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "dashed",
#                             "color": "#5470C6"
#                         }
#                     },
#                     {
#                         "name": "yAxis=50",
#                         "yAxis": 50,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "dashed",
#                             "color": "#5470C6"
#                         }
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "top": 30,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 124,
#                 95,
#                 85,
#                 80,
#                 77,
#                 68,
#                 25
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u8fd9\u662f\u4e00\u4e2a\u6563\u70b9\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": false,
#         "type": "continuous",
#         "min": 20,
#         "max": 150,
#         "inRange": {
#             "color": [
#                 "#028599",
#                 "#FEB834",
#                 "#FF3F5F"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 1,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#         chart_a3919f5b8bfe45df8f8596ad27c56861.setOption(option_a3919f5b8bfe45df8f8596ad27c56861);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 气泡图

# %%
df = pd.DataFrame(data=[['河马', 68, 79],
                         ['蟒蛇', 95, 30],
                         ['老虎', 85, 10],
                         ['大象', 77, 50],
                         ['兔子', 80, 100],
                         ['熊猫', 124, 37],
                         ['狮子', 25, 59]]
                  
                  ,columns=['种类', '数值1', '数值2']
                 
                 )
df = df.sort_values('数值1', ascending=False)
df
# Out:
#    种类  数值1  数值2
# 5  熊猫  124   37
# 1  蟒蛇   95   30
# 2  老虎   85   10
# 4  兔子   80  100
# 3  大象   77   50
# 0  河马   68   79
# 6  狮子   25   59

# %%
x = df.种类.to_list()
y1 = df.数值1.to_list()
y2 = df.数值2.to_list()

from pyecharts.charts import Scatter
from pyecharts import options as opts

sc = Scatter(    # 初始化配置项
    init_opts = opts.InitOpts(
        page_title='散点图'  # 网页标题
        # ,width = '1100px'
        # ,height = '700px'
    )
)

sc.add_xaxis(xaxis_data=y1)
sc.add_yaxis(series_name='', 
             y_axis=[list(z) for z in zip(y2, x)],
             #y_axis=y2,
             color='#028599', # 绿色
             symbol_size=55,# 散点大小
            
    )

# 全局配置项
sc.set_global_opts(
    
    # 图表标题
    title_opts=opts.TitleOpts(is_show=True, 
                              title='这是一个散点图', 
                              pos_left='center'
                             ),
    # 图例
    legend_opts=opts.LegendOpts(is_show=True 
                                ,pos_top=30  # 图例离上边界 30
                                # ,pos_left=50
                                # ,orient = 'vertical'   #  可选：'horizontal', 'vertical'#
                                ,border_color='transparent'# 图例边界颜色为 透明
                               
                               ),  
    
    # x轴配置项
    xaxis_opts=opts.AxisOpts( 
        is_show=True,
        # x轴数值为种类
        type_="value",     #  如果x是数值型，这里要指定为 value
    ),
    # x轴配置项
    yaxis_opts=opts.AxisOpts( 
        is_show=True,
        # x轴数值为种类
        type_="value",     #  如果x是数值型，这里要指定为 value
    ),
    
    
    
    
    # tooltip_opts=opts.TooltipOpts( is_show=True,
    #         formatter=JsCode(
    #             "function (params) {return params.value[0] + ' : ' + params.value[1];}"
    #         )
    
    # ),
    visualmap_opts=opts.VisualMapOpts( 
        is_show=False,  # -------  是否显示映射的标识
        type_="size", 
        max_=150, 
        min_=20, 
        dimension=1,
        # range_color=['#028599',  '#FEB834','#FF3F5F',]# 颜色梯度，绿色 黄 红
        ),
    

)

# 系列配置项
sc.set_series_opts(
    # 标签配置项
    label_opts=opts.LabelOpts(
         is_show=True,
         position = 'top',
         font_size=8, # 字体大小
        
         
         # params.value[0]指的是传入的y1，，就是x 轴接受到的东西
         # params.value[1]指的是传入的y2，y轴接受的东西
         # params.value[2]指的是传入的x，就是Y轴接受的标签
         formatter=JsCode(
                     '''function (params) {
                         return params.value[2]+','+
                                params.value[0]+','+
                                params.value[1];
                       }'''
                 ),       
    ),
    
    # 标记线配置项
    markline_opts=opts.MarkLineOpts(
        data=[
                 opts.MarkLineItem(x=80, 
                                   name="xAxis=80", 
                                   # 线样式配置项
                                   linestyle_opts = opts.LineStyleOpts(color='#5470C6' # 线的颜色
                                                                       ,type_='dashed'  # 线型
                                                                      
                                                                      )
                                  
                                  ),
                 opts.MarkLineItem(y=50, 
                                   name="yAxis=50", 
                                   # 线样式配置项
                                   linestyle_opts = opts.LineStyleOpts(color='#5470C6' # 线的颜色
                                                                       ,type_='dashed'  # 线型
                                                                      
                                                                      )
                                  
                                  ) 
             
             ]
        
    )
    
    
)

sc.load_javascript()

html_name = '散点图4.html'
sc.render(html_name)
# from IPython.display import IFrame
# IFrame(src=html_name, width=950, height=520)
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\散点图4.html'

# %%
sc.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="a7410e0b5bf64861ac41008afcac2021" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_a7410e0b5bf64861ac41008afcac2021 = echarts.init(
#             document.getElementById('a7410e0b5bf64861ac41008afcac2021'), 'white', {renderer: 'canvas'});
#         var option_a7410e0b5bf64861ac41008afcac2021 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#028599",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 55,
#             "data": [
#                 [
#                     124,
#                     37,
#                     "\u718a\u732b"
#                 ],
#                 [
#                     95,
#                     30,
#                     "\u87d2\u86c7"
#                 ],
#                 [
#                     85,
#                     10,
#                     "\u8001\u864e"
#                 ],
#                 [
#                     80,
#                     100,
#                     "\u5154\u5b50"
#                 ],
#                 [
#                     77,
#                     50,
#                     "\u5927\u8c61"
#                 ],
#                 [
#                     68,
#                     79,
#                     "\u6cb3\u9a6c"
#                 ],
#                 [
#                     25,
#                     59,
#                     "\u72ee\u5b50"
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 8,
#                 "formatter": function (params) {                         return params.value[2]+','+                                params.value[0]+','+                                params.value[1];                       }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "xAxis=80",
#                         "xAxis": 80,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "dashed",
#                             "color": "#5470C6"
#                         }
#                     },
#                     {
#                         "name": "yAxis=50",
#                         "yAxis": 50,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "dashed",
#                             "color": "#5470C6"
#                         }
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "top": 30,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "transparent",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 124,
#                 95,
#                 85,
#                 80,
#                 77,
#                 68,
#                 25
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u8fd9\u662f\u4e00\u4e2a\u6563\u70b9\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": false,
#         "type": "continuous",
#         "min": 20,
#         "max": 150,
#         "inRange": {
#             "symbolSize": [
#                 20,
#                 50
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 1,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#         chart_a7410e0b5bf64861ac41008afcac2021.setOption(option_a7410e0b5bf64861ac41008afcac2021);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 雷达图

# %%
df = pd.DataFrame(data = [['骑行', 32, 12],
                         ['足球', 32, 12],
                         ['酷跑', 28, 22],
                         ['健身', 12, 21],
                         ['攀岩', 15, 28]],
                 
                  columns = ['种类', '数值1', '数值2']
                 )

# %%
df
# Out:
#    种类  数值1  数值2
# 0  骑行   32   12
# 1  足球   32   12
# 2  酷跑   28   22
# 3  健身   12   21
# 4  攀岩   15   28

# %%
df.种类.to_list()
# Out:
# ['骑行', '足球', '酷跑', '健身', '攀岩']

# %%
df.iloc[:, 1:]
# Out:
#    数值1  数值2
# 0   32   12
# 1   32   12
# 2   28   22
# 3   12   21
# 4   15   28

# %%
x = df.iloc[:, 1:].max(axis=1).to_list()
x
# Out:
# [32, 32, 28, 21, 28]

# %%
import pyecharts.options as opts
from pyecharts.charts import Radar
ra = (
    Radar(init_opts=opts.InitOpts(page_title='雷达图' ))
    .add_schema(
        schema=[
            opts.RadarIndicatorItem(name=df.种类.to_list()[0]+'（50）', max_= 50),
            opts.RadarIndicatorItem(name=df.种类.to_list()[1]+'（50）', max_= 50),
            opts.RadarIndicatorItem(name=df.种类.to_list()[2]+'（50）', max_= 50),
            opts.RadarIndicatorItem(name=df.种类.to_list()[3]+'（50）', max_= 50),
            opts.RadarIndicatorItem(name=df.种类.to_list()[4]+'（50）', max_= 50),
        ],
        splitarea_opt=opts.SplitAreaOpts(
            is_show=True, 
            areastyle_opts=opts.AreaStyleOpts(opacity=0.1)
        ),
        # 几个维度的字体
        textstyle_opts=opts.TextStyleOpts(font_size=22, color=""),
        
        
    )
    .add(
        series_name="数值1",
        data=[df.数值1.to_list()],
        color='#028599',
        linestyle_opts=opts.LineStyleOpts(width=3), # 线宽
        areastyle_opts=opts.AreaStyleOpts(opacity=0.2)  # 图像填充透明度
    )
    .add(
        series_name="数值2",
        data=[df.数值2.to_list()],
        color='#FF3F5F',
        linestyle_opts=opts.LineStyleOpts(width=3), 
        areastyle_opts=opts.AreaStyleOpts(opacity=0) # 不填充
    )
    # 系列配置项
    .set_series_opts(
    
        # 数据标签配置项
        label_opts=opts.LabelOpts(
            is_show = True,
            position = 'top'
        )
    
    
    )
    
    # 全局配置项
    .set_global_opts(
        
        # 图表标题
        title_opts=opts.TitleOpts(is_show=False, 
                                  title='这是一个雷达图', 
                                  pos_left='center'
                                 ),
        # 图例
        legend_opts=opts.LegendOpts(is_show=True 
                                    # ,pos_top=0  # 图例离上边界 30
                                    # ,pos_left=350
                                    ,pos_bottom=1
                                    ,orient = 'horizontal'   #  可选：'horizontal', 'vertical'#
                                    ,border_color='transparent'# 图例边界颜色为 透明

                               ),  
    
    )
    .render("雷达图.html")
)

from IPython.display import IFrame
IFrame(src='雷达图.html', width=950, height=520)
# Out:
#         <iframe
#             width="950"
#             height="520"
#             src="雷达图.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
ra
# Out:
# 'D:\\yxp_ipy\\03 可视化\\pyecharts\\雷达图.html'

# %% [markdown]
# # 漏斗图

# %%
df = pd.DataFrame(data = [['展现', 100], ['点击', 90], ['访问', 80], ['咨询', 50], ['订单', 10]],
             columns = ['步骤', '人数'
                       
                       ]
            
            
            )
df['相对上一步的转化率'] = df.人数/df.人数.shift(1)

df['相对第一步的转化率'] = df.人数/100
df
# Out:
#    步骤   人数  相对上一步的转化率  相对第一步的转化率
# 0  展现  100        NaN        1.0
# 1  点击   90   0.900000        0.9
# 2  访问   80   0.888889        0.8
# 3  咨询   50   0.625000        0.5
# 4  订单   10   0.200000        0.1

# %%
data = df[['步骤', '人数']].values.tolist()
data
# Out:
# [['展现', 100], ['点击', 90], ['访问', 80], ['咨询', 50], ['订单', 10]]

# %%
import pyecharts.options as opts
from pyecharts.charts import Funnel

(
    Funnel(init_opts=opts.InitOpts(page_title='漏斗图' ))
    .add(
        series_name="",
        data_pair=data,
        gap=2,
        # tooltip_opts=opts.TooltipOpts(trigger="item", formatter="{a} <br/>{b} : {c}%"),
        label_opts=opts.LabelOpts(is_show=True, position="inside",
                                           formatter="{b} : {c}",
                                 font_size=12
                                 ),
        
        
        
        itemstyle_opts=opts.ItemStyleOpts(border_color="#fff", border_width=1),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="漏斗图", subtitle="纯属虚构"))
    .render("漏斗图.html")
)
from IPython.display import IFrame
IFrame(src='漏斗图.html', width=950, height=520)
# Out:
#         <iframe
#             width="950"
#             height="520"
#             src="漏斗图.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 桑基图

# %%
from pyecharts import options as opts
from pyecharts.charts import Sankey

nodes = [
    {"name": "category1"},
    {"name": "category2"},
    {"name": "category3"},
    {"name": "category4"},
    {"name": "category5"},
    {"name": "category6"},
]

links = [
    {"source": "category1", "target": "category2", "value": 10},
    {"source": "category2", "target": "category3", "value": 15},
    {"source": "category3", "target": "category4", "value": 20},
    {"source": "category5", "target": "category6", "value": 25},
]
c = (
    Sankey(init_opts=opts.InitOpts(page_title='桑基图' ))
    .add(
        "sankey",
        nodes,
        links,
        linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
        label_opts=opts.LabelOpts(position="right",formatter="{b}"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title=""),
                     legend_opts=opts.LegendOpts(is_show=False)
                    )
    
    .render("桑基图.html")
)
from IPython.display import IFrame
IFrame(src='桑基图.html', width=950, height=520)
# Out:
#         <iframe
#             width="950"
#             height="520"
#             src="桑基图.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 词云图

# %%
df = pd.DataFrame([
    ("花鸟市场", 1446),
    ("汽车", 928),
    ("视频", 906),
    ("电视", 825),
    ("Lover Boy 88", 514),
    ("动漫", 486),
    ("音乐", 53),
    ("直播", 163),
    ("广播电台", 86),
    ("戏曲曲艺", 17),
    ("演出票务", 6),
    ("给陌生的你听", 1),
    ("资讯", 1437),
    ("商业财经", 422),
    ("娱乐八卦", 353),
    ("军事", 331),
    ("科技资讯", 313),
    ("社会时政", 307),
    ("时尚", 43),
    ("网络奇闻", 15)
])
df.columns = ['词', '数值']
df
# Out:
#                词    数值
# 0           花鸟市场  1446
# 1             汽车   928
# 2             视频   906
# 3             电视   825
# 4   Lover Boy 88   514
# 5             动漫   486
# 6             音乐    53
# 7             直播   163
# 8           广播电台    86
# 9           戏曲曲艺    17
# 10          演出票务     6
# 11        给陌生的你听     1
# 12            资讯  1437
# 13          商业财经   422
# 14          娱乐八卦   353
# 15            军事   331
# 16          科技资讯   313
# 17          社会时政   307
# 18            时尚    43
# 19          网络奇闻    15

# %%
df.values.to_
# Out:
# array([['花鸟市场', 1446],
#        ['汽车', 928],
#        ['视频', 906],
#        ['电视', 825],
#        ['Lover Boy 88', 514],
#        ['动漫', 486],
#        ['音乐', 53],
#        ['直播', 163],
#        ['广播电台', 86],
#        ['戏曲曲艺', 17],
#        ['演出票务', 6],
#        ['给陌生的你听', 1],
#        ['资讯', 1437],
#        ['商业财经', 422],
#        ['娱乐八卦', 353],
#        ['军事', 331],
#        ['科技资讯', 313],
#        ['社会时政', 307],
#        ['时尚', 43],
#        ['网络奇闻', 15]], dtype=object)

# %%
from pyecharts import options as opts
from pyecharts.charts import WordCloud

words = 
c = (
    WordCloud()
    .add("", words, word_size_range=[12, 55])
    .set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-自定义图片"))
    .render("词云图.html")
)


from IPython.display import IFrame
IFrame(src='词云图.html', width=950, height=520)
# Out:
#         <iframe
#             width="950"
#             height="520"
#             src="词云图.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 组合图

# %% [markdown]
# ## 柱状图+线图

# %% [markdown]
# ## 散点图+线图

# %%
from pyecharts.charts import Scatter, Line
sc1 = Scatter()
sc1.add_xaxis(xaxis_data=df.Series1.to_list())
sc1.add_yaxis(series_name = 'A',
             y_axis =df.Series2.to_list(),
             symbol_size=20,
             label_opts=opts.LabelOpts(is_show=False),
            )
sc1.set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_="value",     #  如果x是数值型，这里要指定为 value
        )
)

sc2 = Scatter()
sc2.add_xaxis(xaxis_data=df.Series2.to_list())
sc2.add_yaxis(series_name = 'B',
             y_axis =df.Series3.to_list(),
             symbol_size=20,
             label_opts=opts.LabelOpts(is_show=False),
            )
sc2.set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_="value",     #  如果x是数值型，这里要指定为 value
        )
)


x = np.linspace(0, 500, 20).tolist()
y = (np.sin(x)*200+200).tolist()
line1 = Line()
line1.add_xaxis(x)
line1.add_yaxis('C',y,label_opts=opts.LabelOpts(is_show=False), is_smooth=True)

sc1.overlap(sc2)
sc1.overlap(line1)
sc1.load_javascript()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 3>()
#       1 from pyecharts.charts import Scatter, Line
#       2 sc1 = Scatter()
# ----> 3 sc1.add_xaxis(xaxis_data=df.Series1.to_list())
#       4 sc1.add_yaxis(series_name = 'A',
#       5              y_axis =df.Series2.to_list(),
#       6              symbol_size=20,
#       7              label_opts=opts.LabelOpts(is_show=False),
#       8             )
#       9 sc1.set_global_opts(
#      10         xaxis_opts=opts.AxisOpts(
#      11             type_="value",     #  如果x是数值型，这里要指定为 value
#      12         )
#      13 )
#
# File D:\anaconda\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Series1'

# %%
sc1.render_notebook()

# %%
words = [
    ("花鸟市场", 1446),
    ("汽车", 928),
    ("视频", 906),
    ("电视", 825),
    ("Lover Boy 88", 514),
    ("动漫", 486),
    ("音乐", 53),
    ("直播", 163),
    ("广播电台", 86),
    ("戏曲曲艺", 17),
    ("演出票务", 6),
    ("给陌生的你听", 1),
    ("资讯", 1437),
    ("商业财经", 422),
    ("娱乐八卦", 353),
    ("军事", 331),
    ("科技资讯", 313),
    ("社会时政", 307),
    ("时尚", 43),
    ("网络奇闻", 15),
    ("旅游出行", 438),
    ("景点类型", 957),
    ("国内游", 927),
    ("远途出行方式", 908),
    ("酒店", 693),
    ("关注景点", 611),
    ("旅游网站偏好", 512),
    ("出国游", 382),
    ("交通票务", 312),
    ("旅游方式", 187),
    ("旅游主题", 163),
    ("港澳台", 104),
    ("本地周边游", 3),
    ("小卖家", 1331),
    ("全日制学校", 941),
    ("基础教育科目", 585),
    ("考试培训", 473),
    ("语言学习", 358),
    ("留学", 246),
    ("K12课程培训", 207),
    ("艺术培训", 194),
    ("技能培训", 104),
    ("IT培训", 87),
    ("高等教育专业", 63),
    ("家教", 48),
    ("体育培训", 23),
    ("职场培训", 5),
    ("金融财经", 1328),
    ("银行", 765),
    ("股票", 452),
    ("保险", 415),
    ("贷款", 253),
    ("基金", 211),
    ("信用卡", 180),
    ("外汇", 138),
    ("P2P", 116),
    ("贵金属", 98),
    ("债券", 93),
    ("网络理财", 92),
    ("信托", 90),
    ("征信", 76),
    ("期货", 76),
    ("公积金", 40),
    ("银行理财", 36),
    ("银行业务", 30),
    ("典当", 7),
    ("海外置业", 1),
    ("汽车", 1309),
    ("汽车档次", 965),
    ("汽车品牌", 900),
    ("汽车车型", 727),
    ("购车阶段", 461),
    ("二手车", 309),
    ("汽车美容", 260),
    ("新能源汽车", 173),
    ("汽车维修", 155),
    ("租车服务", 136),
    ("车展", 121),
    ("违章查询", 76),
    ("汽车改装", 62),
    ("汽车用品", 37),
    ("路况查询", 32),
    ("汽车保险", 28),
    ("陪驾代驾", 4),
    ("网络购物", 1275),
    ("做我的猫", 1088),
    ("只想要你知道", 907),
    ("团购", 837),
    ("比价", 201),
    ("海淘", 195),
    ("移动APP购物", 179),
    ("支付方式", 119),
    ("代购", 43),
    ("体育健身", 1234),
    ("体育赛事项目", 802),
    ("运动项目", 405),
    ("体育类赛事", 337),
    ("健身项目", 199),
    ("健身房健身", 78),
    ("运动健身", 77),
    ("家庭健身", 36),
    ("健身器械", 29),
    ("办公室健身", 3),
    ("商务服务", 1201),
    ("法律咨询", 508),
    ("化工材料", 147),
    ("广告服务", 125),
    ("会计审计", 115),
    ("人员招聘", 101),
    ("印刷打印", 66),
    ("知识产权", 32),
    ("翻译", 22),
    ("安全安保", 9),
    ("公关服务", 8),
    ("商旅服务", 2),
    ("展会服务", 2),
    ("特许经营", 1),
    ("休闲爱好", 1169),
    ("收藏", 412),
    ("摄影", 393),
    ("温泉", 230),
    ("博彩彩票", 211),
    ("美术", 207),
    ("书法", 139),
    ("DIY手工", 75),
    ("舞蹈", 23),
    ("钓鱼", 21),
    ("棋牌桌游", 17),
    ("KTV", 6),
    ("密室", 5),
    ("采摘", 4),
    ("电玩", 1),
    ("真人CS", 1),
    ("轰趴", 1),
    ("家电数码", 1111),
    ("手机", 885),
    ("电脑", 543),
    ("大家电", 321),
    ("家电关注品牌", 253),
    ("网络设备", 162),
    ("摄影器材", 149),
    ("影音设备", 133),
    ("办公数码设备", 113),
    ("生活电器", 67),
    ("厨房电器", 54),
    ("智能设备", 45),
    ("个人护理电器", 22),
    ("服饰鞋包", 1047),
    ("服装", 566),
    ("饰品", 289),
    ("鞋", 184),
    ("箱包", 168),
    ("奢侈品", 137),
    ("母婴亲子", 1041),
    ("孕婴保健", 505),
    ("母婴社区", 299),
    ("早教", 103),
    ("奶粉辅食", 66),
    ("童车童床", 41),
    ("关注品牌", 271),
    ("宝宝玩乐", 30),
    ("母婴护理服务", 25),
    ("纸尿裤湿巾", 16),
    ("妈妈用品", 15),
    ("宝宝起名", 12),
    ("童装童鞋", 9),
    ("胎教", 8),
    ("宝宝安全", 1),
    ("宝宝洗护用品", 1),
    ("软件应用", 1018),
    ("系统工具", 896),
    ("理财购物", 440),
    ("生活实用", 365),
    ("影音图像", 256),
    ("社交通讯", 214),
    ("手机美化", 39),
    ("办公学习", 28),
    ("应用市场", 23),
    ("母婴育儿", 14),
    ("游戏", 946),
    ("手机游戏", 565),
    ("PC游戏", 353),
    ("网页游戏", 254),
    ("游戏机", 188),
    ("模拟辅助", 166),
    ("个护美容", 942),
    ("护肤品", 177),
    ("彩妆", 133),
    ("美发", 80),
    ("香水", 50),
    ("个人护理", 46),
    ("美甲", 26),
    ("SPA美体", 21),
    ("花鸟萌宠", 914),
    ("绿植花卉", 311),
    ("狗", 257),
    ("其他宠物", 131),
    ("水族", 125),
    ("猫", 122),
    ("动物", 81),
    ("鸟", 67),
    ("宠物用品", 41),
    ("宠物服务", 26),
    ("书籍阅读", 913),
    ("网络小说", 483),
    ("关注书籍", 128),
    ("文学", 105),
    ("报刊杂志", 77),
    ("人文社科", 22),
    ("建材家居", 907),
    ("装修建材", 644),
    ("家具", 273),
    ("家居风格", 187),
    ("家居家装关注品牌", 140),
    ("家纺", 107),
    ("厨具", 47),
    ("灯具", 43),
    ("家居饰品", 29),
    ("家居日常用品", 10),
    ("生活服务", 883),
    ("物流配送", 536),
    ("家政服务", 108),
    ("摄影服务", 49),
    ("搬家服务", 38),
    ("物业维修", 37),
    ("婚庆服务", 24),
    ("二手回收", 24),
    ("鲜花配送", 3),
    ("维修服务", 3),
    ("殡葬服务", 1),
    ("求职创业", 874),
    ("创业", 363),
    ("目标职位", 162),
    ("目标行业", 50),
    ("兼职", 21),
    ("期望年薪", 20),
    ("实习", 16),
    ("雇主类型", 10),
    ("星座运势", 789),
    ("星座", 316),
    ("算命", 303),
    ("解梦", 196),
    ("风水", 93),
    ("面相分析", 47),
    ("手相", 32),
    ("公益", 90),
]

# %%
import json
import base64

img_path = r'1.png';
with open(img_path, 'rb') as file:
    image_data1 = file.read()
image = base64.b64encode(image_data1).decode('utf8')
data = {"key": ["image"], "value": [image]}
# 转成 json 字符串
json_str = json.dumps(data)

# %%
json_str[0:100]

# %%
json.load()

# %%
import json

from pyecharts import options as opts
from pyecharts.charts import WordCloud



# with open("wordcloud_image_base64.json", "r", encoding="utf-8") as f:
#     j = json.load(f)


c = (
    WordCloud()
    .add("", words, word_size_range=[12, 55], mask_image=json_str["base64"])
    .set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-自定义图片"))
    .render("wordcloud_custom_mask_image.html")
)

# %%
s1 = '''
冠县国美
冠百购物中心
莘县成和
陵县家庭号购物中心
德百家电澳德乐店
庆云供销大厦
武城盐百购物广场
武城金蝶电子
武城好运来购物
德百家电大楼店
'''.split()

# %%
s2 = '''
聊城百大三联
冠县国美
武城盐百购物广场
陵县家庭号购物中心
聊城金鼎
惠民信誉楼
莘县成和
开发区振华超市
冠百购物中心
临清商博瑞
高唐双隆购物广场
垦利县信誉楼
德百家电大楼店
庆云供销大厦
高唐商博瑞

'''.split()

# %%
s3 = '''
冠县国美
德百家电大楼店
垦利县信誉楼

'''.split()

# %%
s4 = '''
聊城百大三联
冠县国美
武城盐百购物广场
陵县家庭号购物中心
聊城金鼎
惠民信誉楼
莘县成和
开发区振华超市
冠百购物中心
临清商博瑞
高唐双隆购物广场
垦利县信誉楼
德百家电大楼店
庆云供销大厦
高唐商博瑞
德州武城德百
夏津大鹏影库
莘县张寨

'''.split()

# %%
s1

# %%
for i in pd.Series(s1+s2+s3+s4).value_counts().head(5).index:
    print(i, end='、')
